# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
import glob 

from vehicle_model_DDQN1 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 1)

# %%
# STATE_SIZE = env.calculation_comp["state_size"]
STATE_SIZE = 4
ACTION_SIZE = env.calculation_comp["action_size"] 
LEARNING_RATE = 0.00025 

TOTAL_EPISODES = 500
MAX_STEPS = 50000 

GAMMA = 0.95 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
TAU = 0.001 
DELAY_TRAINING = 10000
EPSILON_MIN_ITER = 5000

# %%
primary_network = keras.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()), 
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(ACTION_SIZE),
])
target_network = keras.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()), 
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(ACTION_SIZE),
])

primary_network.compile(
    loss="mse", 
    optimizer=keras.optimizers.Adam(lr=LEARNING_RATE) 
)

# for t, p in zip(target_network.trainable_variables, primary_network.trainable_variables): 
#     t.assign(p)

# %%
def update_network(primary_network, target_network): 
    for t, p in zip(target_network.trainable_variables, primary_network.trainable_variables): 
        t.assign(t * (1 - TAU) + p * TAU)

# %%
class Memory: 
    def __init__(self, max_memory): 
        self.max_memory = max_memory 
        self._samples = [] 
        
    def add_sample(self, sample): 
        self._samples.append(sample)
        if len(self._samples) > self.max_memory: 
            self._samples.pop(0)
        
    def sample(self, no_samples): 
        if no_samples > len(self._samples): 
            return random.sample(self._samples, len(self._samples))
        else: 
            return random.sample(self._samples, no_samples)
    
    @property
    def num_samples(self):
        return len(self._samples)
    

# memory = Memory(10000)

# %%
def choose_action(state, primary_network, eps): 
    if random.random() < eps: 
        return random.randint(0, ACTION_SIZE - 1)
    else: 
        return np.argmax(primary_network(np.array(state).reshape(1, -1)))

# %%
def train(primary_network, target_network, memory): 
    batch = memory.sample(BATCH_SIZE)
    states = np.array([val[0] for val in batch]) 
    actions = np.array([val[1] for val in batch])
    rewards = np.array([val[2] for val in batch])
    next_states = np.array([np.zeros(STATE_SIZE) if val[3] is None else val[3]  
                            for val in batch])
    
    prim_qt = primary_network(states)
    prim_qtp1 = primary_network(next_states)
    target_q = prim_qt.numpy() 
    updates = rewards 
    valid_idxs = next_states.sum(axis=1) != 0 
    batch_idxs = np.arange(BATCH_SIZE)
    prim_action_tp1 = np.argmax(prim_qtp1.numpy(), axis=1)
    q_from_target = target_network(next_states)
    updates[valid_idxs] += GAMMA * q_from_target.numpy()[batch_idxs[valid_idxs], 
                                                        prim_action_tp1[valid_idxs]]
    
    target_q[batch_idxs, actions] = updates 
    loss = primary_network.train_on_batch(states, target_q)
    return loss

# %%
def initialization():
    memory = Memory(10000)
    
    primary_network = keras.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=[STATE_SIZE], 
                           kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(),  
        keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(ACTION_SIZE),
    ])
    target_network = keras.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=[STATE_SIZE], 
                           kernel_initializer=keras.initializers.he_normal()), 
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(ACTION_SIZE),
    ])
    primary_network.compile(
        loss="mse", 
        optimizer=keras.optimizers.Adam(lr=LEARNING_RATE) 
    )
    return memory, primary_network, target_network

# %%
def initialization_env(driving_path, reward_factor):
    env = Environment(cell_model, driving_path, battery_path, motor_path, reward_factor)
    return env

# %%
def save_weights(primary_net, target_net, root): 
    primary_net.save_weights("./{}/primary_net_checkpoint".format(root))
    target_net.save_weights("./{}/target_net_checkpoint".format(root))
    print("model is saved..")

# %%
print("environment version: {}".format(env.version)) 

 
reward_factors = [10] * 3
results_dict = {} 
driving_cycle_paths = glob.glob("training/*.mat")
# driving_cycle_paths.pop(1)
driving_cycle_paths = driving_cycle_paths[:10]

for trial, reward_factor in enumerate(reward_factors): 
    eps = MAX_EPSILON 
    steps = 0
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    
    memory, primary_network, target_network = initialization()
#     for episode in range(TOTAL_EPISODES):
    for episode in range(TOTAL_EPISODES): 
        driving_cycle_path = np.random.choice(driving_cycle_paths)
        print(driving_cycle_path)
        env = initialization_env(driving_cycle_path, 10)
        state = env.reset() 

        avg_loss = 0 
        total_reward = 0
        cnt = 1 

        while True:
            action = choose_action(state, primary_network, eps)
            next_state, reward, done = env.step(action)
            total_reward += reward 
            if done: 
                next_state = None 
            memory.add_sample((state, action, reward, next_state))

            if steps > DELAY_TRAINING: 
                loss = train(primary_network, target_network, memory)
                update_network(primary_network, target_network)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps - 
                                                                        DELAY_TRAINING))
            else: 
                loss = -1

            avg_loss += loss 
            steps += 1 

            if done: 
                SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
                avg_loss /= cnt 
                print('Episode: {}'.format(episode),
                      'Total reward: {}'.format(total_reward), 
                      'Explore P: {:.4f}'.format(eps), 
                      "SOC: {:.4f}".format(env.SOC), 
                     "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
                     "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
                     )
                
                episode_rewards.append(total_reward)
                episode_SOCs.append(env.SOC)
                episode_FCs.append(env.fuel_consumption)
                break 

            state = next_state 
            cnt += 1 
    
    root = "DDQN5_trial{}".format(trial+2)
    save_weights(primary_network, target_network, root)
    
    results_dict[reward_factor] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs 
    }
# Out:
# environment version: 1
# training\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 0 Total reward: -2718.7897105070765 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 267.0524 Fuel Consumption: 48.2656
# training\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 1 Total reward: -2847.839663856588 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 279.7690 Fuel Consumption: 50.1496
# training\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 2 Total reward: -2792.1068651339788 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 274.4174 Fuel Consumption: 47.9330
# training\cudec_freeway.mat
# maximum steps, simulation is done ...
# Episode: 3 Total reward: -1701.3210753891904 Explore P: 1.0000 SOC: 0.0819 Cumulative_SOC_deviation: 167.6773 Fuel Consumption: 24.5481
# training\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 4 Total reward: -1414.8690883897623 Explore P: 1.0000 SOC: 0.9257 Cumulative_SOC_deviation: 137.3867 Fuel Consumption: 41.0025
# training\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 5 Total reward: -2648.7795618704763 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 260.2035 Fuel Consumption: 46.7448
# training\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 6 Total reward: -1011.1257580198723 Explore P: 1.0000 SOC: 0.6525 Cumulative_SOC_deviation: 96.4123 Fuel Consumption: 47.0023
# training\cudec_freeway.mat
# maximum steps, simulation is done ...
# Episode: 7 Total reward: -1698.0122333754816 Explore P: 1.0000 SOC: 0.0741 Cumulative_SOC_deviation: 167.3904 Fuel Consumption: 24.1082
# training\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 8 Total reward: -979.9969456670608 Explore P: 1.0000 SOC: 0.8075 Cumulative_SOC_deviation: 92.0041 Fuel Consumption: 59.9558
# training\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 9 Total reward: -2686.1704635979295 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 264.0297 Fuel Consumption: 45.8736
# training\cudec_freeway.mat
# WARNING:tensorflow:Layer dense_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# Episode: 10 Total reward: -1759.4906937598557 Explore P: 0.9947 SOC: 0.0546 Cumulative_SOC_deviation: 173.6603 Fuel Consumption: 22.8879
# training\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 11 Total reward: -2109.207793227868 Explore P: 0.9584 SOC: 0.7594 Cumulative_SOC_deviation: 202.5417 Fuel Consumption: 83.7906
# training\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 12 Total reward: -2727.9203408652393 Explore P: 0.9380 SOC: 1.0000 Cumulative_SOC_deviation: 268.0357 Fuel Consumption: 47.5632
# training\cudec_freeway.mat
# maximum steps, simulation is done ...
# Episode: 13 Total reward: -1775.2999459144244 Explore P: 0.9280 SOC: 0.0585 Cumulative_SOC_deviation: 175.2026 Fuel Consumption: 23.2735
# training\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 14 Total reward: -2081.6923985421636 Explore P: 0.8942 SOC: 0.7691 Cumulative_SOC_deviation: 199.7583 Fuel Consumption: 84.1098
# training\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 15 Total reward: -1957.7529613987938 Explore P: 0.8616 SOC: 0.7382 Cumulative_SOC_deviation: 187.5819 Fuel Consumption: 81.9342
# training\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 16 Total reward: -1034.4834724660257 Explore P: 0.8438 SOC: 0.6291 Cumulative_SOC_deviation: 98.9141 Fuel Consumption: 45.3421
# training\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 17 Total reward: -1655.0449702879675 Explore P: 0.8131 SOC: 0.6873 Cumulative_SOC_deviation: 157.6851 Fuel Consumption: 78.1942
# training\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 18 Total reward: -1179.082260494686 Explore P: 0.7988 SOC: 0.8719 Cumulative_SOC_deviation: 114.2221 Fuel Consumption: 36.8611
# training\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 19 Total reward: -2725.956017425512 Explore P: 0.7819 SOC: 1.0000 Cumulative_SOC_deviation: 267.8237 Fuel Consumption: 47.7186
# training\manhattan.mat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e0d316b23ebc> in <module>
#      36
#      37             if steps > DELAY_TRAINING:
# ---> 38                 loss = train(primary_network, target_network, memory)
#      39                 update_network(primary_network, target_network)
#      40                 eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps -
#
# <ipython-input-8-0a73323861da> in train(primary_network, target_network, memory)
#       7                             for val in batch])
#       8
# ----> 9     prim_qt = primary_network(states)
#      10     prim_qtp1 = primary_network(next_states)
#      11     target_q = prim_qt.numpy()
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py in call(self, inputs, training, mask)
#     254       if not self.built:
#     255         self._init_graph_network(self.inputs, self.outputs, name=self.name)
# --> 256       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     257
#     258     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\network.py in call(self, inputs, training, mask)
#     706     return self._run_internal_graph(
#     707         inputs, training=training, mask=mask,
# --> 708         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     709
#     710   def compute_output_shape(self, input_shape):
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     858
#     859           # Compute outputs.
# --> 860           output_tensors = layer(computed_tensors, **kwargs)
#     861
#     862           # Update tensor_dict.
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     886         with backend.name_scope(self._name_scope()):
#     887           self._maybe_build(inputs)
# --> 888           cast_inputs = self._maybe_cast_inputs(inputs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in _maybe_cast_inputs(self, inputs)
#    1786         else:
#    1787           return x
# -> 1788       return nest.map_structure(f, inputs)
#    1789     else:
#    1790       return inputs
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in f(x)
#    1783           if self._dtype_defaulted_to_floatx:
#    1784             self._warn_about_input_casting(x.dtype.base_dtype)
# -> 1785           return math_ops.cast(x, compute_dtype)
#    1786         else:
#    1787           return x
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\ops\math_ops.py in cast(x, dtype, name)
#     702       x = ops.convert_to_tensor(x, name="x")
#     703       if x.dtype.base_dtype != base_type:
# --> 704         x = gen_math_ops.cast(x, base_type, name=name)
#     705     if x.dtype.is_complex and base_type.is_floating:
#     706       logging.warn("Casting complex to real discards imaginary part.")
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in cast(x, DstT, Truncate, name)
#    2197         _ctx._context_handle, _ctx._thread_local_data.device_name, "Cast",
#    2198         name, _ctx._post_execution_callbacks, x, "DstT", DstT, "Truncate",
# -> 2199         Truncate)
#    2200       return _result
#    2201     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
with open("DDQN5.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)

# %%
# with open("results/replay_memory_size_effect.pkl", "rb") as f: 
#     data = pickle.load(f)
    
# data
