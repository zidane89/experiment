# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 

from vehicle_model_DDPG import Environment 
from cell_model import CellModel 

# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_e-4wd_Battery.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_id_75_110_Westinghouse.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 10)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64): 
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple): 
        index = self.buffer_counter % self.buffer_capacity 
        
        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)
        
        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    out = layers.Dense(512, activation="relu")(inputs)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_out = layers.Dense(16, activation="relu")(state_input)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_input)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    
    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

actor_model = get_actor() 
critic_model = get_critic() 

target_actor = get_actor() 
target_critic = get_critic() 
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

critic_lr = 0.002 
actor_lr = 0.001 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 200 
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002 
BATCH_SIZE = 32

# %%
print(env.version)

buffer = Buffer(50000, BATCH_SIZE)
eps = MAX_EPSILON 
steps = 0 

ep_reward_list = [] 
avg_reward_list = [] 

for ep in range(total_episodes): 
    state = env.reset() 
    episodic_reward = 0 
    
    while True: 
        tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
        action = policy_epsilon_greedy(tf_state, eps)
#         print(action)
        next_state, reward, done = env.step(action)
        if done: 
            next_state = [0] * num_states 
        
        buffer.record((state, action, reward, next_state))
        episodic_reward += reward 
        
        buffer.learn() 
        update_target(tau)
        steps += 1 
        
        eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * steps)
        
        if done: 
            break 
        
        state = next_state 
    
    ep_reward_list.append(episodic_reward) 
    avg_reward = np.mean(ep_reward_list[-40:])
    avg_reward_list.append(avg_reward)
    
#     print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
    SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
    print(
          'Episode: {}'.format(ep + 1),
          'Total reward: {}'.format(episodic_reward), 
          "SOC: {:.4f}".format(env.SOC), 
          "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
          "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
    )
# Out:
# 0
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_13 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_4 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# Episode: 1 Total reward: -894.6918797981173 SOC: 0.7727 Cumulative_SOC_deviation: 83.5958 Fuel Consumption: 58.7336
# maximum steps, simulation is done ...
# Episode: 2 Total reward: -817.0334917868632 SOC: 0.7582 Cumulative_SOC_deviation: 75.9471 Fuel Consumption: 57.5621
# maximum steps, simulation is done ...
# Episode: 3 Total reward: -866.8753500295675 SOC: 0.7761 Cumulative_SOC_deviation: 80.7783 Fuel Consumption: 59.0920
# maximum steps, simulation is done ...
# Episode: 4 Total reward: -786.140642077218 SOC: 0.7049 Cumulative_SOC_deviation: 73.2529 Fuel Consumption: 53.6121
# maximum steps, simulation is done ...
# Episode: 5 Total reward: -792.7133373682939 SOC: 0.7232 Cumulative_SOC_deviation: 73.7654 Fuel Consumption: 55.0597
# maximum steps, simulation is done ...
# Episode: 6 Total reward: -772.3791539874396 SOC: 0.6990 Cumulative_SOC_deviation: 71.9225 Fuel Consumption: 53.1542
# maximum steps, simulation is done ...
# Episode: 7 Total reward: -882.3754969087565 SOC: 0.6698 Cumulative_SOC_deviation: 83.1485 Fuel Consumption: 50.8904
# maximum steps, simulation is done ...
# Episode: 8 Total reward: -772.9384077801185 SOC: 0.6604 Cumulative_SOC_deviation: 72.2766 Fuel Consumption: 50.1725
# maximum steps, simulation is done ...
# Episode: 9 Total reward: -883.4189747243739 SOC: 0.6313 Cumulative_SOC_deviation: 83.5423 Fuel Consumption: 47.9964
# maximum steps, simulation is done ...
# Episode: 10 Total reward: -924.6398693871748 SOC: 0.6397 Cumulative_SOC_deviation: 87.6144 Fuel Consumption: 48.4960
# maximum steps, simulation is done ...
# Episode: 11 Total reward: -982.1676116857561 SOC: 0.6124 Cumulative_SOC_deviation: 93.5696 Fuel Consumption: 46.4718
# maximum steps, simulation is done ...
# Episode: 12 Total reward: -990.2849437535824 SOC: 0.6173 Cumulative_SOC_deviation: 94.3331 Fuel Consumption: 46.9543
# maximum steps, simulation is done ...
# Episode: 13 Total reward: -1223.3549048048235 SOC: 0.5870 Cumulative_SOC_deviation: 117.8744 Fuel Consumption: 44.6113
# maximum steps, simulation is done ...
# Episode: 14 Total reward: -1250.286704597285 SOC: 0.5748 Cumulative_SOC_deviation: 120.6536 Fuel Consumption: 43.7511
# maximum steps, simulation is done ...
# Episode: 15 Total reward: -1351.9794795786943 SOC: 0.5503 Cumulative_SOC_deviation: 131.0309 Fuel Consumption: 41.6702
# maximum steps, simulation is done ...
# Episode: 16 Total reward: -1333.9331680669904 SOC: 0.5578 Cumulative_SOC_deviation: 129.1548 Fuel Consumption: 42.3849
# maximum steps, simulation is done ...
# Episode: 17 Total reward: -1687.6826144561346 SOC: 0.5048 Cumulative_SOC_deviation: 164.9338 Fuel Consumption: 38.3450
# maximum steps, simulation is done ...
# Episode: 18 Total reward: -1646.1043044386352 SOC: 0.5187 Cumulative_SOC_deviation: 160.6624 Fuel Consumption: 39.4802
# maximum steps, simulation is done ...
# Episode: 19 Total reward: -1769.4406027291902 SOC: 0.4983 Cumulative_SOC_deviation: 173.1659 Fuel Consumption: 37.7812
# maximum steps, simulation is done ...
# Episode: 20 Total reward: -1918.4370643178331 SOC: 0.4764 Cumulative_SOC_deviation: 188.2204 Fuel Consumption: 36.2331
# maximum steps, simulation is done ...
# Episode: 21 Total reward: -1821.7101470110306 SOC: 0.4884 Cumulative_SOC_deviation: 178.4580 Fuel Consumption: 37.1297
# maximum steps, simulation is done ...
# Episode: 22 Total reward: -2338.647435546429 SOC: 0.4290 Cumulative_SOC_deviation: 230.6007 Fuel Consumption: 32.6405
# maximum steps, simulation is done ...
# Episode: 23 Total reward: -2061.7215744538 SOC: 0.4496 Cumulative_SOC_deviation: 202.7263 Fuel Consumption: 34.4582
# maximum steps, simulation is done ...
# Episode: 24 Total reward: -2222.3169491819194 SOC: 0.4373 Cumulative_SOC_deviation: 218.8936 Fuel Consumption: 33.3808
# maximum steps, simulation is done ...
# Episode: 25 Total reward: -2416.3269367588982 SOC: 0.4076 Cumulative_SOC_deviation: 238.4992 Fuel Consumption: 31.3352
# maximum steps, simulation is done ...
# Episode: 26 Total reward: -2414.0770140329996 SOC: 0.4004 Cumulative_SOC_deviation: 238.3511 Fuel Consumption: 30.5660
# maximum steps, simulation is done ...
# Episode: 27 Total reward: -2283.249804431745 SOC: 0.4251 Cumulative_SOC_deviation: 225.0794 Fuel Consumption: 32.4554
# maximum steps, simulation is done ...
# Episode: 28 Total reward: -1923.726812731779 SOC: 0.6056 Cumulative_SOC_deviation: 187.6759 Fuel Consumption: 46.9681
# maximum steps, simulation is done ...
# Episode: 29 Total reward: -336.20265780696906 SOC: 0.6383 Cumulative_SOC_deviation: 28.7908 Fuel Consumption: 48.2949
# maximum steps, simulation is done ...
# Episode: 30 Total reward: -378.64119241681203 SOC: 0.6324 Cumulative_SOC_deviation: 33.0504 Fuel Consumption: 48.1369
# maximum steps, simulation is done ...
# Episode: 31 Total reward: -288.31566123162355 SOC: 0.6165 Cumulative_SOC_deviation: 24.1653 Fuel Consumption: 46.6631
# maximum steps, simulation is done ...
# Episode: 32 Total reward: -303.9166438979321 SOC: 0.6088 Cumulative_SOC_deviation: 25.7856 Fuel Consumption: 46.0610
# maximum steps, simulation is done ...
# Episode: 33 Total reward: -297.4225251571798 SOC: 0.6238 Cumulative_SOC_deviation: 25.0148 Fuel Consumption: 47.2745
# maximum steps, simulation is done ...
# Episode: 34 Total reward: -275.4190758983801 SOC: 0.6177 Cumulative_SOC_deviation: 22.8785 Fuel Consumption: 46.6345
# maximum steps, simulation is done ...
# Episode: 35 Total reward: -279.5782940213938 SOC: 0.6177 Cumulative_SOC_deviation: 23.2931 Fuel Consumption: 46.6476
# maximum steps, simulation is done ...
# Episode: 36 Total reward: -273.01836644435 SOC: 0.6106 Cumulative_SOC_deviation: 22.6972 Fuel Consumption: 46.0467
# maximum steps, simulation is done ...
# Episode: 37 Total reward: -261.829321956835 SOC: 0.6108 Cumulative_SOC_deviation: 21.5726 Fuel Consumption: 46.1031
# maximum steps, simulation is done ...
# Episode: 38 Total reward: -271.07522810600034 SOC: 0.6098 Cumulative_SOC_deviation: 22.5157 Fuel Consumption: 45.9181
# maximum steps, simulation is done ...
# Episode: 39 Total reward: -278.20857642648565 SOC: 0.6121 Cumulative_SOC_deviation: 23.1884 Fuel Consumption: 46.3248
# maximum steps, simulation is done ...
# Episode: 40 Total reward: -254.66355401477614 SOC: 0.6058 Cumulative_SOC_deviation: 20.9014 Fuel Consumption: 45.6492
# maximum steps, simulation is done ...
# Episode: 41 Total reward: -252.80065406282844 SOC: 0.6097 Cumulative_SOC_deviation: 20.6825 Fuel Consumption: 45.9758
# maximum steps, simulation is done ...
# Episode: 42 Total reward: -249.885975566139 SOC: 0.6100 Cumulative_SOC_deviation: 20.3968 Fuel Consumption: 45.9176
# maximum steps, simulation is done ...
# Episode: 43 Total reward: -258.80273837495474 SOC: 0.6078 Cumulative_SOC_deviation: 21.2948 Fuel Consumption: 45.8546
# maximum steps, simulation is done ...
# Episode: 44 Total reward: -264.25720975661596 SOC: 0.6124 Cumulative_SOC_deviation: 21.8228 Fuel Consumption: 46.0296
# maximum steps, simulation is done ...
# Episode: 45 Total reward: -259.12539253454133 SOC: 0.6093 Cumulative_SOC_deviation: 21.3364 Fuel Consumption: 45.7616
# maximum steps, simulation is done ...
# Episode: 46 Total reward: -270.24547072690996 SOC: 0.6067 Cumulative_SOC_deviation: 22.4583 Fuel Consumption: 45.6628
# maximum steps, simulation is done ...
# Episode: 47 Total reward: -253.6434013488725 SOC: 0.6070 Cumulative_SOC_deviation: 20.8120 Fuel Consumption: 45.5229
# maximum steps, simulation is done ...
# Episode: 48 Total reward: -246.26013670593403 SOC: 0.6033 Cumulative_SOC_deviation: 20.1138 Fuel Consumption: 45.1222
# maximum steps, simulation is done ...
# Episode: 49 Total reward: -257.9198631878338 SOC: 0.6029 Cumulative_SOC_deviation: 21.2577 Fuel Consumption: 45.3433
# maximum steps, simulation is done ...
# Episode: 50 Total reward: -301.48467115812514 SOC: 0.5959 Cumulative_SOC_deviation: 25.6884 Fuel Consumption: 44.6008
# maximum steps, simulation is done ...
# Episode: 51 Total reward: -270.53330290426373 SOC: 0.6041 Cumulative_SOC_deviation: 22.5037 Fuel Consumption: 45.4963
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1d2d34c9f966> in <module>
#      24
#      25         buffer.learn()
# ---> 26         update_target(tau)
#      27         steps += 1
#      28
#
# <ipython-input-5-732055c3c3b0> in update_target(tau)
#       3     target_variables = target_critic.weights
#       4     for i, variable in enumerate(critic_model.weights):
# ----> 5         new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
#       6     target_critic.set_weights(new_weights)
#       7
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\ops\variables.py in _run_op(a, *args, **kwargs)
#    1077     def _run_op(a, *args, **kwargs):
#    1078       # pylint: disable=protected-access
# -> 1079       return tensor_oper(a.value(), *args, **kwargs)
#    1080
#    1081     functools.update_wrapper(_run_op, tensor_oper)
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\ops\math_ops.py in binary_op_wrapper(x, y)
#     910           else:
#     911             raise
# --> 912       return func(x, y, name=name)
#     913
#     914   def binary_op_wrapper_sparse(sp_x, y):
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\ops\math_ops.py in _mul_dispatch(x, y, name)
#    1204   is_tensor_y = isinstance(y, ops.Tensor)
#    1205   if is_tensor_y:
# -> 1206     return gen_math_ops.mul(x, y, name=name)
#    1207   else:
#    1208     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# ~\Anaconda3\envs\tf2.1_gpu\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in mul(x, y, name)
#    6683       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    6684         _ctx._context_handle, _ctx._thread_local_data.device_name, "Mul",
# -> 6685         name, _ctx._post_execution_callbacks, x, y)
#    6686       return _result
#    6687     except _core._FallbackException:
#
# KeyboardInterrupt:
