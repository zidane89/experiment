# %%
import matplotlib.pyplot as plt 
import pickle

# %%
with open("DDQN_3_1_ver2.pkl", "rb") as f: 
    data1 = pickle.load(f)[10]
with open("DDQN_3_2_ver2.pkl", "rb") as f: 
    data2 = pickle.load(f)[10]
with open("DDQN_3_3_ver2.pkl", "rb") as f: 
    data3 = pickle.load(f)[10]
with open("DDQN_3_4_ver2.pkl", "rb") as f: 
    data4 = pickle.load(f)[10]

# %%
plt.plot(data1["rewards"], label="version1", linewidth=2) 
plt.plot(data2["rewards"], label="version2", linewidth=2)
plt.plot(data3["rewards"], label="version3", linewidth=2)
plt.plot(data4["rewards"], label="version4", linewidth=2)

plt.xlabel("episodes")
plt.ylabel("episodic rewards")
plt.legend() 
plt.grid() 
# plt.ylim([-1000, -250])
plt.savefig("rewards_with_states.png")

# %%
rewards = results["rewards"]
SOCs = results["SOCs"]


plt.plot(rewards, label="rewards")
plt.xlabel("episodes")
plt.ylabel("episodic rewards")
plt.grid()
plt.savefig("results.png")
