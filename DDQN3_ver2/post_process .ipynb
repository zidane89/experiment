# %%
import matplotlib.pyplot as plt 
import pickle

# %%
with open("DDQN3_1_400.pkl", "rb") as f: 
    data1 = pickle.load(f)[1]
with open("DDQN3_2_400.pkl", "rb") as f: 
    data2 = pickle.load(f)[1]
with open("DDQN3_3_400.pkl", "rb") as f: 
    data3 = pickle.load(f)[1]

# %%
plt.figure(figsize=(12, 7))
plt.plot(data1["rewards"], label="power in W", linewidth=2) 
plt.plot(data2["rewards"], label="power in kW", linewidth=2)
plt.plot(data3["rewards"], label="power normalized", linewidth=2)

plt.xlabel("episodes", fontsize=16)
plt.ylabel("episodic rewards", fontsize=16)
plt.xlim([0, 125])
plt.legend(fontsize=14, loc="upper left") 
plt.grid() 
# plt.ylim([-1000, -250])
plt.savefig("rewards_with_states.png")

# %%
rewards = results["rewards"]
SOCs = results["SOCs"]


plt.plot(rewards, label="rewards")
plt.xlabel("episodes")
plt.ylabel("episodic rewards")
plt.grid()
plt.savefig("results.png")
