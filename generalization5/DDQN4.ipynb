# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
import glob 

from vehicle_model_DDQN1 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 1)

# %%
# STATE_SIZE = env.calculation_comp["state_size"]
STATE_SIZE = 4
ACTION_SIZE = env.calculation_comp["action_size"] 
LEARNING_RATE = 0.00025 

TOTAL_EPISODES = 400
MAX_STEPS = 50000 

GAMMA = 0.95 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
TAU = 0.001 
DELAY_TRAINING = 10000
EPSILON_MIN_ITER = 5000

# %%
primary_network = keras.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()), 
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(ACTION_SIZE),
])
target_network = keras.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()), 
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(ACTION_SIZE),
])

primary_network.compile(
    loss="mse", 
    optimizer=keras.optimizers.Adam(lr=LEARNING_RATE) 
)

# for t, p in zip(target_network.trainable_variables, primary_network.trainable_variables): 
#     t.assign(p)

# %%
def update_network(primary_network, target_network): 
    for t, p in zip(target_network.trainable_variables, primary_network.trainable_variables): 
        t.assign(t * (1 - TAU) + p * TAU)

# %%
class Memory: 
    def __init__(self, max_memory): 
        self.max_memory = max_memory 
        self._samples = [] 
        
    def add_sample(self, sample): 
        self._samples.append(sample)
        if len(self._samples) > self.max_memory: 
            self._samples.pop(0)
        
    def sample(self, no_samples): 
        if no_samples > len(self._samples): 
            return random.sample(self._samples, len(self._samples))
        else: 
            return random.sample(self._samples, no_samples)
    
    @property
    def num_samples(self):
        return len(self._samples)
    

# memory = Memory(10000)

# %%
def choose_action(state, primary_network, eps): 
    if random.random() < eps: 
        return random.randint(0, ACTION_SIZE - 1)
    else: 
        return np.argmax(primary_network(np.array(state).reshape(1, -1)))

# %%
def train(primary_network, target_network, memory): 
    batch = memory.sample(BATCH_SIZE)
    states = np.array([val[0] for val in batch]) 
    actions = np.array([val[1] for val in batch])
    rewards = np.array([val[2] for val in batch])
    next_states = np.array([np.zeros(STATE_SIZE) if val[3] is None else val[3]  
                            for val in batch])
    
    prim_qt = primary_network(states)
    prim_qtp1 = primary_network(next_states)
    target_q = prim_qt.numpy() 
    updates = rewards 
    valid_idxs = next_states.sum(axis=1) != 0 
    batch_idxs = np.arange(BATCH_SIZE)
    prim_action_tp1 = np.argmax(prim_qtp1.numpy(), axis=1)
    q_from_target = target_network(next_states)
    updates[valid_idxs] += GAMMA * q_from_target.numpy()[batch_idxs[valid_idxs], 
                                                        prim_action_tp1[valid_idxs]]
    
    target_q[batch_idxs, actions] = updates 
    loss = primary_network.train_on_batch(states, target_q)
    return loss

# %%
def initialization():
    memory = Memory(10000)
    
    primary_network = keras.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=[STATE_SIZE], 
                           kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(),  
        keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(ACTION_SIZE),
    ])
    target_network = keras.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=[STATE_SIZE], 
                           kernel_initializer=keras.initializers.he_normal()), 
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(ACTION_SIZE),
    ])
    primary_network.compile(
        loss="mse", 
        optimizer=keras.optimizers.Adam(lr=LEARNING_RATE) 
    )
    return memory, primary_network, target_network

# %%
def initialization_env(driving_path, reward_factor):
    env = Environment(cell_model, driving_path, battery_path, motor_path, reward_factor)
    return env

# %%
def save_weights(primary_net, target_net, root): 
    primary_net.save_weights("./{}/primary_net_checkpoint".format(root))
    target_net.save_weights("./{}/target_net_checkpoint".format(root))
    print("model is saved..")

# %%
def test_agent(primary_network, reward_factor, test_path_start): 
    test_cycles = glob.glob("../data/driving_cycles/city/*.mat")[test_path_start:]
    test_cycle = np.random.choice(test_cycles)
    env = initialization_env(test_cycle, reward_factor)
    
    total_reward = 0 
    state = env.reset()
    while True: 
        action = np.argmax(primary_network(np.array(state).reshape(1, -1))) 
        next_state, reward, done = env.step(action)
        
        state = next_state 
        total_reward += reward 
        
        if done: 
            break 
            
    SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
    print("******************* Test is done *****************")
    print(test_cycle)
    print('Total reward: {}'.format(total_reward), 
          "SOC: {:.4f}".format(env.SOC), 
          "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
          "Fuel Consumption: {:.4f}".format(env.fuel_consumption))
    print("******************* Test is done *****************")
    print("")
    return env.history

# %%
print("environment version: {}".format(env.version)) 

 
reward_factors = [10] 
results_dict = {} 
driving_cycle_paths = glob.glob("../data/driving_cycles/city/*.mat")[:20]

for trial, reward_factor in enumerate(reward_factors): 
    eps = MAX_EPSILON 
    steps = 0
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    episode_test_history = [] 
    episode_num_test = [] 
    
    memory, primary_network, target_network = initialization()
#     for episode in range(TOTAL_EPISODES):
    for episode in range(TOTAL_EPISODES): 
        k = episode % len(driving_cycle_paths)
        driving_cycle_path = driving_cycle_paths[k]
#         driving_cycle_path = np.random.choice(driving_cycle_paths)
        print(driving_cycle_path)
        env = initialization_env(driving_cycle_path, reward_factor)
        state = env.reset() 

        avg_loss = 0 
        total_reward = 0
        cnt = 1 

        while True:
            action = choose_action(state, primary_network, eps)
            next_state, reward, done = env.step(action)
            total_reward += reward 
            if done: 
                next_state = None 
            memory.add_sample((state, action, reward, next_state))

            if steps > DELAY_TRAINING: 
                loss = train(primary_network, target_network, memory)
                update_network(primary_network, target_network)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps - 
                                                                        DELAY_TRAINING))
            else: 
                loss = -1

            avg_loss += loss 
            steps += 1 

            if done: 
                SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
                avg_loss /= cnt 
                print('Episode: {}'.format(episode),
                      'Total reward: {}'.format(total_reward), 
                      'Explore P: {:.4f}'.format(eps), 
                      "SOC: {:.4f}".format(env.SOC), 
                     "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
                     "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
                     )
                
                episode_rewards.append(total_reward)
                episode_SOCs.append(env.SOC)
                episode_FCs.append(env.fuel_consumption)
                break 

            state = next_state 
            cnt += 1 
        
        if (episode + 1) % 10 == 0: 
            history = test_agent(primary_network, reward_factor, -1) 
            episode_test_history.append(history) 
            episode_num_test.append(episode + 1) 
    
    root = "DDQN4_trial{}".format(trial+1)
    save_weights(primary_network, target_network, root)
    
    results_dict[reward_factor] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs, 
        "test_history": episode_test_history, 
        "test_episode_num": episode_num_test,
    }
# Out:
# environment version: 1
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 0 Total reward: -11511.766973210815 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 1119.1962 Fuel Consumption: 319.8054
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 1 Total reward: -6026.5162737234405 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 584.7631 Fuel Consumption: 178.8854
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 2 Total reward: -5439.9474679210325 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 527.6911 Fuel Consumption: 163.0367
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 3 Total reward: -7623.598032336902 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 740.3942 Fuel Consumption: 219.6565
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# WARNING:tensorflow:Layer dense_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# Episode: 4 Total reward: -8586.04985584375 Explore P: 0.9936 SOC: 1.0000 Cumulative_SOC_deviation: 833.8866 Fuel Consumption: 247.1834
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 5 Total reward: -3625.8363930642204 Explore P: 0.9736 SOC: 1.0000 Cumulative_SOC_deviation: 351.1205 Fuel Consumption: 114.6309
# ../data/driving_cycles/city\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 6 Total reward: -5451.226903026141 Explore P: 0.9456 SOC: 1.0000 Cumulative_SOC_deviation: 529.4897 Fuel Consumption: 156.3303
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 7 Total reward: -3886.942818697285 Explore P: 0.9254 SOC: 1.0000 Cumulative_SOC_deviation: 376.6984 Fuel Consumption: 119.9592
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 8 Total reward: -3856.588805763522 Explore P: 0.9058 SOC: 1.0000 Cumulative_SOC_deviation: 374.1450 Fuel Consumption: 115.1392
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 9 Total reward: -6566.449196406108 Explore P: 0.8748 SOC: 1.0000 Cumulative_SOC_deviation: 638.5827 Fuel Consumption: 180.6220
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -242.79650118073206 SOC: 0.6309 Cumulative_SOC_deviation: 22.6477 Fuel Consumption: 16.3194
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 10 Total reward: -6610.976026106605 Explore P: 0.8448 SOC: 1.0000 Cumulative_SOC_deviation: 642.9758 Fuel Consumption: 181.2181
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 11 Total reward: -3828.8866781674933 Explore P: 0.8269 SOC: 1.0000 Cumulative_SOC_deviation: 371.7180 Fuel Consumption: 111.7070
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 12 Total reward: -7924.78016497845 Explore P: 0.7929 SOC: 1.0000 Cumulative_SOC_deviation: 770.8552 Fuel Consumption: 216.2286
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 13 Total reward: -4290.671051463506 Explore P: 0.7717 SOC: 1.0000 Cumulative_SOC_deviation: 414.7483 Fuel Consumption: 143.1879
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 14 Total reward: -6443.159883680446 Explore P: 0.7452 SOC: 1.0000 Cumulative_SOC_deviation: 624.9597 Fuel Consumption: 193.5627
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 15 Total reward: -6485.377094885763 Explore P: 0.7197 SOC: 1.0000 Cumulative_SOC_deviation: 630.3360 Fuel Consumption: 182.0169
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 16 Total reward: -7434.713140891849 Explore P: 0.6919 SOC: 1.0000 Cumulative_SOC_deviation: 723.9607 Fuel Consumption: 195.1060
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 17 Total reward: -3627.3533499506893 Explore P: 0.6773 SOC: 1.0000 Cumulative_SOC_deviation: 352.3654 Fuel Consumption: 103.6995
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 18 Total reward: -3690.964856991925 Explore P: 0.6630 SOC: 1.0000 Cumulative_SOC_deviation: 357.6087 Fuel Consumption: 114.8779
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 19 Total reward: -3451.097250980742 Explore P: 0.6497 SOC: 1.0000 Cumulative_SOC_deviation: 333.4137 Fuel Consumption: 116.9603
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -653.8504975934044 SOC: 0.5156 Cumulative_SOC_deviation: 64.7117 Fuel Consumption: 6.7333
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 20 Total reward: -3609.2296463591138 Explore P: 0.6359 SOC: 1.0000 Cumulative_SOC_deviation: 349.2810 Fuel Consumption: 116.4195
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 21 Total reward: -8213.371592762558 Explore P: 0.6081 SOC: 1.0000 Cumulative_SOC_deviation: 798.3278 Fuel Consumption: 230.0933
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 22 Total reward: -11104.139429767403 Explore P: 0.5739 SOC: 1.0000 Cumulative_SOC_deviation: 1081.1941 Fuel Consumption: 292.1985
# ../data/driving_cycles/city\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 23 Total reward: -4914.985009780596 Explore P: 0.5575 SOC: 1.0000 Cumulative_SOC_deviation: 479.4789 Fuel Consumption: 120.1960
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 24 Total reward: -3544.3340192925284 Explore P: 0.5457 SOC: 1.0000 Cumulative_SOC_deviation: 344.8622 Fuel Consumption: 95.7122
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 25 Total reward: -3271.7429457261915 Explore P: 0.5345 SOC: 1.0000 Cumulative_SOC_deviation: 317.1733 Fuel Consumption: 100.0098
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 26 Total reward: -5617.7864073878445 Explore P: 0.5178 SOC: 1.0000 Cumulative_SOC_deviation: 546.7379 Fuel Consumption: 150.4074
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 27 Total reward: -9373.247546830182 Explore P: 0.4919 SOC: 1.0000 Cumulative_SOC_deviation: 910.1628 Fuel Consumption: 271.6192
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 28 Total reward: -7119.410276335128 Explore P: 0.4718 SOC: 1.0000 Cumulative_SOC_deviation: 695.2194 Fuel Consumption: 167.2162
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 29 Total reward: -6986.437769575338 Explore P: 0.4526 SOC: 1.0000 Cumulative_SOC_deviation: 682.0852 Fuel Consumption: 165.5859
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -551.3217503440917 SOC: 0.5551 Cumulative_SOC_deviation: 54.1167 Fuel Consumption: 10.1546
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 30 Total reward: -5633.568546537313 Explore P: 0.4372 SOC: 1.0000 Cumulative_SOC_deviation: 550.4315 Fuel Consumption: 129.2539
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 31 Total reward: -2754.878778827457 Explore P: 0.4257 SOC: 1.0000 Cumulative_SOC_deviation: 265.7380 Fuel Consumption: 97.4988
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 32 Total reward: -3494.9345564900673 Explore P: 0.4168 SOC: 1.0000 Cumulative_SOC_deviation: 340.9287 Fuel Consumption: 85.6474
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 33 Total reward: -6938.279286927453 Explore P: 0.3998 SOC: 1.0000 Cumulative_SOC_deviation: 678.3526 Fuel Consumption: 154.7532
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 34 Total reward: -11131.830811974796 Explore P: 0.3776 SOC: 1.0000 Cumulative_SOC_deviation: 1086.4473 Fuel Consumption: 267.3582
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 35 Total reward: -1892.9813326544365 Explore P: 0.3710 SOC: 1.0000 Cumulative_SOC_deviation: 183.6093 Fuel Consumption: 56.8883
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 36 Total reward: -8975.314035610374 Explore P: 0.3526 SOC: 1.0000 Cumulative_SOC_deviation: 877.0189 Fuel Consumption: 205.1249
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 37 Total reward: -1253.294584446924 Explore P: 0.3485 SOC: 1.0000 Cumulative_SOC_deviation: 121.1056 Fuel Consumption: 42.2387
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 38 Total reward: -8729.403948403531 Explore P: 0.3312 SOC: 1.0000 Cumulative_SOC_deviation: 853.2688 Fuel Consumption: 196.7160
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 39 Total reward: -3090.673004213888 Explore P: 0.3243 SOC: 1.0000 Cumulative_SOC_deviation: 301.9857 Fuel Consumption: 70.8161
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -99.85516468234167 SOC: 0.6071 Cumulative_SOC_deviation: 8.6483 Fuel Consumption: 13.3717
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 40 Total reward: -5360.392097013364 Explore P: 0.3134 SOC: 1.0000 Cumulative_SOC_deviation: 524.9585 Fuel Consumption: 110.8071
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 41 Total reward: -1788.8476540830384 Explore P: 0.3080 SOC: 1.0000 Cumulative_SOC_deviation: 173.6132 Fuel Consumption: 52.7158
# ../data/driving_cycles/city\VITO_MOLCity.mat
# Available condition is not avail... SOC: 1
# Episode: 42 Total reward: -1843.6764747200707 Explore P: 0.3026 SOC: 1.0000 Cumulative_SOC_deviation: 179.0985 Fuel Consumption: 52.6917
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 43 Total reward: -1153.9774627597278 Explore P: 0.2965 SOC: 0.7282 Cumulative_SOC_deviation: 109.9517 Fuel Consumption: 54.4609
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 44 Total reward: -2665.969130519352 Explore P: 0.2906 SOC: 1.0000 Cumulative_SOC_deviation: 260.1588 Fuel Consumption: 64.3810
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 45 Total reward: -1997.420342687459 Explore P: 0.2830 SOC: 1.0000 Cumulative_SOC_deviation: 190.7370 Fuel Consumption: 90.0507
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 46 Total reward: -6361.622107112544 Explore P: 0.2723 SOC: 1.0000 Cumulative_SOC_deviation: 620.9404 Fuel Consumption: 152.2177
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 47 Total reward: -1332.2406902118726 Explore P: 0.2652 SOC: 0.9312 Cumulative_SOC_deviation: 126.0154 Fuel Consumption: 72.0870
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 48 Total reward: -3115.7726319468165 Explore P: 0.2558 SOC: 1.0000 Cumulative_SOC_deviation: 300.2828 Fuel Consumption: 112.9450
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 49 Total reward: -9099.471568298964 Explore P: 0.2432 SOC: 1.0000 Cumulative_SOC_deviation: 890.2524 Fuel Consumption: 196.9473
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -1638.3255782559768 SOC: 0.8174 Cumulative_SOC_deviation: 160.9242 Fuel Consumption: 29.0832
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_MOLCity.mat
# Available condition is not avail... SOC: 0.988072326308792
# Episode: 50 Total reward: -1383.2731449849798 Explore P: 0.2390 SOC: 0.9881 Cumulative_SOC_deviation: 133.4397 Fuel Consumption: 48.8758
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 51 Total reward: -1925.0844330720397 Explore P: 0.2341 SOC: 0.9249 Cumulative_SOC_deviation: 188.8202 Fuel Consumption: 36.8827
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 52 Total reward: -2557.9367704741685 Explore P: 0.2293 SOC: 1.0000 Cumulative_SOC_deviation: 250.6007 Fuel Consumption: 51.9297
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 53 Total reward: -4047.5930759697253 Explore P: 0.2223 SOC: 1.0000 Cumulative_SOC_deviation: 396.8495 Fuel Consumption: 79.0983
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 54 Total reward: -8838.893341440664 Explore P: 0.2115 SOC: 1.0000 Cumulative_SOC_deviation: 864.0091 Fuel Consumption: 198.8022
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 55 Total reward: -831.13497272464 Explore P: 0.2072 SOC: 0.5768 Cumulative_SOC_deviation: 78.8975 Fuel Consumption: 42.1598
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 56 Total reward: -1861.1260408096882 Explore P: 0.2030 SOC: 1.0000 Cumulative_SOC_deviation: 182.0458 Fuel Consumption: 40.6684
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 57 Total reward: -666.6130843200833 Explore P: 0.1978 SOC: 0.7133 Cumulative_SOC_deviation: 61.1725 Fuel Consumption: 54.8881
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 58 Total reward: -686.9246088738272 Explore P: 0.1938 SOC: 0.6133 Cumulative_SOC_deviation: 64.1431 Fuel Consumption: 45.4940
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 59 Total reward: -4041.289098973987 Explore P: 0.1862 SOC: 1.0000 Cumulative_SOC_deviation: 393.4915 Fuel Consumption: 106.3737
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -266.64420144476327 SOC: 0.6172 Cumulative_SOC_deviation: 25.2803 Fuel Consumption: 13.8412
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 60 Total reward: -4808.765710468003 Explore P: 0.1788 SOC: 1.0000 Cumulative_SOC_deviation: 469.3218 Fuel Consumption: 115.5474
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 61 Total reward: -368.4692501129993 Explore P: 0.1768 SOC: 0.7320 Cumulative_SOC_deviation: 35.3001 Fuel Consumption: 15.4687
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 62 Total reward: -452.46652215224657 Explore P: 0.1723 SOC: 0.6882 Cumulative_SOC_deviation: 40.1269 Fuel Consumption: 51.1973
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 63 Total reward: -551.8535736066813 Explore P: 0.1675 SOC: 0.6628 Cumulative_SOC_deviation: 51.4268 Fuel Consumption: 37.5860
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 64 Total reward: -1764.3006880148512 Explore P: 0.1641 SOC: 1.0000 Cumulative_SOC_deviation: 171.7548 Fuel Consumption: 46.7532
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 65 Total reward: -523.3614355378837 Explore P: 0.1623 SOC: 0.7949 Cumulative_SOC_deviation: 50.3569 Fuel Consumption: 19.7923
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 66 Total reward: -2520.128238126974 Explore P: 0.1590 SOC: 1.0000 Cumulative_SOC_deviation: 246.8649 Fuel Consumption: 51.4793
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 67 Total reward: -1854.2850652343775 Explore P: 0.1560 SOC: 1.0000 Cumulative_SOC_deviation: 181.2907 Fuel Consumption: 41.3779
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 68 Total reward: -2054.224231338478 Explore P: 0.1530 SOC: 1.0000 Cumulative_SOC_deviation: 200.5361 Fuel Consumption: 48.8628
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 69 Total reward: -559.7860807805644 Explore P: 0.1491 SOC: 0.6558 Cumulative_SOC_deviation: 51.0457 Fuel Consumption: 49.3288
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -280.83206746787096 SOC: 0.6264 Cumulative_SOC_deviation: 26.6587 Fuel Consumption: 14.2454
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 70 Total reward: -2110.0453510838465 Explore P: 0.1461 SOC: 1.0000 Cumulative_SOC_deviation: 205.6967 Fuel Consumption: 53.0786
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 71 Total reward: -1599.927588017309 Explore P: 0.1445 SOC: 1.0000 Cumulative_SOC_deviation: 154.9187 Fuel Consumption: 50.7402
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 72 Total reward: -4423.593273578894 Explore P: 0.1392 SOC: 1.0000 Cumulative_SOC_deviation: 430.9810 Fuel Consumption: 113.7835
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 73 Total reward: -2086.786487412978 Explore P: 0.1366 SOC: 1.0000 Cumulative_SOC_deviation: 203.2437 Fuel Consumption: 54.3499
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 74 Total reward: -3419.0100905738495 Explore P: 0.1316 SOC: 1.0000 Cumulative_SOC_deviation: 333.9943 Fuel Consumption: 79.0672
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 75 Total reward: -273.322411037297 Explore P: 0.1295 SOC: 0.6394 Cumulative_SOC_deviation: 25.2910 Fuel Consumption: 20.4125
# ../data/driving_cycles/city\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# Episode: 76 Total reward: -1279.9170824393186 Explore P: 0.1260 SOC: 0.7474 Cumulative_SOC_deviation: 124.0665 Fuel Consumption: 39.2521
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 77 Total reward: -4253.785183960687 Explore P: 0.1211 SOC: 1.0000 Cumulative_SOC_deviation: 416.1509 Fuel Consumption: 92.2762
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 78 Total reward: -4412.591298229314 Explore P: 0.1165 SOC: 1.0000 Cumulative_SOC_deviation: 432.2619 Fuel Consumption: 89.9723
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 79 Total reward: -509.2061414250457 Explore P: 0.1136 SOC: 0.6497 Cumulative_SOC_deviation: 46.1033 Fuel Consumption: 48.1735
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -104.97826869171872 SOC: 0.6069 Cumulative_SOC_deviation: 9.0968 Fuel Consumption: 14.0100
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 80 Total reward: -356.16427173139857 Explore P: 0.1106 SOC: 0.6491 Cumulative_SOC_deviation: 32.8691 Fuel Consumption: 27.4732
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 81 Total reward: -971.7083977804198 Explore P: 0.1064 SOC: 0.7259 Cumulative_SOC_deviation: 92.8635 Fuel Consumption: 43.0733
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 82 Total reward: -813.4269766789077 Explore P: 0.1044 SOC: 0.7815 Cumulative_SOC_deviation: 79.0950 Fuel Consumption: 22.4774
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 83 Total reward: -551.9908967309794 Explore P: 0.1009 SOC: 0.5654 Cumulative_SOC_deviation: 48.0088 Fuel Consumption: 71.9034
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 84 Total reward: -1149.1142059612844 Explore P: 0.0989 SOC: 0.9610 Cumulative_SOC_deviation: 111.2515 Fuel Consumption: 36.5993
# ../data/driving_cycles/city\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# Episode: 85 Total reward: -312.84640973000546 Explore P: 0.0963 SOC: 0.5971 Cumulative_SOC_deviation: 28.4594 Fuel Consumption: 28.2520
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 86 Total reward: -1153.0802840863837 Explore P: 0.0946 SOC: 0.9840 Cumulative_SOC_deviation: 111.3898 Fuel Consumption: 39.1819
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 87 Total reward: -4190.1459044630965 Explore P: 0.0902 SOC: 1.0000 Cumulative_SOC_deviation: 408.5299 Fuel Consumption: 104.8465
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 88 Total reward: -4926.871573134821 Explore P: 0.0879 SOC: 1.0000 Cumulative_SOC_deviation: 477.2091 Fuel Consumption: 154.7802
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 89 Total reward: -255.18103870288192 Explore P: 0.0846 SOC: 0.6184 Cumulative_SOC_deviation: 22.0646 Fuel Consumption: 34.5351
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -124.42407038340701 SOC: 0.5951 Cumulative_SOC_deviation: 11.1591 Fuel Consumption: 12.8328
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 90 Total reward: -235.71704460276288 Explore P: 0.0825 SOC: 0.6209 Cumulative_SOC_deviation: 21.0423 Fuel Consumption: 25.2945
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 91 Total reward: -8129.922925237687 Explore P: 0.0783 SOC: 1.0000 Cumulative_SOC_deviation: 793.6496 Fuel Consumption: 193.4266
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 92 Total reward: -776.9497670902358 Explore P: 0.0769 SOC: 0.6989 Cumulative_SOC_deviation: 75.8337 Fuel Consumption: 18.6127
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 93 Total reward: -309.0975322300255 Explore P: 0.0751 SOC: 0.5972 Cumulative_SOC_deviation: 26.4069 Fuel Consumption: 45.0284
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 94 Total reward: -303.389908370895 Explore P: 0.0737 SOC: 0.6348 Cumulative_SOC_deviation: 29.0313 Fuel Consumption: 13.0769
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 95 Total reward: -430.35917293092547 Explore P: 0.0724 SOC: 0.6910 Cumulative_SOC_deviation: 41.4667 Fuel Consumption: 15.6920
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 96 Total reward: -191.392042139627 Explore P: 0.0711 SOC: 0.6134 Cumulative_SOC_deviation: 18.0312 Fuel Consumption: 11.0805
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 97 Total reward: -298.0191535490102 Explore P: 0.0698 SOC: 0.6684 Cumulative_SOC_deviation: 28.4213 Fuel Consumption: 13.8058
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 98 Total reward: -562.3088801278077 Explore P: 0.0676 SOC: 0.5640 Cumulative_SOC_deviation: 49.2625 Fuel Consumption: 69.6838
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 99 Total reward: -255.93536668208543 Explore P: 0.0665 SOC: 0.5726 Cumulative_SOC_deviation: 24.0513 Fuel Consumption: 15.4221
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -327.9939372367756 SOC: 0.5757 Cumulative_SOC_deviation: 31.6042 Fuel Consumption: 11.9523
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 100 Total reward: -542.4370806761921 Explore P: 0.0637 SOC: 0.6842 Cumulative_SOC_deviation: 50.5013 Fuel Consumption: 37.4240
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 101 Total reward: -184.211733245741 Explore P: 0.0618 SOC: 0.6187 Cumulative_SOC_deviation: 16.3491 Fuel Consumption: 20.7204
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 102 Total reward: -307.2349841110593 Explore P: 0.0596 SOC: 0.5987 Cumulative_SOC_deviation: 27.4221 Fuel Consumption: 33.0137
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 103 Total reward: -624.6980299664936 Explore P: 0.0578 SOC: 0.5815 Cumulative_SOC_deviation: 55.3142 Fuel Consumption: 71.5563
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 104 Total reward: -579.1457961263638 Explore P: 0.0565 SOC: 0.5686 Cumulative_SOC_deviation: 53.6149 Fuel Consumption: 42.9966
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 105 Total reward: -166.77312108933694 Explore P: 0.0556 SOC: 0.5897 Cumulative_SOC_deviation: 15.7224 Fuel Consumption: 9.5495
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 106 Total reward: -87.12586002473024 Explore P: 0.0546 SOC: 0.5842 Cumulative_SOC_deviation: 7.8029 Fuel Consumption: 9.0968
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 107 Total reward: -340.741564823988 Explore P: 0.0531 SOC: 0.5894 Cumulative_SOC_deviation: 32.2272 Fuel Consumption: 18.4695
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 108 Total reward: -274.43924005094726 Explore P: 0.0523 SOC: 0.5704 Cumulative_SOC_deviation: 25.9035 Fuel Consumption: 15.4044
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 109 Total reward: -72.93096580056462 Explore P: 0.0514 SOC: 0.5943 Cumulative_SOC_deviation: 6.4637 Fuel Consumption: 8.2942
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -288.55560443361475 SOC: 0.5796 Cumulative_SOC_deviation: 27.6548 Fuel Consumption: 12.0081
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 110 Total reward: -56.08692502313961 Explore P: 0.0505 SOC: 0.6093 Cumulative_SOC_deviation: 4.6568 Fuel Consumption: 9.5190
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 111 Total reward: -423.0405040086351 Explore P: 0.0493 SOC: 0.5724 Cumulative_SOC_deviation: 39.2268 Fuel Consumption: 30.7720
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 112 Total reward: -442.4407267615129 Explore P: 0.0483 SOC: 0.5825 Cumulative_SOC_deviation: 39.7841 Fuel Consumption: 44.5998
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 113 Total reward: -196.57140791634328 Explore P: 0.0470 SOC: 0.5860 Cumulative_SOC_deviation: 17.9560 Fuel Consumption: 17.0118
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 114 Total reward: -342.73821146194024 Explore P: 0.0463 SOC: 0.5907 Cumulative_SOC_deviation: 30.0434 Fuel Consumption: 42.3041
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 115 Total reward: -484.2961541664959 Explore P: 0.0447 SOC: 0.5823 Cumulative_SOC_deviation: 45.4844 Fuel Consumption: 29.4522
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 116 Total reward: -82.37604654292834 Explore P: 0.0439 SOC: 0.5912 Cumulative_SOC_deviation: 7.4229 Fuel Consumption: 8.1473
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 117 Total reward: -536.6690335876516 Explore P: 0.0430 SOC: 0.5770 Cumulative_SOC_deviation: 49.3270 Fuel Consumption: 43.3995
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 118 Total reward: -140.14849614878918 Explore P: 0.0423 SOC: 0.5810 Cumulative_SOC_deviation: 13.1370 Fuel Consumption: 8.7783
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 119 Total reward: -398.3313093012829 Explore P: 0.0416 SOC: 0.5841 Cumulative_SOC_deviation: 35.5234 Fuel Consumption: 43.0975
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -261.39003990297465 SOC: 0.5800 Cumulative_SOC_deviation: 24.9276 Fuel Consumption: 12.1143
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 120 Total reward: -132.93081556429354 Explore P: 0.0410 SOC: 0.5751 Cumulative_SOC_deviation: 12.4618 Fuel Consumption: 8.3129
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 121 Total reward: -836.7846696664905 Explore P: 0.0392 SOC: 0.6281 Cumulative_SOC_deviation: 81.5576 Fuel Consumption: 21.2089
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 122 Total reward: -153.58329306191823 Explore P: 0.0386 SOC: 0.6048 Cumulative_SOC_deviation: 14.2760 Fuel Consumption: 10.8233
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 123 Total reward: -100.01595503986627 Explore P: 0.0381 SOC: 0.5909 Cumulative_SOC_deviation: 8.3376 Fuel Consumption: 16.6401
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 124 Total reward: -556.4768515687007 Explore P: 0.0371 SOC: 0.5802 Cumulative_SOC_deviation: 48.3990 Fuel Consumption: 72.4872
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 125 Total reward: -30.463039007773954 Explore P: 0.0368 SOC: 0.6035 Cumulative_SOC_deviation: 2.4646 Fuel Consumption: 5.8173
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 126 Total reward: -33.16837640713598 Explore P: 0.0364 SOC: 0.5976 Cumulative_SOC_deviation: 2.7988 Fuel Consumption: 5.1804
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 127 Total reward: -100.06076477319073 Explore P: 0.0359 SOC: 0.5909 Cumulative_SOC_deviation: 9.0670 Fuel Consumption: 9.3907
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 128 Total reward: -247.17134211259278 Explore P: 0.0349 SOC: 0.5899 Cumulative_SOC_deviation: 22.1323 Fuel Consumption: 25.8483
# ../data/driving_cycles/city\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# Episode: 129 Total reward: -181.389297365211 Explore P: 0.0342 SOC: 0.6007 Cumulative_SOC_deviation: 15.4275 Fuel Consumption: 27.1143
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -91.51936674398283 SOC: 0.5945 Cumulative_SOC_deviation: 7.8919 Fuel Consumption: 12.6001
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 130 Total reward: -43.19960551447291 Explore P: 0.0339 SOC: 0.5977 Cumulative_SOC_deviation: 3.8289 Fuel Consumption: 4.9109
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 131 Total reward: -39.15470402167437 Explore P: 0.0334 SOC: 0.5989 Cumulative_SOC_deviation: 3.0554 Fuel Consumption: 8.6004
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 132 Total reward: -249.9129974244076 Explore P: 0.0323 SOC: 0.5915 Cumulative_SOC_deviation: 22.0084 Fuel Consumption: 29.8292
# ../data/driving_cycles/city\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# Episode: 133 Total reward: -109.74142530264564 Explore P: 0.0317 SOC: 0.6070 Cumulative_SOC_deviation: 8.1631 Fuel Consumption: 28.1105
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 134 Total reward: -254.6531823098866 Explore P: 0.0311 SOC: 0.5970 Cumulative_SOC_deviation: 20.8607 Fuel Consumption: 46.0464
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 135 Total reward: -46.23507019589176 Explore P: 0.0306 SOC: 0.5979 Cumulative_SOC_deviation: 3.7831 Fuel Consumption: 8.4045
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 136 Total reward: -26.44404503766325 Explore P: 0.0304 SOC: 0.6041 Cumulative_SOC_deviation: 2.0994 Fuel Consumption: 5.4499
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 137 Total reward: -50.666983286238825 Explore P: 0.0299 SOC: 0.6011 Cumulative_SOC_deviation: 4.1956 Fuel Consumption: 8.7107
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 138 Total reward: -314.65176091087636 Explore P: 0.0295 SOC: 0.6006 Cumulative_SOC_deviation: 27.2531 Fuel Consumption: 42.1203
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 139 Total reward: -308.65355370733016 Explore P: 0.0290 SOC: 0.5923 Cumulative_SOC_deviation: 26.4126 Fuel Consumption: 44.5276
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -180.87487167285178 SOC: 0.5913 Cumulative_SOC_deviation: 16.7960 Fuel Consumption: 12.9145
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 140 Total reward: -238.52577993184215 Explore P: 0.0284 SOC: 0.5833 Cumulative_SOC_deviation: 20.6547 Fuel Consumption: 31.9791
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 141 Total reward: -137.7012826687097 Explore P: 0.0281 SOC: 0.5929 Cumulative_SOC_deviation: 12.1107 Fuel Consumption: 16.5938
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 142 Total reward: -339.2116199768267 Explore P: 0.0274 SOC: 0.5918 Cumulative_SOC_deviation: 30.6740 Fuel Consumption: 32.4720
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 143 Total reward: -343.5733727375442 Explore P: 0.0269 SOC: 0.5925 Cumulative_SOC_deviation: 29.8764 Fuel Consumption: 44.8093
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 144 Total reward: -365.69740723634857 Explore P: 0.0265 SOC: 0.5958 Cumulative_SOC_deviation: 32.2993 Fuel Consumption: 42.7042
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 145 Total reward: -320.7081459538577 Explore P: 0.0259 SOC: 0.5987 Cumulative_SOC_deviation: 29.3966 Fuel Consumption: 26.7424
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 146 Total reward: -48.344644159772386 Explore P: 0.0257 SOC: 0.6110 Cumulative_SOC_deviation: 4.2319 Fuel Consumption: 6.0255
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 147 Total reward: -118.80147220415502 Explore P: 0.0250 SOC: 0.6017 Cumulative_SOC_deviation: 8.6317 Fuel Consumption: 32.4843
# ../data/driving_cycles/city\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 148 Total reward: -93.01161833674321 Explore P: 0.0246 SOC: 0.6080 Cumulative_SOC_deviation: 6.8745 Fuel Consumption: 24.2670
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 149 Total reward: -44.098417656570604 Explore P: 0.0243 SOC: 0.6042 Cumulative_SOC_deviation: 3.5253 Fuel Consumption: 8.8454
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -79.27185450982715 SOC: 0.5988 Cumulative_SOC_deviation: 6.6088 Fuel Consumption: 13.1839
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 150 Total reward: -151.03302520811596 Explore P: 0.0237 SOC: 0.6083 Cumulative_SOC_deviation: 11.7618 Fuel Consumption: 33.4151
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 151 Total reward: -105.7184419319869 Explore P: 0.0234 SOC: 0.6114 Cumulative_SOC_deviation: 9.5128 Fuel Consumption: 10.5906
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 152 Total reward: -347.25884007430085 Explore P: 0.0228 SOC: 0.6591 Cumulative_SOC_deviation: 31.2970 Fuel Consumption: 34.2888
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 153 Total reward: -8874.062686327625 Explore P: 0.0221 SOC: 1.0000 Cumulative_SOC_deviation: 867.1341 Fuel Consumption: 202.7214
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 154 Total reward: -125.38209201393275 Explore P: 0.0216 SOC: 0.6023 Cumulative_SOC_deviation: 9.9791 Fuel Consumption: 25.5911
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 155 Total reward: -182.49097021422054 Explore P: 0.0213 SOC: 0.6150 Cumulative_SOC_deviation: 14.9060 Fuel Consumption: 33.4312
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 156 Total reward: -276.6620434043846 Explore P: 0.0208 SOC: 0.6145 Cumulative_SOC_deviation: 24.5409 Fuel Consumption: 31.2527
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# Episode: 157 Total reward: -399.59156443789635 Explore P: 0.0202 SOC: 0.6493 Cumulative_SOC_deviation: 36.6735 Fuel Consumption: 32.8569
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 158 Total reward: -63.30447661612456 Explore P: 0.0200 SOC: 0.6100 Cumulative_SOC_deviation: 5.2762 Fuel Consumption: 10.5421
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 159 Total reward: -60.33917693961939 Explore P: 0.0198 SOC: 0.6036 Cumulative_SOC_deviation: 5.0177 Fuel Consumption: 10.1624
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -124.88787540855152 SOC: 0.6068 Cumulative_SOC_deviation: 11.1496 Fuel Consumption: 13.3921
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 160 Total reward: -85.80818107381084 Explore P: 0.0196 SOC: 0.6059 Cumulative_SOC_deviation: 7.7085 Fuel Consumption: 8.7229
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 161 Total reward: -287.8939245868203 Explore P: 0.0194 SOC: 0.7574 Cumulative_SOC_deviation: 26.7339 Fuel Consumption: 20.5545
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 162 Total reward: -7600.643660829448 Explore P: 0.0190 SOC: 1.0000 Cumulative_SOC_deviation: 738.8389 Fuel Consumption: 212.2548
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 163 Total reward: -319.4111545981954 Explore P: 0.0187 SOC: 0.6007 Cumulative_SOC_deviation: 27.6770 Fuel Consumption: 42.6414
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 164 Total reward: -71.33991484277506 Explore P: 0.0186 SOC: 0.6053 Cumulative_SOC_deviation: 6.1411 Fuel Consumption: 9.9292
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 165 Total reward: -203.3537303383367 Explore P: 0.0184 SOC: 0.6322 Cumulative_SOC_deviation: 18.9236 Fuel Consumption: 14.1177
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 166 Total reward: -221.1036366547463 Explore P: 0.0181 SOC: 0.5962 Cumulative_SOC_deviation: 17.8122 Fuel Consumption: 42.9817
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 167 Total reward: -24.737632442309412 Explore P: 0.0180 SOC: 0.5970 Cumulative_SOC_deviation: 1.9912 Fuel Consumption: 4.8252
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 168 Total reward: -47.348891147419266 Explore P: 0.0179 SOC: 0.6019 Cumulative_SOC_deviation: 3.7187 Fuel Consumption: 10.1624
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 169 Total reward: -43.0316421726294 Explore P: 0.0177 SOC: 0.5989 Cumulative_SOC_deviation: 3.4468 Fuel Consumption: 8.5637
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -96.96820906837783 SOC: 0.5949 Cumulative_SOC_deviation: 8.4054 Fuel Consumption: 12.9145
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 170 Total reward: -178.35790917443455 Explore P: 0.0174 SOC: 0.5969 Cumulative_SOC_deviation: 15.2546 Fuel Consumption: 25.8116
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 171 Total reward: -70.23360915524201 Explore P: 0.0173 SOC: 0.5967 Cumulative_SOC_deviation: 6.0451 Fuel Consumption: 9.7827
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 172 Total reward: -183.58557790457007 Explore P: 0.0168 SOC: 0.6021 Cumulative_SOC_deviation: 16.4716 Fuel Consumption: 18.8696
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 173 Total reward: -44.41664628942615 Explore P: 0.0167 SOC: 0.6194 Cumulative_SOC_deviation: 3.1573 Fuel Consumption: 12.8439
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 174 Total reward: -2731.3697181619145 Explore P: 0.0166 SOC: 1.0000 Cumulative_SOC_deviation: 263.6412 Fuel Consumption: 94.9574
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 175 Total reward: -214.98861909652746 Explore P: 0.0163 SOC: 0.6061 Cumulative_SOC_deviation: 18.2537 Fuel Consumption: 32.4516
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 176 Total reward: -324.96752578112813 Explore P: 0.0162 SOC: 0.7350 Cumulative_SOC_deviation: 27.1770 Fuel Consumption: 53.1980
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 177 Total reward: -318.9433708957808 Explore P: 0.0160 SOC: 0.7653 Cumulative_SOC_deviation: 29.7617 Fuel Consumption: 21.3261
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 178 Total reward: -377.161830662934 Explore P: 0.0158 SOC: 0.6006 Cumulative_SOC_deviation: 30.4147 Fuel Consumption: 73.0152
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 179 Total reward: -124.64427120462567 Explore P: 0.0156 SOC: 0.5928 Cumulative_SOC_deviation: 9.2861 Fuel Consumption: 31.7832
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -58.050844729628274 SOC: 0.6013 Cumulative_SOC_deviation: 4.5292 Fuel Consumption: 12.7593
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# ...
# maximum steps, simulation is done ...
# Episode: 339 Total reward: -181.17855103351084 Explore P: 0.0101 SOC: 0.6136 Cumulative_SOC_deviation: 16.2514 Fuel Consumption: 18.6641
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -167.48824785135312 SOC: 0.6148 Cumulative_SOC_deviation: 15.3084 Fuel Consumption: 14.4046
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# Episode: 340 Total reward: -132.6435534490549 Explore P: 0.0101 SOC: 0.5967 Cumulative_SOC_deviation: 10.6195 Fuel Consumption: 26.4489
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 341 Total reward: -186.96509739270996 Explore P: 0.0101 SOC: 0.6112 Cumulative_SOC_deviation: 14.3957 Fuel Consumption: 43.0076
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 342 Total reward: -109.1212733596829 Explore P: 0.0101 SOC: 0.6091 Cumulative_SOC_deviation: 10.0288 Fuel Consumption: 8.8332
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 343 Total reward: -106.99219278772061 Explore P: 0.0101 SOC: 0.6006 Cumulative_SOC_deviation: 9.6195 Fuel Consumption: 10.7972
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 344 Total reward: -147.834397160523 Explore P: 0.0101 SOC: 0.6156 Cumulative_SOC_deviation: 12.9293 Fuel Consumption: 18.5415
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 345 Total reward: -153.73275710821662 Explore P: 0.0101 SOC: 0.6149 Cumulative_SOC_deviation: 13.4885 Fuel Consumption: 18.8478
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 346 Total reward: -139.042999191086 Explore P: 0.0101 SOC: 0.6023 Cumulative_SOC_deviation: 11.3881 Fuel Consumption: 25.1624
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 347 Total reward: -90.28965996808124 Explore P: 0.0101 SOC: 0.6070 Cumulative_SOC_deviation: 8.1873 Fuel Consumption: 8.4167
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 348 Total reward: -133.74392307378588 Explore P: 0.0100 SOC: 0.5945 Cumulative_SOC_deviation: 10.8912 Fuel Consumption: 24.8317
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 349 Total reward: -161.29524641067064 Explore P: 0.0100 SOC: 0.6091 Cumulative_SOC_deviation: 14.2680 Fuel Consumption: 18.6151
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -161.90150560624213 SOC: 0.6157 Cumulative_SOC_deviation: 14.7608 Fuel Consumption: 14.2930
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 350 Total reward: -114.1393463261103 Explore P: 0.0100 SOC: 0.6120 Cumulative_SOC_deviation: 8.1279 Fuel Consumption: 32.8599
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 351 Total reward: -92.87566384919394 Explore P: 0.0100 SOC: 0.6086 Cumulative_SOC_deviation: 8.4153 Fuel Consumption: 8.7229
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 352 Total reward: -273.34604904522513 Explore P: 0.0100 SOC: 0.6072 Cumulative_SOC_deviation: 25.5028 Fuel Consumption: 18.3184
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 353 Total reward: -155.93351213133863 Explore P: 0.0100 SOC: 0.6116 Cumulative_SOC_deviation: 13.7294 Fuel Consumption: 18.6396
# ../data/driving_cycles/city\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 354 Total reward: -178.80047795704763 Explore P: 0.0100 SOC: 0.6101 Cumulative_SOC_deviation: 15.4932 Fuel Consumption: 23.8682
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 355 Total reward: -195.72759412283955 Explore P: 0.0100 SOC: 0.6045 Cumulative_SOC_deviation: 16.9867 Fuel Consumption: 25.8606
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 356 Total reward: -174.92929964785424 Explore P: 0.0100 SOC: 0.6160 Cumulative_SOC_deviation: 14.8224 Fuel Consumption: 26.7057
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 357 Total reward: -73.2555583565162 Explore P: 0.0100 SOC: 0.6056 Cumulative_SOC_deviation: 5.6513 Fuel Consumption: 16.7421
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 358 Total reward: -73.18101396753522 Explore P: 0.0100 SOC: 0.6106 Cumulative_SOC_deviation: 5.5847 Fuel Consumption: 17.3341
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 359 Total reward: -66.52779750031337 Explore P: 0.0100 SOC: 0.6092 Cumulative_SOC_deviation: 4.9474 Fuel Consumption: 17.0538
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -179.85829792152663 SOC: 0.6131 Cumulative_SOC_deviation: 16.5417 Fuel Consumption: 14.4414
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 360 Total reward: -48.8633464583877 Explore P: 0.0100 SOC: 0.6074 Cumulative_SOC_deviation: 4.3536 Fuel Consumption: 5.3274
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 361 Total reward: -58.030204445719185 Explore P: 0.0100 SOC: 0.6060 Cumulative_SOC_deviation: 4.1341 Fuel Consumption: 16.6891
# ../data/driving_cycles/city\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# Episode: 362 Total reward: -62.8471782086271 Explore P: 0.0100 SOC: 0.6072 Cumulative_SOC_deviation: 5.2832 Fuel Consumption: 10.0154
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 363 Total reward: -116.52992150393982 Explore P: 0.0100 SOC: 0.6121 Cumulative_SOC_deviation: 10.5915 Fuel Consumption: 10.6150
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 364 Total reward: -133.24283880643702 Explore P: 0.0100 SOC: 0.6043 Cumulative_SOC_deviation: 10.2117 Fuel Consumption: 31.1261
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# Episode: 365 Total reward: -115.59013103551625 Explore P: 0.0100 SOC: 0.6057 Cumulative_SOC_deviation: 8.4430 Fuel Consumption: 31.1601
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 366 Total reward: -195.21121506984514 Explore P: 0.0100 SOC: 0.6058 Cumulative_SOC_deviation: 12.5127 Fuel Consumption: 70.0839
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 367 Total reward: -68.72247688932356 Explore P: 0.0100 SOC: 0.5992 Cumulative_SOC_deviation: 5.2517 Fuel Consumption: 16.2059
# ../data/driving_cycles/city\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# Episode: 368 Total reward: -695.9362872568239 Explore P: 0.0100 SOC: 0.6110 Cumulative_SOC_deviation: 67.7471 Fuel Consumption: 18.4654
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 369 Total reward: -129.19426226364828 Explore P: 0.0100 SOC: 0.6074 Cumulative_SOC_deviation: 11.8885 Fuel Consumption: 10.3088
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -69.32756939295867 SOC: 0.6012 Cumulative_SOC_deviation: 5.4576 Fuel Consumption: 14.7517
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 370 Total reward: -180.74450547262782 Explore P: 0.0100 SOC: 0.6121 Cumulative_SOC_deviation: 15.0763 Fuel Consumption: 29.9816
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 371 Total reward: -2781.4039227463204 Explore P: 0.0100 SOC: 1.0000 Cumulative_SOC_deviation: 269.7602 Fuel Consumption: 83.8017
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 372 Total reward: -3167.097319681422 Explore P: 0.0100 SOC: 1.0000 Cumulative_SOC_deviation: 306.6550 Fuel Consumption: 100.5473
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 373 Total reward: -2545.772437271704 Explore P: 0.0100 SOC: 1.0000 Cumulative_SOC_deviation: 246.2126 Fuel Consumption: 83.6461
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 374 Total reward: -307.5720151832295 Explore P: 0.0100 SOC: 0.5998 Cumulative_SOC_deviation: 23.5984 Fuel Consumption: 71.5876
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 375 Total reward: -279.10859562722624 Explore P: 0.0100 SOC: 0.6191 Cumulative_SOC_deviation: 24.9473 Fuel Consumption: 29.6359
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 376 Total reward: -188.85616328246135 Explore P: 0.0100 SOC: 0.6215 Cumulative_SOC_deviation: 17.7629 Fuel Consumption: 11.2274
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 377 Total reward: -339.3254973084623 Explore P: 0.0100 SOC: 0.6168 Cumulative_SOC_deviation: 30.9935 Fuel Consumption: 29.3910
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 378 Total reward: -87.70564346745842 Explore P: 0.0100 SOC: 0.6206 Cumulative_SOC_deviation: 8.1447 Fuel Consumption: 6.2582
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 379 Total reward: -312.658222015531 Explore P: 0.0100 SOC: 0.6152 Cumulative_SOC_deviation: 28.3243 Fuel Consumption: 29.4155
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -106.24863996661541 SOC: 0.6116 Cumulative_SOC_deviation: 9.2661 Fuel Consumption: 13.5881
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 380 Total reward: -122.31433536046731 Explore P: 0.0100 SOC: 0.6126 Cumulative_SOC_deviation: 10.5190 Fuel Consumption: 17.1245
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 381 Total reward: -228.75956066851614 Explore P: 0.0100 SOC: 0.6123 Cumulative_SOC_deviation: 21.0878 Fuel Consumption: 17.8814
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 382 Total reward: -238.12077884320198 Explore P: 0.0100 SOC: 0.6245 Cumulative_SOC_deviation: 19.4537 Fuel Consumption: 43.5833
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 383 Total reward: -203.8111517407418 Explore P: 0.0100 SOC: 0.6206 Cumulative_SOC_deviation: 19.4010 Fuel Consumption: 9.8007
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 384 Total reward: -164.82635276408092 Explore P: 0.0100 SOC: 0.6085 Cumulative_SOC_deviation: 15.3590 Fuel Consumption: 11.2367
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 385 Total reward: -133.2235998011374 Explore P: 0.0100 SOC: 0.6067 Cumulative_SOC_deviation: 10.1189 Fuel Consumption: 32.0349
# ../data/driving_cycles/city\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# Episode: 386 Total reward: -308.711546615653 Explore P: 0.0100 SOC: 0.6145 Cumulative_SOC_deviation: 27.8858 Fuel Consumption: 29.8537
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 387 Total reward: -196.30276081818846 Explore P: 0.0100 SOC: 0.6200 Cumulative_SOC_deviation: 17.7324 Fuel Consumption: 18.9784
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 388 Total reward: -152.88454775248746 Explore P: 0.0100 SOC: 0.6105 Cumulative_SOC_deviation: 12.1235 Fuel Consumption: 31.6498
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 389 Total reward: -210.6260877458528 Explore P: 0.0100 SOC: 0.6146 Cumulative_SOC_deviation: 16.7691 Fuel Consumption: 42.9355
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -354.6753335232817 SOC: 0.6616 Cumulative_SOC_deviation: 33.7854 Fuel Consumption: 16.8216
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 390 Total reward: -1323.2223848641859 Explore P: 0.0100 SOC: 1.0000 Cumulative_SOC_deviation: 127.4327 Fuel Consumption: 48.8950
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 391 Total reward: -264.40084146049134 Explore P: 0.0100 SOC: 0.6043 Cumulative_SOC_deviation: 23.2437 Fuel Consumption: 31.9642
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 392 Total reward: -331.2356536850426 Explore P: 0.0100 SOC: 0.6015 Cumulative_SOC_deviation: 26.0236 Fuel Consumption: 70.9997
# ../data/driving_cycles/city\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 393 Total reward: -107.86584298387675 Explore P: 0.0100 SOC: 0.6068 Cumulative_SOC_deviation: 7.7159 Fuel Consumption: 30.7067
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# Episode: 394 Total reward: -230.46996168193874 Explore P: 0.0100 SOC: 0.6112 Cumulative_SOC_deviation: 21.2077 Fuel Consumption: 18.3933
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 395 Total reward: -251.8562259688185 Explore P: 0.0100 SOC: 0.6173 Cumulative_SOC_deviation: 20.8499 Fuel Consumption: 43.3574
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 396 Total reward: -229.91015829691653 Explore P: 0.0100 SOC: 0.6115 Cumulative_SOC_deviation: 20.4552 Fuel Consumption: 25.3584
# ../data/driving_cycles/city\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# Episode: 397 Total reward: -73.62225967455585 Explore P: 0.0100 SOC: 0.6092 Cumulative_SOC_deviation: 5.7233 Fuel Consumption: 16.3897
# ../data/driving_cycles/city\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# Episode: 398 Total reward: -184.7650784401953 Explore P: 0.0100 SOC: 0.6063 Cumulative_SOC_deviation: 15.9296 Fuel Consumption: 25.4686
# ../data/driving_cycles/city\ny_city_traffic.mat
# maximum steps, simulation is done ...
# Episode: 399 Total reward: -49.43089544454601 Explore P: 0.0100 SOC: 0.6103 Cumulative_SOC_deviation: 4.3895 Fuel Consumption: 5.5356
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -118.66009404693541 SOC: 0.6094 Cumulative_SOC_deviation: 10.4970 Fuel Consumption: 13.6902
# ******************* Test is done *****************
#
# model is saved..

# %%
with open("DDQN4.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)

# %%
# with open("results/replay_memory_size_effect.pkl", "rb") as f: 
#     data = pickle.load(f)
    
# data
