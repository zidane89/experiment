# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import glob
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 

from vehicle_model_DDPG1 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 10)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64):      
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple):
        index = self.buffer_counter % self.buffer_capacity 

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)

        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    inputs_batchnorm = layers.BatchNormalization()(inputs)
    
    out = layers.Dense(512, activation="relu")(inputs_batchnorm)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_input_batchnorm = layers.BatchNormalization()(state_input)
    
    state_out = layers.Dense(16, activation="relu")(state_input_batchnorm)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

critic_lr = 0.0005 
actor_lr = 0.00025 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 400
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
DELAY_TRAINING = 10000

# %%
def initialization(): 
    actor_model = get_actor() 
    critic_model = get_critic() 

    target_actor = get_actor() 
    target_critic = get_critic() 
    target_actor.set_weights(actor_model.get_weights())
    target_critic.set_weights(critic_model.get_weights())
    
    buffer = Buffer(500000, BATCH_SIZE)
    return actor_model, critic_model, target_actor, target_critic, buffer

# %%
def save_weights(actor_model, critic_model, target_actor, target_critic, root): 
    actor_model.save_weights("./{}/actor_model_checkpoint".format(root))
    critic_model.save_weights("./{}/critic_model_checkpoint".format(root))
    target_actor.save_weights("./{}/target_actor_checkpoint".format(root))
    target_critic.save_weights("./{}/target_critic_checkpoint".format(root))
    print("model is saved..")

# %%
def initialization_env(driving_path, reward_factor):
    env = Environment(cell_model, driving_path, battery_path, motor_path, reward_factor)
    return env

# %%
def test_agent(actor_model, reward_factor, test_path_start):
    test_cycles = glob.glob("../data/driving_cycles/city/*.mat")[test_path_start:]
    test_cycle = np.random.choice(test_cycles)
    env = initialization_env(test_cycle, reward_factor)
    
    total_reward = 0
    state = env.reset() 
    while True: 
        tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
        action = policy_epsilon_greedy(tf_state, -1)
        next_state, reward, done = env.step(action)
        
        state = next_state 
        total_reward += reward 
        
        if done: 
            break 
        
    SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
    
    print("******************* Test is start *****************")
    print(test_cycle)
    print('Total reward: {}'.format(total_reward), 
          "SOC: {:.4f}".format(env.SOC), 
          "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
          "Fuel Consumption: {:.4f}".format(env.fuel_consumption))
    print("******************* Test is done *****************")
    print("")

# %%
print(env.version)

num_trials = 1
results_dict = {} 
driving_cycle_paths = glob.glob("../data/driving_cycles/city/*.mat")[:1]

for trial in range(num_trials): 
    print("")
    print("Trial {}".format(trial))
    print("")
    
    actor_model, critic_model, target_actor, target_critic, buffer = initialization()
    
    eps = MAX_EPSILON 
    steps = 0
    
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    for ep in range(total_episodes): 
        driving_cycle_path = np.random.choice(driving_cycle_paths)
        print(driving_cycle_path)
        env = initialization_env(driving_cycle_path, 10)
        
        start = time.time() 
        state = env.reset() 
        episodic_reward = 0 

        while True: 
            tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
            action = policy_epsilon_greedy(tf_state, eps)
    #         print(action)
            next_state, reward, done = env.step(action)
            if done: 
                next_state = [0] * num_states 

            buffer.record((state, action, reward, next_state))
            episodic_reward += reward 

            if steps > DELAY_TRAINING: 
                buffer.learn() 
                update_target(tau)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps
                                                                        -DELAY_TRAINING))

            steps += 1

            if done: 
                break 

            state = next_state 

        elapsed_time = time.time() - start 
        print("elapsed_time: {:.3f}".format(elapsed_time))
        episode_rewards.append(episodic_reward) 
        episode_SOCs.append(env.SOC)
        episode_FCs.append(env.fuel_consumption) 

    #     print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
        SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
        print(
              'Episode: {}'.format(ep + 1),
              "Exploration P: {:.4f}".format(eps),
              'Total reward: {}'.format(episodic_reward), 
              "SOC: {:.4f}".format(env.SOC), 
              "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
              "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
        )
        print("")
        
        if (ep + 1) % 10 == 0: 
            test_agent(actor_model, 10, 1)
    
    root = "DDPG1_trial{}".format(trial+1)
    save_weights(actor_model, critic_model, target_actor, target_critic, root)
    
    results_dict[trial + 1] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs 
    }
# Out:
# 1
#
# Trial 0
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.949
# Episode: 1 Exploration P: 1.0000 Total reward: -4615.524111680618 SOC: 1.0000 Cumulative_SOC_deviation: 445.9899 Fuel Consumption: 155.6249
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.925
# Episode: 2 Exploration P: 1.0000 Total reward: -4563.9545600827005 SOC: 1.0000 Cumulative_SOC_deviation: 441.2019 Fuel Consumption: 151.9360
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.850
# Episode: 3 Exploration P: 1.0000 Total reward: -4656.04168492277 SOC: 1.0000 Cumulative_SOC_deviation: 449.6774 Fuel Consumption: 159.2679
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.917
# Episode: 4 Exploration P: 1.0000 Total reward: -4645.10001404313 SOC: 1.0000 Cumulative_SOC_deviation: 449.0144 Fuel Consumption: 154.9555
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.474
# Episode: 5 Exploration P: 1.0000 Total reward: -4657.985047787507 SOC: 1.0000 Cumulative_SOC_deviation: 450.5311 Fuel Consumption: 152.6744
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.313
# Episode: 6 Exploration P: 1.0000 Total reward: -4645.517751899938 SOC: 1.0000 Cumulative_SOC_deviation: 449.0508 Fuel Consumption: 155.0101
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 16.306
# Episode: 7 Exploration P: 1.0000 Total reward: -4668.48809286522 SOC: 1.0000 Cumulative_SOC_deviation: 451.1424 Fuel Consumption: 157.0643
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# WARNING:tensorflow:Layer batch_normalization_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 61.168
# Episode: 8 Exploration P: 0.9807 Total reward: -4644.489547155277 SOC: 1.0000 Cumulative_SOC_deviation: 449.0818 Fuel Consumption: 153.6713
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 79.148
# Episode: 9 Exploration P: 0.9544 Total reward: -4715.998764313161 SOC: 1.0000 Cumulative_SOC_deviation: 456.2606 Fuel Consumption: 153.3926
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 79.939
# Episode: 10 Exploration P: 0.9289 Total reward: -4469.891819746047 SOC: 1.0000 Cumulative_SOC_deviation: 432.4796 Fuel Consumption: 145.0954
#
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# ../data/driving_cycles/city\VITO_RW_Kangoo_DePost_Brussels_101_1.mat
# Total reward: -3834.1646647404073 SOC: 0.3629 Cumulative_SOC_deviation: 382.7844 Fuel Consumption: 6.3208
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.544
# Episode: 11 Exploration P: 0.9040 Total reward: -4495.539658855515 SOC: 1.0000 Cumulative_SOC_deviation: 435.2582 Fuel Consumption: 142.9579
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 80.064
# Episode: 12 Exploration P: 0.8797 Total reward: -4509.324590648689 SOC: 1.0000 Cumulative_SOC_deviation: 436.6289 Fuel Consumption: 143.0355
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.505
# Episode: 13 Exploration P: 0.8562 Total reward: -4375.982804705784 SOC: 1.0000 Cumulative_SOC_deviation: 423.7739 Fuel Consumption: 138.2434
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.379
# Episode: 14 Exploration P: 0.8333 Total reward: -4291.946671768168 SOC: 1.0000 Cumulative_SOC_deviation: 415.6619 Fuel Consumption: 135.3273
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.536
# Episode: 15 Exploration P: 0.8110 Total reward: -4353.723549957089 SOC: 1.0000 Cumulative_SOC_deviation: 422.2927 Fuel Consumption: 130.7966
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.988
# Episode: 16 Exploration P: 0.7893 Total reward: -4148.995259390318 SOC: 1.0000 Cumulative_SOC_deviation: 401.8704 Fuel Consumption: 130.2909
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.701
# Episode: 17 Exploration P: 0.7682 Total reward: -4001.5893863401684 SOC: 1.0000 Cumulative_SOC_deviation: 388.1374 Fuel Consumption: 120.2154
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.521
# Episode: 18 Exploration P: 0.7476 Total reward: -4047.6134712588887 SOC: 1.0000 Cumulative_SOC_deviation: 392.7479 Fuel Consumption: 120.1349
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 84.622
# Episode: 19 Exploration P: 0.7277 Total reward: -3939.8512946284222 SOC: 1.0000 Cumulative_SOC_deviation: 382.6557 Fuel Consumption: 113.2944
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 84.375
# Episode: 20 Exploration P: 0.7082 Total reward: -3831.693603242993 SOC: 1.0000 Cumulative_SOC_deviation: 371.8939 Fuel Consumption: 112.7542
#
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# ../data/driving_cycles/city\VITO_RW_Kangoo_DePost_Brussels_101_1.mat
# Total reward: -3834.1646647404073 SOC: 0.3629 Cumulative_SOC_deviation: 382.7844 Fuel Consumption: 6.3208
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 80.467
# Episode: 21 Exploration P: 0.6893 Total reward: -3475.360640030473 SOC: 1.0000 Cumulative_SOC_deviation: 336.9229 Fuel Consumption: 106.1320
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.808
# Episode: 22 Exploration P: 0.6709 Total reward: -3816.2579852358017 SOC: 1.0000 Cumulative_SOC_deviation: 370.4561 Fuel Consumption: 111.6970
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.128
# Episode: 23 Exploration P: 0.6530 Total reward: -3291.079718627817 SOC: 1.0000 Cumulative_SOC_deviation: 318.4994 Fuel Consumption: 106.0860
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.859
# Episode: 24 Exploration P: 0.6356 Total reward: -3296.7286325543337 SOC: 1.0000 Cumulative_SOC_deviation: 319.4021 Fuel Consumption: 102.7074
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.997
# Episode: 25 Exploration P: 0.6186 Total reward: -3399.5222173936954 SOC: 1.0000 Cumulative_SOC_deviation: 329.8337 Fuel Consumption: 101.1847
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 80.680
# Episode: 26 Exploration P: 0.6022 Total reward: -3146.232826726834 SOC: 1.0000 Cumulative_SOC_deviation: 304.8312 Fuel Consumption: 97.9210
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.814
# Episode: 27 Exploration P: 0.5861 Total reward: -2926.0653647211197 SOC: 1.0000 Cumulative_SOC_deviation: 283.0428 Fuel Consumption: 95.6370
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.087
# Episode: 28 Exploration P: 0.5705 Total reward: -2965.4449073899423 SOC: 1.0000 Cumulative_SOC_deviation: 286.9127 Fuel Consumption: 96.3179
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 80.058
# Episode: 29 Exploration P: 0.5553 Total reward: -2606.02588764706 SOC: 1.0000 Cumulative_SOC_deviation: 251.8129 Fuel Consumption: 87.8972
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.785
# Episode: 30 Exploration P: 0.5406 Total reward: -2600.0390256079645 SOC: 1.0000 Cumulative_SOC_deviation: 250.9545 Fuel Consumption: 90.4943
#
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# ../data/driving_cycles/city\VITO_RW_Jumper_Brussels_101_1.mat
# Total reward: -2935.5432896418984 SOC: 0.3953 Cumulative_SOC_deviation: 292.9359 Fuel Consumption: 6.1845
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.278
# Episode: 31 Exploration P: 0.5262 Total reward: -2620.3179072802877 SOC: 1.0000 Cumulative_SOC_deviation: 253.0987 Fuel Consumption: 89.3308
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 79.302
# Episode: 32 Exploration P: 0.5122 Total reward: -2707.021225013056 SOC: 1.0000 Cumulative_SOC_deviation: 261.6340 Fuel Consumption: 90.6811
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.637
# Episode: 33 Exploration P: 0.4986 Total reward: -2069.395353762554 SOC: 1.0000 Cumulative_SOC_deviation: 199.0295 Fuel Consumption: 79.1001
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 80.945
# Episode: 34 Exploration P: 0.4854 Total reward: -2093.0101536042603 SOC: 1.0000 Cumulative_SOC_deviation: 201.2080 Fuel Consumption: 80.9302
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 81.874
# Episode: 35 Exploration P: 0.4725 Total reward: -1685.472709556739 SOC: 0.9498 Cumulative_SOC_deviation: 161.0205 Fuel Consumption: 75.2675
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.266
# Episode: 36 Exploration P: 0.4600 Total reward: -1995.777643284027 SOC: 1.0000 Cumulative_SOC_deviation: 191.4500 Fuel Consumption: 81.2778
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.485
# Episode: 37 Exploration P: 0.4478 Total reward: -1315.0587988143477 SOC: 0.9076 Cumulative_SOC_deviation: 124.3362 Fuel Consumption: 71.6964
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 80.156
# Episode: 38 Exploration P: 0.4359 Total reward: -1226.431943354854 SOC: 0.8786 Cumulative_SOC_deviation: 115.6787 Fuel Consumption: 69.6451
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# elapsed_time: 82.418
# Episode: 39 Exploration P: 0.4244 Total reward: -1218.3302957294948 SOC: 0.8480 Cumulative_SOC_deviation: 115.0495 Fuel Consumption: 67.8351
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat

# %%
with open("DDPG1.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)
