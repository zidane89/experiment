# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
import glob 

from vehicle_model_DDQN1 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 1)

# %%
# STATE_SIZE = env.calculation_comp["state_size"]
STATE_SIZE = 4
ACTION_SIZE = env.calculation_comp["action_size"] 
LEARNING_RATE = 0.00025 

TOTAL_EPISODES = 400
MAX_STEPS = 50000 

GAMMA = 0.95 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
TAU = 0.001 
DELAY_TRAINING = 10000
EPSILON_MIN_ITER = 5000

# %%
primary_network = keras.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()), 
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(ACTION_SIZE),
])
target_network = keras.Sequential([
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()), 
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#     keras.layers.BatchNormalization(), 
    keras.layers.Dense(ACTION_SIZE),
])

primary_network.compile(
    loss="mse", 
    optimizer=keras.optimizers.Adam(lr=LEARNING_RATE) 
)

# for t, p in zip(target_network.trainable_variables, primary_network.trainable_variables): 
#     t.assign(p)

# %%
def update_network(primary_network, target_network): 
    for t, p in zip(target_network.trainable_variables, primary_network.trainable_variables): 
        t.assign(t * (1 - TAU) + p * TAU)

# %%
class Memory: 
    def __init__(self, max_memory): 
        self.max_memory = max_memory 
        self._samples = [] 
        
    def add_sample(self, sample): 
        self._samples.append(sample)
        if len(self._samples) > self.max_memory: 
            self._samples.pop(0)
        
    def sample(self, no_samples): 
        if no_samples > len(self._samples): 
            return random.sample(self._samples, len(self._samples))
        else: 
            return random.sample(self._samples, no_samples)
    
    @property
    def num_samples(self):
        return len(self._samples)
    

# memory = Memory(10000)

# %%
def choose_action(state, primary_network, eps): 
    if random.random() < eps: 
        return random.randint(0, ACTION_SIZE - 1)
    else: 
        return np.argmax(primary_network(np.array(state).reshape(1, -1)))

# %%
def train(primary_network, target_network, memory): 
    batch = memory.sample(BATCH_SIZE)
    states = np.array([val[0] for val in batch]) 
    actions = np.array([val[1] for val in batch])
    rewards = np.array([val[2] for val in batch])
    next_states = np.array([np.zeros(STATE_SIZE) if val[3] is None else val[3]  
                            for val in batch])
    
    prim_qt = primary_network(states)
    prim_qtp1 = primary_network(next_states)
    target_q = prim_qt.numpy() 
    updates = rewards 
    valid_idxs = next_states.sum(axis=1) != 0 
    batch_idxs = np.arange(BATCH_SIZE)
    prim_action_tp1 = np.argmax(prim_qtp1.numpy(), axis=1)
    q_from_target = target_network(next_states)
    updates[valid_idxs] += GAMMA * q_from_target.numpy()[batch_idxs[valid_idxs], 
                                                        prim_action_tp1[valid_idxs]]
    
    target_q[batch_idxs, actions] = updates 
    loss = primary_network.train_on_batch(states, target_q)
    return loss

# %%
def initialization():
    memory = Memory(10000)
    
    primary_network = keras.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=[STATE_SIZE], 
                           kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(),  
        keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(ACTION_SIZE),
    ])
    target_network = keras.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=[STATE_SIZE], 
                           kernel_initializer=keras.initializers.he_normal()), 
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.he_normal()),
#         keras.layers.BatchNormalization(), 
        keras.layers.Dense(ACTION_SIZE),
    ])
    primary_network.compile(
        loss="mse", 
        optimizer=keras.optimizers.Adam(lr=LEARNING_RATE) 
    )
    return memory, primary_network, target_network

# %%
def initialization_env(driving_path, reward_factor):
    env = Environment(cell_model, driving_path, battery_path, motor_path, reward_factor)
    return env

# %%
def save_weights(primary_net, target_net, root): 
    primary_net.save_weights("./{}/primary_net_checkpoint".format(root))
    target_net.save_weights("./{}/target_net_checkpoint".format(root))
    print("model is saved..")

# %%
def test_agent(primary_network, reward_factor, test_path_start): 
    test_cycles = glob.glob("../data/driving_cycles/city/*.mat")[test_path_start:]
    test_cycle = np.random.choice(test_cycles)
    env = initialization_env(test_cycle, reward_factor)
    
    total_reward = 0 
    state = env.reset()
    while True: 
        action = np.argmax(primary_network(np.array(state).reshape(1, -1))) 
        next_state, reward, done = env.step(action)
        
        state = next_state 
        total_reward += reward 
        
        if done: 
            break 
            
    SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
    print("******************* Test is done *****************")
    print(test_cycle)
    print('Total reward: {}'.format(total_reward), 
          "SOC: {:.4f}".format(env.SOC), 
          "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
          "Fuel Consumption: {:.4f}".format(env.fuel_consumption))
    print("******************* Test is done *****************")
    print("")
    return env.history

# %%
print("environment version: {}".format(env.version)) 

 
reward_factors = [10] 
results_dict = {} 
driving_cycle_paths = glob.glob("../data/driving_cycles/city/*.mat")[:7]

for trial, reward_factor in enumerate(reward_factors): 
    eps = MAX_EPSILON 
    steps = 0
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    episode_test_history = [] 
    episode_num_test = [] 
    
    memory, primary_network, target_network = initialization()
#     for episode in range(TOTAL_EPISODES):
    for episode in range(TOTAL_EPISODES): 
        driving_cycle_path = np.random.choice(driving_cycle_paths)
        print(driving_cycle_path)
        env = initialization_env(driving_cycle_path, reward_factor)
        state = env.reset() 

        avg_loss = 0 
        total_reward = 0
        cnt = 1 

        while True:
            action = choose_action(state, primary_network, eps)
            next_state, reward, done = env.step(action)
            total_reward += reward 
            if done: 
                next_state = None 
            memory.add_sample((state, action, reward, next_state))

            if steps > DELAY_TRAINING: 
                loss = train(primary_network, target_network, memory)
                update_network(primary_network, target_network)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps - 
                                                                        DELAY_TRAINING))
            else: 
                loss = -1

            avg_loss += loss 
            steps += 1 

            if done: 
                SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
                avg_loss /= cnt 
                print('Episode: {}'.format(episode),
                      'Total reward: {}'.format(total_reward), 
                      'Explore P: {:.4f}'.format(eps), 
                      "SOC: {:.4f}".format(env.SOC), 
                     "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
                     "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
                     )
                
                episode_rewards.append(total_reward)
                episode_SOCs.append(env.SOC)
                episode_FCs.append(env.fuel_consumption)
                break 

            state = next_state 
            cnt += 1 
        
        if (episode + 1) % 10 == 0: 
            history = test_agent(primary_network, reward_factor, -1) 
            episode_test_history.append(history) 
            episode_num_test.append(episode + 1) 
    
    root = "DDQN3_trial{}".format(trial+1)
    save_weights(primary_network, target_network, root)
    
    results_dict[reward_factor] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs, 
        "test_history": episode_test_history, 
        "test_episode_num": episode_num_test,
    }
# Out:
# environment version: 1
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 0 Total reward: -3683.1876025270276 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 356.2401 Fuel Consumption: 120.7865
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 1 Total reward: -3914.6859482135933 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 379.2191 Fuel Consumption: 122.4945
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 2 Total reward: -6571.389416275781 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 636.1257 Fuel Consumption: 210.1328
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 3 Total reward: -3635.2356359830187 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 351.5319 Fuel Consumption: 119.9169
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 4 Total reward: -3702.911651784338 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 358.7597 Fuel Consumption: 115.3150
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 5 Total reward: -3882.158212381589 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 376.5532 Fuel Consumption: 116.6266
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 6 Total reward: -3696.4436217758625 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 358.1781 Fuel Consumption: 114.6631
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 7 Total reward: -3881.251612594244 Explore P: 1.0000 SOC: 1.0000 Cumulative_SOC_deviation: 376.0200 Fuel Consumption: 121.0520
# ../data/driving_cycles/city\07_manhattan.mat
# WARNING:tensorflow:Layer dense_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# Episode: 8 Total reward: -3888.3568207819494 Explore P: 0.9920 SOC: 1.0000 Cumulative_SOC_deviation: 376.6401 Fuel Consumption: 121.9556
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 9 Total reward: -3885.525056770129 Explore P: 0.9709 SOC: 1.0000 Cumulative_SOC_deviation: 376.1256 Fuel Consumption: 124.2693
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -5317.099264704333 SOC: 1.0000 Cumulative_SOC_deviation: 517.2092 Fuel Consumption: 145.0077
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 10 Total reward: -6695.266550519684 Explore P: 0.9356 SOC: 1.0000 Cumulative_SOC_deviation: 648.8159 Fuel Consumption: 207.1076
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 11 Total reward: -3648.9989674157514 Explore P: 0.9161 SOC: 1.0000 Cumulative_SOC_deviation: 353.1436 Fuel Consumption: 117.5625
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 12 Total reward: -6532.552946785312 Explore P: 0.8828 SOC: 1.0000 Cumulative_SOC_deviation: 633.4928 Fuel Consumption: 197.6249
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 13 Total reward: -3877.439989634409 Explore P: 0.8640 SOC: 1.0000 Cumulative_SOC_deviation: 376.4606 Fuel Consumption: 112.8336
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 14 Total reward: -3513.7931557194306 Explore P: 0.8460 SOC: 1.0000 Cumulative_SOC_deviation: 340.4714 Fuel Consumption: 109.0787
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 15 Total reward: -6346.5106667437 Explore P: 0.8153 SOC: 1.0000 Cumulative_SOC_deviation: 615.6530 Fuel Consumption: 189.9808
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 16 Total reward: -6323.353735834861 Explore P: 0.7856 SOC: 1.0000 Cumulative_SOC_deviation: 614.2857 Fuel Consumption: 180.4968
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 17 Total reward: -6269.775472882093 Explore P: 0.7571 SOC: 1.0000 Cumulative_SOC_deviation: 608.6424 Fuel Consumption: 183.3519
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 18 Total reward: -3526.8837462783104 Explore P: 0.7418 SOC: 1.0000 Cumulative_SOC_deviation: 342.9190 Fuel Consumption: 97.6942
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 19 Total reward: -3725.807876362584 Explore P: 0.7261 SOC: 1.0000 Cumulative_SOC_deviation: 362.1777 Fuel Consumption: 104.0313
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -311.51671158184473 SOC: 0.6391 Cumulative_SOC_deviation: 29.4573 Fuel Consumption: 16.9440
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 20 Total reward: -6117.601539178584 Explore P: 0.6997 SOC: 1.0000 Cumulative_SOC_deviation: 594.2007 Fuel Consumption: 175.5949
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 21 Total reward: -3222.4428432301975 Explore P: 0.6852 SOC: 1.0000 Cumulative_SOC_deviation: 312.8768 Fuel Consumption: 93.6749
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 22 Total reward: -5817.497075903577 Explore P: 0.6604 SOC: 1.0000 Cumulative_SOC_deviation: 564.5963 Fuel Consumption: 171.5340
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 23 Total reward: -5653.745452322937 Explore P: 0.6364 SOC: 1.0000 Cumulative_SOC_deviation: 548.3840 Fuel Consumption: 169.9050
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 24 Total reward: -4036.2677432800147 Explore P: 0.6195 SOC: 1.0000 Cumulative_SOC_deviation: 390.5366 Fuel Consumption: 130.9018
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 25 Total reward: -5760.471213042282 Explore P: 0.5970 SOC: 1.0000 Cumulative_SOC_deviation: 559.0810 Fuel Consumption: 169.6614
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 26 Total reward: -5505.863240524399 Explore P: 0.5754 SOC: 1.0000 Cumulative_SOC_deviation: 533.4811 Fuel Consumption: 171.0522
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 27 Total reward: -3555.6388927427124 Explore P: 0.5632 SOC: 1.0000 Cumulative_SOC_deviation: 344.1811 Fuel Consumption: 113.8284
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 28 Total reward: -3083.0331583951634 Explore P: 0.5516 SOC: 1.0000 Cumulative_SOC_deviation: 298.0768 Fuel Consumption: 102.2648
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 29 Total reward: -3591.655856266043 Explore P: 0.5369 SOC: 1.0000 Cumulative_SOC_deviation: 346.6973 Fuel Consumption: 124.6826
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -2930.435137356134 SOC: 1.0000 Cumulative_SOC_deviation: 286.6157 Fuel Consumption: 64.2784
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 30 Total reward: -3543.313949531126 Explore P: 0.5257 SOC: 1.0000 Cumulative_SOC_deviation: 342.9171 Fuel Consumption: 114.1430
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 31 Total reward: -3481.83477366581 Explore P: 0.5146 SOC: 1.0000 Cumulative_SOC_deviation: 337.4587 Fuel Consumption: 107.2474
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 32 Total reward: -3223.21441535251 Explore P: 0.5043 SOC: 1.0000 Cumulative_SOC_deviation: 311.9644 Fuel Consumption: 103.5705
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 33 Total reward: -2541.727676003622 Explore P: 0.4940 SOC: 1.0000 Cumulative_SOC_deviation: 245.7925 Fuel Consumption: 83.8030
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 34 Total reward: -3425.2404284142353 Explore P: 0.4835 SOC: 1.0000 Cumulative_SOC_deviation: 333.5391 Fuel Consumption: 89.8495
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 35 Total reward: -3371.6597539489476 Explore P: 0.4734 SOC: 1.0000 Cumulative_SOC_deviation: 328.2265 Fuel Consumption: 89.3952
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 36 Total reward: -3431.4727545785095 Explore P: 0.4634 SOC: 1.0000 Cumulative_SOC_deviation: 332.9891 Fuel Consumption: 101.5817
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 37 Total reward: -2559.542143025509 Explore P: 0.4511 SOC: 1.0000 Cumulative_SOC_deviation: 245.8095 Fuel Consumption: 101.4468
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 38 Total reward: -3414.380489682375 Explore P: 0.4417 SOC: 1.0000 Cumulative_SOC_deviation: 333.0282 Fuel Consumption: 84.0987
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 39 Total reward: -3193.3796879782667 Explore P: 0.4324 SOC: 1.0000 Cumulative_SOC_deviation: 311.4630 Fuel Consumption: 78.7501
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -657.4797126768744 SOC: 0.6815 Cumulative_SOC_deviation: 63.8647 Fuel Consumption: 18.8330
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 40 Total reward: -3385.383418565409 Explore P: 0.4233 SOC: 1.0000 Cumulative_SOC_deviation: 329.5400 Fuel Consumption: 89.9831
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 41 Total reward: -3065.7855238385696 Explore P: 0.4121 SOC: 1.0000 Cumulative_SOC_deviation: 295.4392 Fuel Consumption: 111.3935
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 42 Total reward: -3354.2475807885844 Explore P: 0.4035 SOC: 1.0000 Cumulative_SOC_deviation: 326.8348 Fuel Consumption: 85.8991
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 43 Total reward: -3355.4797859915802 Explore P: 0.3955 SOC: 1.0000 Cumulative_SOC_deviation: 326.6023 Fuel Consumption: 89.4567
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 44 Total reward: -2525.228474335049 Explore P: 0.3851 SOC: 1.0000 Cumulative_SOC_deviation: 242.6796 Fuel Consumption: 98.4324
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 45 Total reward: -3935.5182946651084 Explore P: 0.3712 SOC: 0.9936 Cumulative_SOC_deviation: 380.9751 Fuel Consumption: 125.7673
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 46 Total reward: -3127.1266344987966 Explore P: 0.3635 SOC: 1.0000 Cumulative_SOC_deviation: 304.4839 Fuel Consumption: 82.2873
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 47 Total reward: -2964.759344820767 Explore P: 0.3563 SOC: 1.0000 Cumulative_SOC_deviation: 290.8695 Fuel Consumption: 56.0646
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 48 Total reward: -3215.913449516085 Explore P: 0.3488 SOC: 1.0000 Cumulative_SOC_deviation: 314.0892 Fuel Consumption: 75.0213
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 49 Total reward: -2905.962761940228 Explore P: 0.3419 SOC: 1.0000 Cumulative_SOC_deviation: 283.7123 Fuel Consumption: 68.8393
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -3031.2975251960565 SOC: 1.0000 Cumulative_SOC_deviation: 298.4394 Fuel Consumption: 46.9040
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 50 Total reward: -1982.8446700957466 Explore P: 0.3329 SOC: 1.0000 Cumulative_SOC_deviation: 190.3862 Fuel Consumption: 78.9826
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 51 Total reward: -3287.545897462763 Explore P: 0.3264 SOC: 1.0000 Cumulative_SOC_deviation: 319.7954 Fuel Consumption: 89.5915
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 52 Total reward: -3080.1190664798696 Explore P: 0.3147 SOC: 0.9986 Cumulative_SOC_deviation: 297.5863 Fuel Consumption: 104.2558
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 53 Total reward: -2793.1573364126493 Explore P: 0.3085 SOC: 1.0000 Cumulative_SOC_deviation: 273.5887 Fuel Consumption: 57.2704
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 54 Total reward: -2777.3147465011066 Explore P: 0.3021 SOC: 1.0000 Cumulative_SOC_deviation: 271.7928 Fuel Consumption: 59.3863
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 55 Total reward: -2794.7120892073367 Explore P: 0.2962 SOC: 1.0000 Cumulative_SOC_deviation: 271.5409 Fuel Consumption: 79.3031
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 56 Total reward: -3843.8518942271735 Explore P: 0.2856 SOC: 0.9999 Cumulative_SOC_deviation: 370.5690 Fuel Consumption: 138.1623
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 57 Total reward: -2381.0871910711217 Explore P: 0.2797 SOC: 1.0000 Cumulative_SOC_deviation: 230.5803 Fuel Consumption: 75.2842
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 58 Total reward: -2494.446270224344 Explore P: 0.2739 SOC: 1.0000 Cumulative_SOC_deviation: 242.8291 Fuel Consumption: 66.1551
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 59 Total reward: -3165.682624096371 Explore P: 0.2683 SOC: 1.0000 Cumulative_SOC_deviation: 307.3533 Fuel Consumption: 92.1497
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -689.2876703256661 SOC: 0.6985 Cumulative_SOC_deviation: 66.9431 Fuel Consumption: 19.8563
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 60 Total reward: -833.7002210880136 Explore P: 0.2628 SOC: 0.6282 Cumulative_SOC_deviation: 78.6453 Fuel Consumption: 47.2468
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 61 Total reward: -1433.0054102163544 Explore P: 0.2560 SOC: 0.9348 Cumulative_SOC_deviation: 135.9596 Fuel Consumption: 73.4098
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 62 Total reward: -2525.332679315647 Explore P: 0.2507 SOC: 1.0000 Cumulative_SOC_deviation: 243.2278 Fuel Consumption: 93.0544
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 63 Total reward: -2741.8906600635064 Explore P: 0.2455 SOC: 1.0000 Cumulative_SOC_deviation: 264.8089 Fuel Consumption: 93.8015
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 64 Total reward: -2362.3209155907994 Explore P: 0.2404 SOC: 1.0000 Cumulative_SOC_deviation: 228.9355 Fuel Consumption: 72.9664
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 65 Total reward: -2108.7143464097367 Explore P: 0.2357 SOC: 1.0000 Cumulative_SOC_deviation: 205.5471 Fuel Consumption: 53.2435
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 66 Total reward: -2229.327003274095 Explore P: 0.2309 SOC: 1.0000 Cumulative_SOC_deviation: 217.2403 Fuel Consumption: 56.9245
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 67 Total reward: -2920.058300353794 Explore P: 0.2264 SOC: 1.0000 Cumulative_SOC_deviation: 284.1280 Fuel Consumption: 78.7778
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 68 Total reward: -587.74129985133 Explore P: 0.2205 SOC: 0.7332 Cumulative_SOC_deviation: 53.2020 Fuel Consumption: 55.7209
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 69 Total reward: -2013.747273999441 Explore P: 0.2160 SOC: 1.0000 Cumulative_SOC_deviation: 196.6424 Fuel Consumption: 47.3231
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -373.9995429244293 SOC: 0.6490 Cumulative_SOC_deviation: 35.6855 Fuel Consumption: 17.1441
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 70 Total reward: -3001.7858706459756 Explore P: 0.2118 SOC: 1.0000 Cumulative_SOC_deviation: 290.3904 Fuel Consumption: 97.8820
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 71 Total reward: -1594.081520903483 Explore P: 0.2075 SOC: 0.7647 Cumulative_SOC_deviation: 153.7012 Fuel Consumption: 57.0697
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 72 Total reward: -2636.2430951234173 Explore P: 0.2033 SOC: 1.0000 Cumulative_SOC_deviation: 257.3756 Fuel Consumption: 62.4875
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 73 Total reward: -2075.635531025012 Explore P: 0.1993 SOC: 1.0000 Cumulative_SOC_deviation: 202.8042 Fuel Consumption: 47.5931
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 74 Total reward: -1504.8024654096644 Explore P: 0.1955 SOC: 0.9400 Cumulative_SOC_deviation: 146.8307 Fuel Consumption: 36.4951
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 75 Total reward: -1651.296708978944 Explore P: 0.1917 SOC: 0.9406 Cumulative_SOC_deviation: 161.4361 Fuel Consumption: 36.9360
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 76 Total reward: -2189.5055955875064 Explore P: 0.1879 SOC: 0.9366 Cumulative_SOC_deviation: 212.1322 Fuel Consumption: 68.1841
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 77 Total reward: -3322.3194248077098 Explore P: 0.1843 SOC: 1.0000 Cumulative_SOC_deviation: 320.7391 Fuel Consumption: 114.9285
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 78 Total reward: -910.4948462516752 Explore P: 0.1778 SOC: 0.6188 Cumulative_SOC_deviation: 83.4879 Fuel Consumption: 75.6159
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 79 Total reward: -2722.756318053231 Explore P: 0.1744 SOC: 1.0000 Cumulative_SOC_deviation: 265.7687 Fuel Consumption: 65.0696
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -1267.2674602904542 SOC: 0.8847 Cumulative_SOC_deviation: 123.4390 Fuel Consumption: 32.8773
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 80 Total reward: -1961.0007000728851 Explore P: 0.1709 SOC: 1.0000 Cumulative_SOC_deviation: 191.2058 Fuel Consumption: 48.9428
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 81 Total reward: -2201.812564493854 Explore P: 0.1674 SOC: 1.0000 Cumulative_SOC_deviation: 214.9857 Fuel Consumption: 51.9556
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 82 Total reward: -2910.583252227522 Explore P: 0.1640 SOC: 1.0000 Cumulative_SOC_deviation: 279.2377 Fuel Consumption: 118.2063
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 83 Total reward: -627.1425264855401 Explore P: 0.1584 SOC: 0.5732 Cumulative_SOC_deviation: 55.3790 Fuel Consumption: 73.3527
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 84 Total reward: -1166.518981167608 Explore P: 0.1552 SOC: 0.8357 Cumulative_SOC_deviation: 113.7128 Fuel Consumption: 29.3910
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 85 Total reward: -1318.9987223884432 Explore P: 0.1521 SOC: 1.0000 Cumulative_SOC_deviation: 127.8722 Fuel Consumption: 40.2765
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 86 Total reward: -876.7863615506401 Explore P: 0.1468 SOC: 0.5686 Cumulative_SOC_deviation: 80.4031 Fuel Consumption: 72.7553
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 87 Total reward: -1073.7814042524285 Explore P: 0.1439 SOC: 0.9384 Cumulative_SOC_deviation: 103.8480 Fuel Consumption: 35.3011
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 88 Total reward: -1171.7969664298391 Explore P: 0.1410 SOC: 0.9698 Cumulative_SOC_deviation: 113.4279 Fuel Consumption: 37.5179
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 89 Total reward: -714.9599396194865 Explore P: 0.1382 SOC: 0.5756 Cumulative_SOC_deviation: 67.1827 Fuel Consumption: 43.1328
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -476.5191486969884 SOC: 0.5634 Cumulative_SOC_deviation: 46.5136 Fuel Consumption: 11.3835
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 90 Total reward: -1101.24264445011 Explore P: 0.1335 SOC: 0.5388 Cumulative_SOC_deviation: 103.0972 Fuel Consumption: 70.2703
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 91 Total reward: -617.8417222476755 Explore P: 0.1309 SOC: 0.6751 Cumulative_SOC_deviation: 60.0160 Fuel Consumption: 17.6819
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 92 Total reward: -2169.643994045899 Explore P: 0.1284 SOC: 1.0000 Cumulative_SOC_deviation: 211.3386 Fuel Consumption: 56.2579
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 93 Total reward: -2127.25452345841 Explore P: 0.1259 SOC: 1.0000 Cumulative_SOC_deviation: 207.1442 Fuel Consumption: 55.8126
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 94 Total reward: -693.7846330210073 Explore P: 0.1235 SOC: 0.7289 Cumulative_SOC_deviation: 67.3383 Fuel Consumption: 20.4012
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 95 Total reward: -731.7645141724563 Explore P: 0.1211 SOC: 0.8309 Cumulative_SOC_deviation: 70.5760 Fuel Consumption: 26.0048
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 96 Total reward: -820.4319128880147 Explore P: 0.1187 SOC: 0.9362 Cumulative_SOC_deviation: 78.5168 Fuel Consumption: 35.2643
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 97 Total reward: -495.2889374143091 Explore P: 0.1164 SOC: 0.5944 Cumulative_SOC_deviation: 45.2768 Fuel Consumption: 42.5204
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 98 Total reward: -468.1231380470956 Explore P: 0.1141 SOC: 0.6647 Cumulative_SOC_deviation: 45.1421 Fuel Consumption: 16.7021
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 99 Total reward: -697.4381944846298 Explore P: 0.1103 SOC: 0.5607 Cumulative_SOC_deviation: 62.4981 Fuel Consumption: 72.4573
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -180.873740779494 SOC: 0.5952 Cumulative_SOC_deviation: 16.7224 Fuel Consumption: 13.6493
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 100 Total reward: -1529.7071387115855 Explore P: 0.1081 SOC: 0.9760 Cumulative_SOC_deviation: 148.9715 Fuel Consumption: 39.9923
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 101 Total reward: -869.2074898948908 Explore P: 0.1045 SOC: 0.5565 Cumulative_SOC_deviation: 79.7216 Fuel Consumption: 71.9918
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 102 Total reward: -670.3079589395383 Explore P: 0.1020 SOC: 0.5753 Cumulative_SOC_deviation: 62.5805 Fuel Consumption: 44.5031
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 103 Total reward: -1768.5108111770394 Explore P: 0.1001 SOC: 1.0000 Cumulative_SOC_deviation: 172.3422 Fuel Consumption: 45.0891
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 104 Total reward: -1079.235849685123 Explore P: 0.0968 SOC: 0.5392 Cumulative_SOC_deviation: 100.8546 Fuel Consumption: 70.6895
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 105 Total reward: -843.7800464870629 Explore P: 0.0944 SOC: 0.5503 Cumulative_SOC_deviation: 80.1837 Fuel Consumption: 41.9433
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 106 Total reward: -519.939013545523 Explore P: 0.0926 SOC: 0.6907 Cumulative_SOC_deviation: 50.3916 Fuel Consumption: 16.0227
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 107 Total reward: -415.7570575540252 Explore P: 0.0909 SOC: 0.6431 Cumulative_SOC_deviation: 40.1835 Fuel Consumption: 13.9220
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 108 Total reward: -911.86412138008 Explore P: 0.0892 SOC: 0.9155 Cumulative_SOC_deviation: 87.8939 Fuel Consumption: 32.9249
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 109 Total reward: -772.129859974294 Explore P: 0.0870 SOC: 0.5547 Cumulative_SOC_deviation: 72.9439 Fuel Consumption: 42.6904
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -487.1219108164296 SOC: 0.5576 Cumulative_SOC_deviation: 47.6302 Fuel Consumption: 10.8200
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 110 Total reward: -832.7110552208645 Explore P: 0.0854 SOC: 0.5595 Cumulative_SOC_deviation: 79.1426 Fuel Consumption: 41.2848
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 111 Total reward: -308.0180432425923 Explore P: 0.0839 SOC: 0.6269 Cumulative_SOC_deviation: 29.5419 Fuel Consumption: 12.5992
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 112 Total reward: -471.00796666014554 Explore P: 0.0823 SOC: 0.6675 Cumulative_SOC_deviation: 45.6737 Fuel Consumption: 14.2713
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 113 Total reward: -313.7303710071389 Explore P: 0.0808 SOC: 0.6205 Cumulative_SOC_deviation: 30.1633 Fuel Consumption: 12.0971
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 114 Total reward: -1148.858781604113 Explore P: 0.0793 SOC: 0.9637 Cumulative_SOC_deviation: 111.2896 Fuel Consumption: 35.9625
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 115 Total reward: -602.9693773402325 Explore P: 0.0778 SOC: 0.9104 Cumulative_SOC_deviation: 56.9346 Fuel Consumption: 33.6231
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 116 Total reward: -436.60887289963773 Explore P: 0.0764 SOC: 0.5906 Cumulative_SOC_deviation: 39.2864 Fuel Consumption: 43.7452
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 117 Total reward: -1012.8333227859871 Explore P: 0.0739 SOC: 0.5729 Cumulative_SOC_deviation: 94.0010 Fuel Consumption: 72.8233
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 118 Total reward: -184.51732448504353 Explore P: 0.0725 SOC: 0.6242 Cumulative_SOC_deviation: 17.3835 Fuel Consumption: 10.6826
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 119 Total reward: -2169.277270970932 Explore P: 0.0713 SOC: 1.0000 Cumulative_SOC_deviation: 212.3387 Fuel Consumption: 45.8906
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -84.94230403740063 SOC: 0.6010 Cumulative_SOC_deviation: 7.1097 Fuel Consumption: 13.8453
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 120 Total reward: -1074.5686475119103 Explore P: 0.0700 SOC: 0.8274 Cumulative_SOC_deviation: 104.6353 Fuel Consumption: 28.2152
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 121 Total reward: -119.01463078026751 Explore P: 0.0687 SOC: 0.6303 Cumulative_SOC_deviation: 10.7769 Fuel Consumption: 11.2460
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 122 Total reward: -230.59811323698614 Explore P: 0.0674 SOC: 0.6454 Cumulative_SOC_deviation: 21.8225 Fuel Consumption: 12.3728
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 123 Total reward: -759.9694204475464 Explore P: 0.0662 SOC: 0.7456 Cumulative_SOC_deviation: 73.7388 Fuel Consumption: 22.5811
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 124 Total reward: -105.90666154575038 Explore P: 0.0650 SOC: 0.6232 Cumulative_SOC_deviation: 9.5298 Fuel Consumption: 10.6091
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 125 Total reward: -223.50800197690666 Explore P: 0.0638 SOC: 0.6687 Cumulative_SOC_deviation: 20.9457 Fuel Consumption: 14.0508
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 126 Total reward: -469.9699158036392 Explore P: 0.0626 SOC: 0.7643 Cumulative_SOC_deviation: 44.9134 Fuel Consumption: 20.8362
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 127 Total reward: -541.9346112044556 Explore P: 0.0612 SOC: 0.6984 Cumulative_SOC_deviation: 48.8267 Fuel Consumption: 53.6674
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 128 Total reward: -211.03633084129748 Explore P: 0.0601 SOC: 0.6701 Cumulative_SOC_deviation: 19.6949 Fuel Consumption: 14.0875
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 129 Total reward: -934.0337733063923 Explore P: 0.0590 SOC: 0.8296 Cumulative_SOC_deviation: 90.6137 Fuel Consumption: 27.8967
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -114.03971873401663 SOC: 0.5993 Cumulative_SOC_deviation: 10.1031 Fuel Consumption: 13.0084
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 130 Total reward: -714.4951082507255 Explore P: 0.0580 SOC: 0.7710 Cumulative_SOC_deviation: 69.1167 Fuel Consumption: 23.3285
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 131 Total reward: -1311.3748505399285 Explore P: 0.0570 SOC: 0.8904 Cumulative_SOC_deviation: 127.9198 Fuel Consumption: 32.1767
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 132 Total reward: -314.44891043561313 Explore P: 0.0560 SOC: 0.6366 Cumulative_SOC_deviation: 30.0417 Fuel Consumption: 14.0320
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 133 Total reward: -364.999194509848 Explore P: 0.0543 SOC: 0.5939 Cumulative_SOC_deviation: 29.1324 Fuel Consumption: 73.6753
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 134 Total reward: -299.2297484096594 Explore P: 0.0533 SOC: 0.6385 Cumulative_SOC_deviation: 28.4683 Fuel Consumption: 14.5464
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 135 Total reward: -741.7480013595978 Explore P: 0.0517 SOC: 0.5767 Cumulative_SOC_deviation: 66.8955 Fuel Consumption: 72.7934
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 136 Total reward: -95.76972550854045 Explore P: 0.0508 SOC: 0.6223 Cumulative_SOC_deviation: 8.5259 Fuel Consumption: 10.5111
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 137 Total reward: -52.750170534823035 Explore P: 0.0500 SOC: 0.6028 Cumulative_SOC_deviation: 4.3893 Fuel Consumption: 8.8576
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 138 Total reward: -775.5762667846795 Explore P: 0.0485 SOC: 0.5684 Cumulative_SOC_deviation: 70.3092 Fuel Consumption: 72.4845
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 139 Total reward: -1811.6575664040474 Explore P: 0.0477 SOC: 1.0000 Cumulative_SOC_deviation: 176.4742 Fuel Consumption: 46.9154
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -281.34760620916774 SOC: 0.5808 Cumulative_SOC_deviation: 26.9003 Fuel Consumption: 12.3442
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 140 Total reward: -51.73043443765547 Explore P: 0.0469 SOC: 0.6039 Cumulative_SOC_deviation: 4.2689 Fuel Consumption: 9.0414
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 141 Total reward: -48.71632120814068 Explore P: 0.0461 SOC: 0.6043 Cumulative_SOC_deviation: 3.9565 Fuel Consumption: 9.1516
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 142 Total reward: -418.98570751886285 Explore P: 0.0453 SOC: 0.5829 Cumulative_SOC_deviation: 37.4888 Fuel Consumption: 44.0977
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 143 Total reward: -98.12546536741527 Explore P: 0.0446 SOC: 0.5788 Cumulative_SOC_deviation: 8.8123 Fuel Consumption: 10.0024
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 144 Total reward: -54.45114648631896 Explore P: 0.0438 SOC: 0.5977 Cumulative_SOC_deviation: 4.5887 Fuel Consumption: 8.5637
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 145 Total reward: -536.6206781204655 Explore P: 0.0431 SOC: 0.6539 Cumulative_SOC_deviation: 52.2417 Fuel Consumption: 14.2037
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 146 Total reward: -500.8418394700531 Explore P: 0.0425 SOC: 0.6542 Cumulative_SOC_deviation: 48.6736 Fuel Consumption: 14.1057
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 147 Total reward: -139.6342405073239 Explore P: 0.0418 SOC: 0.6096 Cumulative_SOC_deviation: 12.8321 Fuel Consumption: 11.3132
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 148 Total reward: -379.4597969383554 Explore P: 0.0411 SOC: 0.5993 Cumulative_SOC_deviation: 33.4174 Fuel Consumption: 45.2858
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 149 Total reward: -685.2530603322543 Explore P: 0.0400 SOC: 0.5826 Cumulative_SOC_deviation: 61.0199 Fuel Consumption: 75.0538
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -174.20211400148955 SOC: 0.5916 Cumulative_SOC_deviation: 16.1259 Fuel Consumption: 12.9430
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 150 Total reward: -812.7178988464143 Explore P: 0.0389 SOC: 0.5707 Cumulative_SOC_deviation: 73.9073 Fuel Consumption: 73.6453
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 151 Total reward: -1574.6536655469629 Explore P: 0.0383 SOC: 1.0000 Cumulative_SOC_deviation: 152.7201 Fuel Consumption: 47.4529
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 152 Total reward: -618.4501213449628 Explore P: 0.0375 SOC: 0.5824 Cumulative_SOC_deviation: 57.4278 Fuel Consumption: 44.1724
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 153 Total reward: -132.12847584378883 Explore P: 0.0369 SOC: 0.5872 Cumulative_SOC_deviation: 12.4434 Fuel Consumption: 7.6941
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 154 Total reward: -984.962652498416 Explore P: 0.0360 SOC: 0.5778 Cumulative_SOC_deviation: 91.1047 Fuel Consumption: 73.9161
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 155 Total reward: -571.7862397915293 Explore P: 0.0352 SOC: 0.5859 Cumulative_SOC_deviation: 52.6071 Fuel Consumption: 45.7157
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 156 Total reward: -146.1015475460339 Explore P: 0.0347 SOC: 0.5841 Cumulative_SOC_deviation: 13.8640 Fuel Consumption: 7.4614
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 157 Total reward: -668.4163041937817 Explore P: 0.0338 SOC: 0.5723 Cumulative_SOC_deviation: 59.3632 Fuel Consumption: 74.7844
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 158 Total reward: -444.6267634284337 Explore P: 0.0333 SOC: 0.5924 Cumulative_SOC_deviation: 40.0882 Fuel Consumption: 43.7452
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 159 Total reward: -477.72285444329754 Explore P: 0.0327 SOC: 0.5855 Cumulative_SOC_deviation: 43.1603 Fuel Consumption: 46.1199
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -208.51574710480932 SOC: 0.5869 Cumulative_SOC_deviation: 19.5136 Fuel Consumption: 13.3799
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 160 Total reward: -57.44759279778919 Explore P: 0.0322 SOC: 0.5964 Cumulative_SOC_deviation: 4.8994 Fuel Consumption: 8.4535
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 161 Total reward: -670.0183695025551 Explore P: 0.0314 SOC: 0.5718 Cumulative_SOC_deviation: 59.6300 Fuel Consumption: 73.7188
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 162 Total reward: -2523.5478337179875 Explore P: 0.0309 SOC: 1.0000 Cumulative_SOC_deviation: 247.0850 Fuel Consumption: 52.6975
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 163 Total reward: -91.51458864669091 Explore P: 0.0305 SOC: 0.5917 Cumulative_SOC_deviation: 8.3625 Fuel Consumption: 7.8901
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 164 Total reward: -1284.9878104343481 Explore P: 0.0300 SOC: 1.0000 Cumulative_SOC_deviation: 124.3847 Fuel Consumption: 41.1409
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 165 Total reward: -456.2813070996695 Explore P: 0.0295 SOC: 0.5962 Cumulative_SOC_deviation: 40.9229 Fuel Consumption: 47.0521
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 166 Total reward: -372.233423341577 Explore P: 0.0291 SOC: 0.5980 Cumulative_SOC_deviation: 32.7472 Fuel Consumption: 44.7618
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 167 Total reward: -1334.3520401800101 Explore P: 0.0287 SOC: 1.0000 Cumulative_SOC_deviation: 129.0246 Fuel Consumption: 44.1060
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 168 Total reward: -54.84269484383032 Explore P: 0.0283 SOC: 0.5988 Cumulative_SOC_deviation: 4.2953 Fuel Consumption: 11.8900
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 169 Total reward: -3281.6513923289735 Explore P: 0.0276 SOC: 0.8882 Cumulative_SOC_deviation: 317.9385 Fuel Consumption: 102.2661
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -120.4362278436493 SOC: 0.5967 Cumulative_SOC_deviation: 10.7248 Fuel Consumption: 13.1880
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 170 Total reward: -386.5438449256814 Explore P: 0.0269 SOC: 0.6067 Cumulative_SOC_deviation: 31.1193 Fuel Consumption: 75.3505
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 171 Total reward: -41.249922519886645 Explore P: 0.0266 SOC: 0.5961 Cumulative_SOC_deviation: 3.2931 Fuel Consumption: 8.3187
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 172 Total reward: -337.3684586105129 Explore P: 0.0262 SOC: 0.6026 Cumulative_SOC_deviation: 29.4060 Fuel Consumption: 43.3084
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 173 Total reward: -39.683253109625134 Explore P: 0.0259 SOC: 0.5987 Cumulative_SOC_deviation: 3.0936 Fuel Consumption: 8.7474
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 174 Total reward: -484.26324431723606 Explore P: 0.0253 SOC: 0.6095 Cumulative_SOC_deviation: 40.6328 Fuel Consumption: 77.9348
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 175 Total reward: -1433.6477763930206 Explore P: 0.0250 SOC: 0.9708 Cumulative_SOC_deviation: 139.5352 Fuel Consumption: 38.2955
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 176 Total reward: -36.087417185747526 Explore P: 0.0247 SOC: 0.6001 Cumulative_SOC_deviation: 2.7475 Fuel Consumption: 8.6127
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 177 Total reward: -197.8696848482171 Explore P: 0.0243 SOC: 0.6091 Cumulative_SOC_deviation: 14.9458 Fuel Consumption: 48.4116
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 178 Total reward: -1640.5414328781733 Explore P: 0.0239 SOC: 1.0000 Cumulative_SOC_deviation: 156.3841 Fuel Consumption: 76.7004
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 179 Total reward: -110.46485032228392 Explore P: 0.0236 SOC: 0.6054 Cumulative_SOC_deviation: 9.9666 Fuel Consumption: 10.7988
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -86.00791808580168 SOC: 0.6020 Cumulative_SOC_deviation: 7.1313 Fuel Consumption: 14.6945
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 180 Total reward: -55.13792389119973 Explore P: 0.0233 SOC: 0.6076 Cumulative_SOC_deviation: 4.2636 Fuel Consumption: 12.5024
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 181 Total reward: -314.97286267794374 Explore P: 0.0229 SOC: 0.6006 Cumulative_SOC_deviation: 26.8594 Fuel Consumption: 46.3784
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 182 Total reward: -312.01161868331945 Explore P: 0.0227 SOC: 0.6055 Cumulative_SOC_deviation: 26.8434 Fuel Consumption: 43.5779
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 183 Total reward: -443.32948786374646 Explore P: 0.0222 SOC: 0.5984 Cumulative_SOC_deviation: 36.8849 Fuel Consumption: 74.4809
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 184 Total reward: -273.864959397928 Explore P: 0.0219 SOC: 0.6054 Cumulative_SOC_deviation: 22.9038 Fuel Consumption: 44.8272
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 185 Total reward: -246.10063871923623 Explore P: 0.0216 SOC: 0.6055 Cumulative_SOC_deviation: 20.0114 Fuel Consumption: 45.9865
# ...
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 337 Total reward: -75.9998376536191 Explore P: 0.0102 SOC: 0.6078 Cumulative_SOC_deviation: 6.7412 Fuel Consumption: 8.5882
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 338 Total reward: -44.12733486906994 Explore P: 0.0102 SOC: 0.6052 Cumulative_SOC_deviation: 3.5686 Fuel Consumption: 8.4412
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 339 Total reward: -53.95640629084689 Explore P: 0.0102 SOC: 0.6061 Cumulative_SOC_deviation: 4.5429 Fuel Consumption: 8.5270
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -245.74859734653828 SOC: 0.6967 Cumulative_SOC_deviation: 22.6412 Fuel Consumption: 19.3365
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 340 Total reward: -161.5467309485412 Explore P: 0.0102 SOC: 0.6130 Cumulative_SOC_deviation: 9.1377 Fuel Consumption: 70.1696
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 341 Total reward: -56.08413089028341 Explore P: 0.0102 SOC: 0.6130 Cumulative_SOC_deviation: 4.4549 Fuel Consumption: 11.5348
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 342 Total reward: -136.62973557530495 Explore P: 0.0102 SOC: 0.6132 Cumulative_SOC_deviation: 9.4350 Fuel Consumption: 42.2796
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 343 Total reward: -67.81785569575209 Explore P: 0.0102 SOC: 0.6093 Cumulative_SOC_deviation: 5.7705 Fuel Consumption: 10.1129
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 344 Total reward: -60.26309249103089 Explore P: 0.0102 SOC: 0.6112 Cumulative_SOC_deviation: 4.9954 Fuel Consumption: 10.3088
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 345 Total reward: -44.67356526821404 Explore P: 0.0102 SOC: 0.6100 Cumulative_SOC_deviation: 3.3359 Fuel Consumption: 11.3143
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 346 Total reward: -107.30723471274624 Explore P: 0.0102 SOC: 0.6029 Cumulative_SOC_deviation: 6.3844 Fuel Consumption: 43.4634
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 347 Total reward: -143.0698356327752 Explore P: 0.0102 SOC: 0.6155 Cumulative_SOC_deviation: 9.9382 Fuel Consumption: 43.6881
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 348 Total reward: -42.706799222799305 Explore P: 0.0102 SOC: 0.6086 Cumulative_SOC_deviation: 3.1588 Fuel Consumption: 11.1183
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 349 Total reward: -49.64586271842633 Explore P: 0.0102 SOC: 0.6138 Cumulative_SOC_deviation: 3.7976 Fuel Consumption: 11.6695
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -964.0293674453243 SOC: 0.8416 Cumulative_SOC_deviation: 93.3939 Fuel Consumption: 30.0902
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 350 Total reward: -1044.90051608061 Explore P: 0.0102 SOC: 0.8183 Cumulative_SOC_deviation: 102.0139 Fuel Consumption: 24.7615
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 351 Total reward: -170.27925122005524 Explore P: 0.0102 SOC: 0.6141 Cumulative_SOC_deviation: 15.8046 Fuel Consumption: 12.2329
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 352 Total reward: -93.45061637104352 Explore P: 0.0102 SOC: 0.6128 Cumulative_SOC_deviation: 8.4189 Fuel Consumption: 9.2618
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 353 Total reward: -60.12252636258385 Explore P: 0.0102 SOC: 0.6152 Cumulative_SOC_deviation: 4.8355 Fuel Consumption: 11.7675
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 354 Total reward: -60.869186567373575 Explore P: 0.0102 SOC: 0.6053 Cumulative_SOC_deviation: 5.2501 Fuel Consumption: 8.3677
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 355 Total reward: -136.23935511246077 Explore P: 0.0102 SOC: 0.6043 Cumulative_SOC_deviation: 9.3107 Fuel Consumption: 43.1327
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 356 Total reward: -71.00277021916582 Explore P: 0.0102 SOC: 0.6060 Cumulative_SOC_deviation: 6.2439 Fuel Consumption: 8.5637
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 357 Total reward: -139.2827610206771 Explore P: 0.0102 SOC: 0.6135 Cumulative_SOC_deviation: 9.7334 Fuel Consumption: 41.9489
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 358 Total reward: -83.3098996178936 Explore P: 0.0101 SOC: 0.6161 Cumulative_SOC_deviation: 7.2817 Fuel Consumption: 10.4926
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 359 Total reward: -182.30950279518075 Explore P: 0.0101 SOC: 0.6075 Cumulative_SOC_deviation: 11.1834 Fuel Consumption: 70.4758
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -85.43350654708951 SOC: 0.6011 Cumulative_SOC_deviation: 7.1927 Fuel Consumption: 13.5064
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 360 Total reward: -57.295405625269424 Explore P: 0.0101 SOC: 0.5985 Cumulative_SOC_deviation: 4.9356 Fuel Consumption: 7.9390
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 361 Total reward: -66.43840610688234 Explore P: 0.0101 SOC: 0.6050 Cumulative_SOC_deviation: 5.8107 Fuel Consumption: 8.3310
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 362 Total reward: -112.089497927202 Explore P: 0.0101 SOC: 0.6101 Cumulative_SOC_deviation: 6.9577 Fuel Consumption: 42.5123
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 363 Total reward: -72.2337161358886 Explore P: 0.0101 SOC: 0.6124 Cumulative_SOC_deviation: 6.0564 Fuel Consumption: 11.6695
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 364 Total reward: -695.0273580952395 Explore P: 0.0101 SOC: 0.6940 Cumulative_SOC_deviation: 68.0303 Fuel Consumption: 14.7244
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 365 Total reward: -55.73787417855282 Explore P: 0.0101 SOC: 0.6046 Cumulative_SOC_deviation: 4.7480 Fuel Consumption: 8.2575
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 366 Total reward: -85.95328662738696 Explore P: 0.0101 SOC: 0.6110 Cumulative_SOC_deviation: 7.5485 Fuel Consumption: 10.4681
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 367 Total reward: -170.44638647235385 Explore P: 0.0101 SOC: 0.6091 Cumulative_SOC_deviation: 10.0534 Fuel Consumption: 69.9124
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 368 Total reward: -71.4395721761106 Explore P: 0.0101 SOC: 0.6160 Cumulative_SOC_deviation: 6.0910 Fuel Consumption: 10.5293
# ../data/driving_cycles/city\manhattan.mat
# maximum steps, simulation is done ...
# Episode: 369 Total reward: -60.630714229359356 Explore P: 0.0101 SOC: 0.6046 Cumulative_SOC_deviation: 5.2398 Fuel Consumption: 8.2330
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -93.61735694990186 SOC: 0.6066 Cumulative_SOC_deviation: 8.0552 Fuel Consumption: 13.0655
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 370 Total reward: -169.45609103330816 Explore P: 0.0101 SOC: 0.6028 Cumulative_SOC_deviation: 9.9678 Fuel Consumption: 69.7777
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 371 Total reward: -170.7986290488898 Explore P: 0.0101 SOC: 0.6089 Cumulative_SOC_deviation: 10.1107 Fuel Consumption: 69.6919
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 372 Total reward: -51.614638443740176 Explore P: 0.0101 SOC: 0.6012 Cumulative_SOC_deviation: 4.3602 Fuel Consumption: 8.0125
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 373 Total reward: -169.23205118747396 Explore P: 0.0101 SOC: 0.6061 Cumulative_SOC_deviation: 9.9797 Fuel Consumption: 69.4347
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 374 Total reward: -129.1511667721918 Explore P: 0.0101 SOC: 0.6045 Cumulative_SOC_deviation: 8.7753 Fuel Consumption: 41.3977
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 375 Total reward: -103.60105881084777 Explore P: 0.0101 SOC: 0.6035 Cumulative_SOC_deviation: 6.0909 Fuel Consumption: 42.6918
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 376 Total reward: -86.66097097048468 Explore P: 0.0101 SOC: 0.6070 Cumulative_SOC_deviation: 7.6524 Fuel Consumption: 10.1374
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 377 Total reward: -60.97231015843878 Explore P: 0.0101 SOC: 0.6025 Cumulative_SOC_deviation: 5.2776 Fuel Consumption: 8.1963
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 378 Total reward: -73.61526956857055 Explore P: 0.0101 SOC: 0.6016 Cumulative_SOC_deviation: 6.5370 Fuel Consumption: 8.2452
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 379 Total reward: -46.28387534927895 Explore P: 0.0101 SOC: 0.6038 Cumulative_SOC_deviation: 3.5276 Fuel Consumption: 11.0081
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -60.57370121723403 SOC: 0.6015 Cumulative_SOC_deviation: 4.7055 Fuel Consumption: 13.5187
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 380 Total reward: -124.9853308252258 Explore P: 0.0101 SOC: 0.6043 Cumulative_SOC_deviation: 8.1652 Fuel Consumption: 43.3329
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 381 Total reward: -123.7565554223428 Explore P: 0.0101 SOC: 0.6038 Cumulative_SOC_deviation: 8.1073 Fuel Consumption: 42.6838
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 382 Total reward: -178.3913244248282 Explore P: 0.0101 SOC: 0.6047 Cumulative_SOC_deviation: 10.8834 Fuel Consumption: 69.5572
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 383 Total reward: -180.2629256614121 Explore P: 0.0101 SOC: 0.6091 Cumulative_SOC_deviation: 13.6432 Fuel Consumption: 43.8309
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 384 Total reward: -175.90583480088 Explore P: 0.0101 SOC: 0.6088 Cumulative_SOC_deviation: 10.6165 Fuel Consumption: 69.7409
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 385 Total reward: -47.78211372074316 Explore P: 0.0101 SOC: 0.6102 Cumulative_SOC_deviation: 3.6407 Fuel Consumption: 11.3755
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 386 Total reward: -42.937212820854825 Explore P: 0.0101 SOC: 0.6135 Cumulative_SOC_deviation: 3.1574 Fuel Consumption: 11.3633
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 387 Total reward: -94.5177849262906 Explore P: 0.0101 SOC: 0.6131 Cumulative_SOC_deviation: 8.2995 Fuel Consumption: 11.5225
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 388 Total reward: -137.70554726675843 Explore P: 0.0101 SOC: 0.6138 Cumulative_SOC_deviation: 9.6210 Fuel Consumption: 41.4957
# ../data/driving_cycles/city\01_FTP72_fuds.mat
# maximum steps, simulation is done ...
# Episode: 389 Total reward: -105.00827011393093 Explore P: 0.0101 SOC: 0.6054 Cumulative_SOC_deviation: 6.2121 Fuel Consumption: 42.8878
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -108.00351729490369 SOC: 0.6092 Cumulative_SOC_deviation: 9.4081 Fuel Consumption: 13.9229
# ******************* Test is done *****************
#
# ../data/driving_cycles/city\07_manhattan.mat
# maximum steps, simulation is done ...
# Episode: 390 Total reward: -86.30117822233821 Explore P: 0.0101 SOC: 0.6036 Cumulative_SOC_deviation: 7.7958 Fuel Consumption: 8.3432
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 391 Total reward: -51.636147516591386 Explore P: 0.0101 SOC: 0.6074 Cumulative_SOC_deviation: 4.0150 Fuel Consumption: 11.4858
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 392 Total reward: -55.75297735362273 Explore P: 0.0101 SOC: 0.6102 Cumulative_SOC_deviation: 4.5652 Fuel Consumption: 10.1006
# ../data/driving_cycles/city\nuremberg_r36.mat
# maximum steps, simulation is done ...
# Episode: 393 Total reward: -46.885979618312234 Explore P: 0.0101 SOC: 0.6093 Cumulative_SOC_deviation: 3.5755 Fuel Consumption: 11.1306
# ../data/driving_cycles/city\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# Episode: 394 Total reward: -70.72640672119981 Explore P: 0.0101 SOC: 0.6128 Cumulative_SOC_deviation: 6.0369 Fuel Consumption: 10.3578
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 395 Total reward: -172.42882722343063 Explore P: 0.0101 SOC: 0.6097 Cumulative_SOC_deviation: 10.2161 Fuel Consumption: 70.2676
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 396 Total reward: -132.94348315988225 Explore P: 0.0101 SOC: 0.6181 Cumulative_SOC_deviation: 9.0443 Fuel Consumption: 42.5000
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 397 Total reward: -140.41185323080492 Explore P: 0.0101 SOC: 0.6171 Cumulative_SOC_deviation: 9.8181 Fuel Consumption: 42.2306
# ../data/driving_cycles/city\FTP_75_cycle.mat
# maximum steps, simulation is done ...
# Episode: 398 Total reward: -170.25857723063422 Explore P: 0.0101 SOC: 0.6118 Cumulative_SOC_deviation: 10.0469 Fuel Consumption: 69.7899
# ../data/driving_cycles/city\06_udds_truck.mat
# maximum steps, simulation is done ...
# Episode: 399 Total reward: -139.20353535376242 Explore P: 0.0101 SOC: 0.6163 Cumulative_SOC_deviation: 9.6985 Fuel Consumption: 42.2183
# maximum steps, simulation is done ...
# ******************* Test is done *****************
# ../data/driving_cycles/city\wvucity.mat
# Total reward: -189.19706249332972 SOC: 0.6154 Cumulative_SOC_deviation: 17.5323 Fuel Consumption: 13.8739
# ******************* Test is done *****************
#
# model is saved..

# %%
with open("DDQN3.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)

# %%
# with open("results/replay_memory_size_effect.pkl", "rb") as f: 
#     data = pickle.load(f)
    
# data
