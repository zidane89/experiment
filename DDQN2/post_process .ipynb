# %%
import matplotlib.pyplot as plt 
import pickle

# %%
with open("DDQN_2.pkl", "rb") as f: 
    data = pickle.load(f)
    
results = data[10]
results
# Out:
# {'rewards': [-938.5687662681216,
#   -959.3243510773347,
#   -930.4582791991589,
#   -915.3322172725034,
#   -894.5666277871862,
#   -781.5023412590368,
#   -749.7304316554681,
#   -748.3254051163468,
#   -811.4409955390141,
#   -697.5556905561887,
#   -675.3942637940477,
#   -690.2505554944588,
#   -731.801712254142,
#   -724.5155012501118,
#   -771.2644871261515,
#   -751.6008702914037,
#   -695.1885958693878,
#   -662.4784592039417,
#   -747.4062265101884,
#   -748.3662409855369,
#   -770.4913638390029,
#   -794.6526415403026,
#   -711.2198579668648,
#   -763.9665411695819,
#   -749.4484590012135,
#   -728.6556041947368,
#   -738.661665709967,
#   -713.6357816890405,
#   -606.822087184063,
#   -721.8643769396069,
#   -701.356613079308,
#   -730.1797477415518,
#   -578.5401016118549,
#   -627.2124362901703,
#   -566.1966803935202,
#   -490.3848375919651,
#   -657.954346534249,
#   -597.0335791061894,
#   -581.6693738113041,
#   -513.079629517697,
#   -470.4561001005174,
# ...

# %%
rewards = results["rewards"]
SOCs = results["SOCs"]


plt.plot(rewards, label="rewards")
plt.xlabel("episodes")
plt.ylabel("episodic rewards")
plt.grid()
plt.savefig("results.png")
