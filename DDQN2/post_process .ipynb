# %%
import matplotlib.pyplot as plt 
import pickle

# %%
with open("results_scaling_2.pkl", "rb") as f: 
    data_scale = pickle.load(f)[10]

with open("results_notScaling_2.pkl", "rb") as f: 
    data_notScale = pickle.load(f)[10]
    
# data_scale
# Out:
# {'rewards': [-4845.30442478257,
#   -4895.580807100905,
#   -4895.887529865797,
#   -4887.382052659463,
#   -4805.785618503359,
#   -4845.2845499728965,
#   -4692.451820921759,
#   -4699.1765719371715,
#   -4793.548713767003,
#   -4665.5224403705015,
#   -4555.176423722897,
#   -4751.437842973847,
#   -4822.131562876917,
#   -4757.699959772962,
#   -4766.232801831624,
#   -4756.834083060756,
#   -4699.428958972728,
#   -4785.96418631677,
#   -4707.129519765958,
#   -4626.363671846685,
#   -4675.34331398358,
#   -4720.095381517279,
#   -4737.211920811993,
#   -4660.776250283965,
#   -4705.400885222805,
#   -4758.176510138837,
#   -4541.791608052277,
#   -4554.761127394033,
#   -4403.261255811701,
#   -4129.490183232632,
#   -4379.900687485705,
#   -4394.944391814149,
#   -4439.415203499096,
#   -4346.4462658397415,
#   -3991.5038593070717,
#   -4074.6001959329374,
#   -3936.226834946168,
#   -4133.727209100721,
#   -3949.2374372754116,
#   -4289.670650241488,
#   -4013.5951745148745,
# ...

# %%
plt.figure(figsize=(14, 10))
plt.plot(data_scale["rewards"], label="Power in [kW]", linewidth=2)
plt.plot(data_notScale["rewards"], label="Power in [W]", linewidth=2)
plt.xlabel("episodes", fontsize=14)
plt.ylabel("episodic rewards", fontsize=14)
plt.legend(fontsize=14)
plt.grid()
plt.savefig("results.png")
