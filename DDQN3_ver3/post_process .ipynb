# %%
import matplotlib.pyplot as plt 
import pickle

# %%
with open("DDQN3_1.pkl", "rb") as f: 
    data1 = pickle.load(f)[10]
with open("DDQN3_2.pkl", "rb") as f: 
    data2 = pickle.load(f)[10]
with open("DDQN3_norm.pkl", "rb") as f: 
    data3 = pickle.load(f)[10]

# %%
plt.plot(data1["rewards"], label="power in kW", linewidth=2) 
plt.plot(data2["rewards"], label="power in W", linewidth=2)
plt.plot(data3["rewards"], label="power normalized", linewidth=2)


plt.xlabel("episodes", fontsize=14)
plt.ylabel("episodic rewards", fontsize=14)
plt.xlim([0, 150])
plt.legend(fontsize=14) 
plt.grid() 
# plt.ylim([-1000, -250])
plt.savefig("rewards_with_states.png")

# %%
rewards = results["rewards"]
SOCs = results["SOCs"]


plt.plot(rewards, label="rewards")
plt.xlabel("episodes")
plt.ylabel("episodic rewards")
plt.grid()
plt.savefig("results.png")
