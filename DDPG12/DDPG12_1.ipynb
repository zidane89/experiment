# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 

from vehicle_model_DDPG12_1 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_e-4wd_Battery.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_id_75_110_Westinghouse.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 10)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64): 
        self.power_mean = 0 
        self.power_std = 0
        self.sum = 0 
        self.sum_deviation = 0 
        self.N = 0 
        
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple):
        self.N += 1 
        index = self.buffer_counter % self.buffer_capacity 
        power = obs_tuple[0][0] 
        
        self.sum += power 
        self.power_mean = self.sum / self.N 
        self.sum_deviation += (power - self.power_mean) ** 2  
        self.power_std = np.sqrt(self.sum_deviation / self.N) 
            
        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)
        
        state_batch = self.state_buffer[batch_indices]
        power_batch = (state_batch[:, 0] - self.power_mean) / self.power_std
        state_batch[:, 0] = power_batch 
        
        next_state_batch = self.next_state_buffer[batch_indices]
        power_batch = (next_state_batch[:, 0] - self.power_mean) / self.power_std
        next_state_batch[:, 0] = power_batch 
#         print(state_batch)
        
        state_batch = tf.convert_to_tensor(state_batch)
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(next_state_batch)
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    out = layers.Dense(512, activation="relu")(inputs)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_out = layers.Dense(16, activation="relu")(state_input)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

critic_lr = 0.0005 
actor_lr = 0.00025 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 100
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
DELAY_TRAINING = 3000

# %%
def initialization(): 
    actor_model = get_actor() 
    critic_model = get_critic() 

    target_actor = get_actor() 
    target_critic = get_critic() 
    target_actor.set_weights(actor_model.get_weights())
    target_critic.set_weights(critic_model.get_weights())
    
    buffer = Buffer(500000, BATCH_SIZE)
    return actor_model, critic_model, target_actor, target_critic, buffer

# %%
def save_weights(actor_model, critic_model, target_actor, target_critic, root): 
    actor_model.save_weights("./{}/actor_model_checkpoint".format(root))
    critic_model.save_weights("./{}/critic_model_checkpoint".format(root))
    target_actor.save_weights("./{}/target_actor_checkpoint".format(root))
    target_critic.save_weights("./{}/target_critic_checkpoint".format(root))
    print("model is saved..")

# %%
print(env.version)

num_trials = 10
results_dict = {} 
for trial in range(num_trials): 
    print()
    print("Trial {}".format(trial))
    
    actor_model, critic_model, target_actor, target_critic, buffer = initialization()
    
    eps = MAX_EPSILON 
    steps = 0
    
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    for ep in range(total_episodes): 
        start = time.time() 
        state = env.reset() 
        episodic_reward = 0 

        while True: 
            tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
            action = policy_epsilon_greedy(tf_state, eps)
    #         print(action)
            next_state, reward, done = env.step(action)
            if done: 
                next_state = [0] * num_states 

            buffer.record((state, action, reward, next_state))
            episodic_reward += reward 

            if steps > DELAY_TRAINING: 
                buffer.learn() 
                update_target(tau)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * steps)

            steps += 1

            if done: 
                break 

            state = next_state 

        elapsed_time = time.time() - start 
        print("elapsed_time: {:.3f}".format(elapsed_time))
        episode_rewards.append(episodic_reward) 
        episode_SOCs.append(env.SOC)
        episode_FCs.append(env.fuel_consumption) 

    #     print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
        SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
        print(
              'Episode: {}'.format(ep + 1),
              "Exploration P: {:.4f}".format(eps),
              'Total reward: {}'.format(episodic_reward), 
              "SOC: {:.4f}".format(env.SOC), 
              "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
              "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
        )
    
    root = "DDPG12_1_trial{}".format(trial+1)
    save_weights(actor_model, critic_model, target_actor, target_critic, root)
    
    results_dict[trial + 1] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs 
    }
# Out:
# 1
# maximum steps, simulation is done ...
# elapsed_time: 30.328
# Episode: 1 Exploration P: 1.0000 Total reward: -979.0321351634449 SOC: 0.7952 Cumulative_SOC_deviation: 91.8397 Fuel Consumption: 60.6348
# maximum steps, simulation is done ...
# elapsed_time: 28.623
# Episode: 2 Exploration P: 1.0000 Total reward: -914.4053961903279 SOC: 0.7825 Cumulative_SOC_deviation: 85.4789 Fuel Consumption: 59.6163
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_12 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 105.529
# Episode: 3 Exploration P: 0.9217 Total reward: -862.1912032281059 SOC: 0.7756 Cumulative_SOC_deviation: 80.3070 Fuel Consumption: 59.1207
# maximum steps, simulation is done ...
# elapsed_time: 126.654
# Episode: 4 Exploration P: 0.8970 Total reward: -778.3908012979189 SOC: 0.7403 Cumulative_SOC_deviation: 72.2080 Fuel Consumption: 56.3104
# maximum steps, simulation is done ...
# elapsed_time: 126.140
# Episode: 5 Exploration P: 0.8730 Total reward: -753.5807617879627 SOC: 0.7251 Cumulative_SOC_deviation: 69.8505 Fuel Consumption: 55.0757
# maximum steps, simulation is done ...
# elapsed_time: 125.125
# Episode: 6 Exploration P: 0.8496 Total reward: -783.9848119970025 SOC: 0.6962 Cumulative_SOC_deviation: 73.1170 Fuel Consumption: 52.8151
# maximum steps, simulation is done ...
# elapsed_time: 125.744
# Episode: 7 Exploration P: 0.8269 Total reward: -789.4001206901203 SOC: 0.6665 Cumulative_SOC_deviation: 73.8887 Fuel Consumption: 50.5127
# maximum steps, simulation is done ...
# elapsed_time: 126.030
# Episode: 8 Exploration P: 0.8048 Total reward: -802.3109010620869 SOC: 0.6658 Cumulative_SOC_deviation: 75.1766 Fuel Consumption: 50.5448
# maximum steps, simulation is done ...
# elapsed_time: 124.508
# Episode: 9 Exploration P: 0.7832 Total reward: -902.7214089896873 SOC: 0.6449 Cumulative_SOC_deviation: 85.3734 Fuel Consumption: 48.9871
# maximum steps, simulation is done ...
# elapsed_time: 125.542
# Episode: 10 Exploration P: 0.7623 Total reward: -1090.366281884985 SOC: 0.6079 Cumulative_SOC_deviation: 104.4180 Fuel Consumption: 46.1861
# maximum steps, simulation is done ...
# elapsed_time: 124.566
# Episode: 11 Exploration P: 0.7419 Total reward: -955.9353635695937 SOC: 0.6347 Cumulative_SOC_deviation: 90.7572 Fuel Consumption: 48.3633
# maximum steps, simulation is done ...
# elapsed_time: 125.077
# Episode: 12 Exploration P: 0.7221 Total reward: -1122.406281289783 SOC: 0.5909 Cumulative_SOC_deviation: 107.7508 Fuel Consumption: 44.8980
# maximum steps, simulation is done ...
# elapsed_time: 125.043
# Episode: 13 Exploration P: 0.7028 Total reward: -1115.2846997423221 SOC: 0.5837 Cumulative_SOC_deviation: 107.0994 Fuel Consumption: 44.2903
# maximum steps, simulation is done ...
# elapsed_time: 125.211
# Episode: 14 Exploration P: 0.6840 Total reward: -1391.7632773218688 SOC: 0.5514 Cumulative_SOC_deviation: 135.0018 Fuel Consumption: 41.7451
# maximum steps, simulation is done ...
# elapsed_time: 125.971
# Episode: 15 Exploration P: 0.6658 Total reward: -1396.5454880152042 SOC: 0.5594 Cumulative_SOC_deviation: 135.4055 Fuel Consumption: 42.4908
# maximum steps, simulation is done ...
# elapsed_time: 124.565
# Episode: 16 Exploration P: 0.6480 Total reward: -1563.4371589603431 SOC: 0.5286 Cumulative_SOC_deviation: 152.3195 Fuel Consumption: 40.2419
# maximum steps, simulation is done ...
# elapsed_time: 125.904
# Episode: 17 Exploration P: 0.6307 Total reward: -1685.16783311837 SOC: 0.5052 Cumulative_SOC_deviation: 164.6761 Fuel Consumption: 38.4071
# maximum steps, simulation is done ...
# elapsed_time: 127.867
# Episode: 18 Exploration P: 0.6139 Total reward: -744.8053867138848 SOC: 0.7063 Cumulative_SOC_deviation: 69.1400 Fuel Consumption: 53.4053
# maximum steps, simulation is done ...
# elapsed_time: 125.677
# Episode: 19 Exploration P: 0.5976 Total reward: -619.0294791066789 SOC: 0.6906 Cumulative_SOC_deviation: 56.6902 Fuel Consumption: 52.1279
# maximum steps, simulation is done ...
# elapsed_time: 126.028
# Episode: 20 Exploration P: 0.5816 Total reward: -626.8098259502033 SOC: 0.6888 Cumulative_SOC_deviation: 57.4883 Fuel Consumption: 51.9266
# maximum steps, simulation is done ...
# elapsed_time: 124.826
# Episode: 21 Exploration P: 0.5662 Total reward: -654.5822725235056 SOC: 0.6979 Cumulative_SOC_deviation: 60.1860 Fuel Consumption: 52.7225
# maximum steps, simulation is done ...
# elapsed_time: 125.704
# Episode: 22 Exploration P: 0.5511 Total reward: -607.8911718279395 SOC: 0.6759 Cumulative_SOC_deviation: 55.6914 Fuel Consumption: 50.9773
# maximum steps, simulation is done ...
# elapsed_time: 125.903
# Episode: 23 Exploration P: 0.5364 Total reward: -575.5566255298015 SOC: 0.6739 Cumulative_SOC_deviation: 52.4597 Fuel Consumption: 50.9594
# maximum steps, simulation is done ...
# elapsed_time: 126.020
# Episode: 24 Exploration P: 0.5222 Total reward: -630.135734253247 SOC: 0.6817 Cumulative_SOC_deviation: 57.8521 Fuel Consumption: 51.6152
# maximum steps, simulation is done ...
# elapsed_time: 126.203
# Episode: 25 Exploration P: 0.5083 Total reward: -596.1959313635327 SOC: 0.6846 Cumulative_SOC_deviation: 54.4505 Fuel Consumption: 51.6906
# maximum steps, simulation is done ...
# elapsed_time: 125.550
# Episode: 26 Exploration P: 0.4948 Total reward: -526.0141765747871 SOC: 0.6635 Cumulative_SOC_deviation: 47.6075 Fuel Consumption: 49.9392
# maximum steps, simulation is done ...
# elapsed_time: 125.830
# Episode: 27 Exploration P: 0.4817 Total reward: -449.74649275687887 SOC: 0.6496 Cumulative_SOC_deviation: 40.0818 Fuel Consumption: 48.9282
# maximum steps, simulation is done ...
# elapsed_time: 126.069
# Episode: 28 Exploration P: 0.4689 Total reward: -485.2877935495941 SOC: 0.6582 Cumulative_SOC_deviation: 43.5699 Fuel Consumption: 49.5888
# maximum steps, simulation is done ...
# elapsed_time: 126.470
# Episode: 29 Exploration P: 0.4565 Total reward: -523.9127705216332 SOC: 0.6589 Cumulative_SOC_deviation: 47.4011 Fuel Consumption: 49.9013
# maximum steps, simulation is done ...
# elapsed_time: 128.266
# Episode: 30 Exploration P: 0.4444 Total reward: -499.5151826707928 SOC: 0.6665 Cumulative_SOC_deviation: 44.9243 Fuel Consumption: 50.2725
# maximum steps, simulation is done ...
# elapsed_time: 129.531
# Episode: 31 Exploration P: 0.4326 Total reward: -452.21855308875223 SOC: 0.6543 Cumulative_SOC_deviation: 40.2969 Fuel Consumption: 49.2499
# maximum steps, simulation is done ...
# elapsed_time: 127.603
# Episode: 32 Exploration P: 0.4212 Total reward: -466.3266543511347 SOC: 0.6450 Cumulative_SOC_deviation: 41.7775 Fuel Consumption: 48.5513
# maximum steps, simulation is done ...
# elapsed_time: 127.998
# Episode: 33 Exploration P: 0.4100 Total reward: -446.7225576178374 SOC: 0.6520 Cumulative_SOC_deviation: 39.7646 Fuel Consumption: 49.0768
# maximum steps, simulation is done ...
# elapsed_time: 128.208
# Episode: 34 Exploration P: 0.3992 Total reward: -478.5725003511215 SOC: 0.6587 Cumulative_SOC_deviation: 42.8996 Fuel Consumption: 49.5762
# maximum steps, simulation is done ...
# elapsed_time: 127.977
# Episode: 35 Exploration P: 0.3887 Total reward: -454.94533084461426 SOC: 0.6505 Cumulative_SOC_deviation: 40.6085 Fuel Consumption: 48.8603
# maximum steps, simulation is done ...
# elapsed_time: 128.383
# Episode: 36 Exploration P: 0.3784 Total reward: -432.4566171015077 SOC: 0.6407 Cumulative_SOC_deviation: 38.4313 Fuel Consumption: 48.1435
# maximum steps, simulation is done ...
# elapsed_time: 128.641
# Episode: 37 Exploration P: 0.3684 Total reward: -462.8929068558665 SOC: 0.6366 Cumulative_SOC_deviation: 41.4878 Fuel Consumption: 48.0152
# maximum steps, simulation is done ...
# elapsed_time: 129.167
# Episode: 38 Exploration P: 0.3587 Total reward: -562.8074381214325 SOC: 0.6324 Cumulative_SOC_deviation: 51.4450 Fuel Consumption: 48.3571
# maximum steps, simulation is done ...
# elapsed_time: 127.663
# Episode: 39 Exploration P: 0.3493 Total reward: -407.7206537044899 SOC: 0.6323 Cumulative_SOC_deviation: 36.0350 Fuel Consumption: 47.3706
# maximum steps, simulation is done ...
# elapsed_time: 128.615
# Episode: 40 Exploration P: 0.3401 Total reward: -522.9978469369453 SOC: 0.6334 Cumulative_SOC_deviation: 47.5196 Fuel Consumption: 47.8023
# maximum steps, simulation is done ...
# elapsed_time: 129.510
# Episode: 41 Exploration P: 0.3311 Total reward: -521.5300184913332 SOC: 0.6357 Cumulative_SOC_deviation: 47.3447 Fuel Consumption: 48.0830
# maximum steps, simulation is done ...
# elapsed_time: 127.510
# Episode: 42 Exploration P: 0.3224 Total reward: -425.470706628789 SOC: 0.6314 Cumulative_SOC_deviation: 37.8069 Fuel Consumption: 47.4022
# maximum steps, simulation is done ...
# elapsed_time: 128.390
# Episode: 43 Exploration P: 0.3140 Total reward: -393.79673254192505 SOC: 0.6232 Cumulative_SOC_deviation: 34.7051 Fuel Consumption: 46.7462
# maximum steps, simulation is done ...
# elapsed_time: 128.110
# Episode: 44 Exploration P: 0.3057 Total reward: -393.23169165776267 SOC: 0.6366 Cumulative_SOC_deviation: 34.5376 Fuel Consumption: 47.8562
# maximum steps, simulation is done ...
# elapsed_time: 129.529
# Episode: 45 Exploration P: 0.2977 Total reward: -489.2519953514351 SOC: 0.6311 Cumulative_SOC_deviation: 44.1355 Fuel Consumption: 47.8971
# maximum steps, simulation is done ...
# elapsed_time: 129.016
# Episode: 46 Exploration P: 0.2899 Total reward: -490.7953192693533 SOC: 0.6302 Cumulative_SOC_deviation: 44.2883 Fuel Consumption: 47.9125
# maximum steps, simulation is done ...
# elapsed_time: 129.469
# Episode: 47 Exploration P: 0.2824 Total reward: -462.37967237331964 SOC: 0.6303 Cumulative_SOC_deviation: 41.4848 Fuel Consumption: 47.5312
# maximum steps, simulation is done ...
# elapsed_time: 128.368
# Episode: 48 Exploration P: 0.2750 Total reward: -385.33845169367356 SOC: 0.6321 Cumulative_SOC_deviation: 33.7935 Fuel Consumption: 47.4037
# maximum steps, simulation is done ...
# elapsed_time: 128.298
# Episode: 49 Exploration P: 0.2678 Total reward: -593.3760519408677 SOC: 0.6309 Cumulative_SOC_deviation: 54.5251 Fuel Consumption: 48.1249
# maximum steps, simulation is done ...
# elapsed_time: 130.400
# Episode: 50 Exploration P: 0.2608 Total reward: -375.3559892028932 SOC: 0.6203 Cumulative_SOC_deviation: 32.8748 Fuel Consumption: 46.6083
# maximum steps, simulation is done ...
# elapsed_time: 128.942
# Episode: 51 Exploration P: 0.2540 Total reward: -481.6539909808532 SOC: 0.6296 Cumulative_SOC_deviation: 43.3923 Fuel Consumption: 47.7315
# maximum steps, simulation is done ...
# elapsed_time: 129.835
# Episode: 52 Exploration P: 0.2474 Total reward: -378.2114044455918 SOC: 0.6279 Cumulative_SOC_deviation: 33.1138 Fuel Consumption: 47.0733
# maximum steps, simulation is done ...
# elapsed_time: 128.639
# Episode: 53 Exploration P: 0.2410 Total reward: -427.0074316213134 SOC: 0.6248 Cumulative_SOC_deviation: 37.9967 Fuel Consumption: 47.0407
# maximum steps, simulation is done ...
# elapsed_time: 128.160
# Episode: 54 Exploration P: 0.2347 Total reward: -556.7253626985179 SOC: 0.6254 Cumulative_SOC_deviation: 50.9044 Fuel Consumption: 47.6809
# maximum steps, simulation is done ...
# elapsed_time: 128.093
# Episode: 55 Exploration P: 0.2286 Total reward: -501.9316152104035 SOC: 0.6292 Cumulative_SOC_deviation: 45.4140 Fuel Consumption: 47.7914
# maximum steps, simulation is done ...
# elapsed_time: 128.014
# Episode: 56 Exploration P: 0.2227 Total reward: -409.49792315964174 SOC: 0.6303 Cumulative_SOC_deviation: 36.2229 Fuel Consumption: 47.2686
# maximum steps, simulation is done ...
# elapsed_time: 128.760
# Episode: 57 Exploration P: 0.2170 Total reward: -588.4192962505982 SOC: 0.6259 Cumulative_SOC_deviation: 54.0456 Fuel Consumption: 47.9629
# maximum steps, simulation is done ...
# elapsed_time: 129.109
# Episode: 58 Exploration P: 0.2114 Total reward: -606.0668216400343 SOC: 0.6193 Cumulative_SOC_deviation: 55.8415 Fuel Consumption: 47.6521
# maximum steps, simulation is done ...
# elapsed_time: 129.431
# Episode: 59 Exploration P: 0.2059 Total reward: -555.3319832212056 SOC: 0.6363 Cumulative_SOC_deviation: 50.6739 Fuel Consumption: 48.5925
# maximum steps, simulation is done ...
# elapsed_time: 128.682
# Episode: 60 Exploration P: 0.2006 Total reward: -501.63940672032095 SOC: 0.6253 Cumulative_SOC_deviation: 45.3910 Fuel Consumption: 47.7291
# maximum steps, simulation is done ...
# elapsed_time: 128.672
# Episode: 61 Exploration P: 0.1954 Total reward: -406.9434556296258 SOC: 0.6256 Cumulative_SOC_deviation: 35.9880 Fuel Consumption: 47.0635
# maximum steps, simulation is done ...
# elapsed_time: 128.519
# Episode: 62 Exploration P: 0.1904 Total reward: -603.1588299939207 SOC: 0.6226 Cumulative_SOC_deviation: 55.5517 Fuel Consumption: 47.6422
# maximum steps, simulation is done ...
# elapsed_time: 130.343
# Episode: 63 Exploration P: 0.1855 Total reward: -697.2957222911779 SOC: 0.6257 Cumulative_SOC_deviation: 64.8908 Fuel Consumption: 48.3875
# maximum steps, simulation is done ...
# elapsed_time: 128.241
# Episode: 64 Exploration P: 0.1808 Total reward: -574.6551345266275 SOC: 0.6245 Cumulative_SOC_deviation: 52.6925 Fuel Consumption: 47.7301
# maximum steps, simulation is done ...
# elapsed_time: 128.971
# Episode: 65 Exploration P: 0.1761 Total reward: -599.8095795136898 SOC: 0.6263 Cumulative_SOC_deviation: 55.1827 Fuel Consumption: 47.9829
# maximum steps, simulation is done ...
# elapsed_time: 129.673
# Episode: 66 Exploration P: 0.1716 Total reward: -395.4960992397107 SOC: 0.6255 Cumulative_SOC_deviation: 34.8476 Fuel Consumption: 47.0198
# maximum steps, simulation is done ...
# elapsed_time: 128.374
# Episode: 67 Exploration P: 0.1673 Total reward: -464.7743334009832 SOC: 0.6261 Cumulative_SOC_deviation: 41.7411 Fuel Consumption: 47.3638
# maximum steps, simulation is done ...
# elapsed_time: 128.407
# Episode: 68 Exploration P: 0.1630 Total reward: -573.6889522997261 SOC: 0.6239 Cumulative_SOC_deviation: 52.6107 Fuel Consumption: 47.5819
# maximum steps, simulation is done ...
# elapsed_time: 129.526
# Episode: 69 Exploration P: 0.1589 Total reward: -348.1890317521266 SOC: 0.6234 Cumulative_SOC_deviation: 30.1682 Fuel Consumption: 46.5074
# maximum steps, simulation is done ...
# elapsed_time: 128.867
# Episode: 70 Exploration P: 0.1548 Total reward: -491.35685708900513 SOC: 0.6335 Cumulative_SOC_deviation: 44.3410 Fuel Consumption: 47.9473
# maximum steps, simulation is done ...
# elapsed_time: 128.461
# Episode: 71 Exploration P: 0.1509 Total reward: -469.2418593955377 SOC: 0.6179 Cumulative_SOC_deviation: 42.2466 Fuel Consumption: 46.7757
# maximum steps, simulation is done ...
# elapsed_time: 128.936
# Episode: 72 Exploration P: 0.1471 Total reward: -666.2758986156788 SOC: 0.6198 Cumulative_SOC_deviation: 61.8618 Fuel Consumption: 47.6582
# maximum steps, simulation is done ...
# elapsed_time: 130.002
# Episode: 73 Exploration P: 0.1434 Total reward: -436.97036770578393 SOC: 0.6217 Cumulative_SOC_deviation: 39.0131 Fuel Consumption: 46.8395
# maximum steps, simulation is done ...
# elapsed_time: 128.541
# Episode: 74 Exploration P: 0.1398 Total reward: -589.0239847559326 SOC: 0.6210 Cumulative_SOC_deviation: 54.1471 Fuel Consumption: 47.5527
# maximum steps, simulation is done ...
# elapsed_time: 131.925
# Episode: 75 Exploration P: 0.1362 Total reward: -357.4763934495629 SOC: 0.6219 Cumulative_SOC_deviation: 31.1031 Fuel Consumption: 46.4453
# maximum steps, simulation is done ...
# elapsed_time: 128.706
# Episode: 76 Exploration P: 0.1328 Total reward: -419.00502468178973 SOC: 0.6236 Cumulative_SOC_deviation: 37.2070 Fuel Consumption: 46.9351
# maximum steps, simulation is done ...
# elapsed_time: 128.819
# Episode: 77 Exploration P: 0.1295 Total reward: -669.79403407526 SOC: 0.6217 Cumulative_SOC_deviation: 62.1697 Fuel Consumption: 48.0969
# maximum steps, simulation is done ...
# elapsed_time: 128.808
# Episode: 78 Exploration P: 0.1263 Total reward: -648.7257940792424 SOC: 0.6244 Cumulative_SOC_deviation: 60.0706 Fuel Consumption: 48.0197
# maximum steps, simulation is done ...
# elapsed_time: 129.173
# Episode: 79 Exploration P: 0.1231 Total reward: -478.0999671397125 SOC: 0.6158 Cumulative_SOC_deviation: 43.1238 Fuel Consumption: 46.8617
# maximum steps, simulation is done ...
# elapsed_time: 129.554
# Episode: 80 Exploration P: 0.1200 Total reward: -642.7260857079494 SOC: 0.6211 Cumulative_SOC_deviation: 59.4539 Fuel Consumption: 48.1870
# maximum steps, simulation is done ...
# elapsed_time: 128.917
# Episode: 81 Exploration P: 0.1171 Total reward: -687.932246396603 SOC: 0.6242 Cumulative_SOC_deviation: 63.9478 Fuel Consumption: 48.4544
# maximum steps, simulation is done ...
# elapsed_time: 128.578
# Episode: 82 Exploration P: 0.1142 Total reward: -629.3808213370479 SOC: 0.6171 Cumulative_SOC_deviation: 58.1611 Fuel Consumption: 47.7694
# maximum steps, simulation is done ...
# elapsed_time: 128.986
# Episode: 83 Exploration P: 0.1113 Total reward: -503.8896498302929 SOC: 0.6237 Cumulative_SOC_deviation: 45.6413 Fuel Consumption: 47.4763
# maximum steps, simulation is done ...
# elapsed_time: 128.484
# Episode: 84 Exploration P: 0.1086 Total reward: -543.6324151399695 SOC: 0.6202 Cumulative_SOC_deviation: 49.6084 Fuel Consumption: 47.5488
# maximum steps, simulation is done ...
# elapsed_time: 129.133
# Episode: 85 Exploration P: 0.1059 Total reward: -620.8284869189307 SOC: 0.6210 Cumulative_SOC_deviation: 57.2895 Fuel Consumption: 47.9336
# maximum steps, simulation is done ...
# elapsed_time: 129.457
# Episode: 86 Exploration P: 0.1033 Total reward: -722.779597148804 SOC: 0.6248 Cumulative_SOC_deviation: 67.4541 Fuel Consumption: 48.2389
# maximum steps, simulation is done ...
# elapsed_time: 130.488
# Episode: 87 Exploration P: 0.1008 Total reward: -387.8128382453268 SOC: 0.6238 Cumulative_SOC_deviation: 34.1049 Fuel Consumption: 46.7641
# maximum steps, simulation is done ...
# elapsed_time: 128.622
# Episode: 88 Exploration P: 0.0983 Total reward: -419.15167599494924 SOC: 0.6228 Cumulative_SOC_deviation: 37.2151 Fuel Consumption: 47.0008
# maximum steps, simulation is done ...
# elapsed_time: 129.681
# Episode: 89 Exploration P: 0.0960 Total reward: -621.7845243695465 SOC: 0.6194 Cumulative_SOC_deviation: 57.3942 Fuel Consumption: 47.8426
# maximum steps, simulation is done ...
# elapsed_time: 128.841
# Episode: 90 Exploration P: 0.0936 Total reward: -606.1537475886995 SOC: 0.6205 Cumulative_SOC_deviation: 55.8418 Fuel Consumption: 47.7357
# maximum steps, simulation is done ...
# elapsed_time: 115.244
# Episode: 91 Exploration P: 0.0914 Total reward: -587.6493242240992 SOC: 0.6232 Cumulative_SOC_deviation: 53.9801 Fuel Consumption: 47.8488
# maximum steps, simulation is done ...
# elapsed_time: 131.682
# Episode: 92 Exploration P: 0.0892 Total reward: -429.62878745708355 SOC: 0.6241 Cumulative_SOC_deviation: 38.2641 Fuel Consumption: 46.9874
# maximum steps, simulation is done ...
# elapsed_time: 130.620
# Episode: 93 Exploration P: 0.0870 Total reward: -357.9698402976791 SOC: 0.6260 Cumulative_SOC_deviation: 31.1031 Fuel Consumption: 46.9384
# maximum steps, simulation is done ...
# elapsed_time: 130.812
# Episode: 94 Exploration P: 0.0849 Total reward: -349.62466090640805 SOC: 0.6179 Cumulative_SOC_deviation: 30.3333 Fuel Consumption: 46.2917
# maximum steps, simulation is done ...
# elapsed_time: 115.892
# Episode: 95 Exploration P: 0.0829 Total reward: -439.4624407624512 SOC: 0.6264 Cumulative_SOC_deviation: 39.2042 Fuel Consumption: 47.4205
# maximum steps, simulation is done ...
# elapsed_time: 130.430
# Episode: 96 Exploration P: 0.0809 Total reward: -338.0098629590548 SOC: 0.6253 Cumulative_SOC_deviation: 29.1531 Fuel Consumption: 46.4786
# maximum steps, simulation is done ...
# elapsed_time: 129.763
# Episode: 97 Exploration P: 0.0790 Total reward: -344.90243356210567 SOC: 0.6234 Cumulative_SOC_deviation: 29.8509 Fuel Consumption: 46.3937
# maximum steps, simulation is done ...
# elapsed_time: 131.361
# Episode: 98 Exploration P: 0.0771 Total reward: -367.03824411599425 SOC: 0.6257 Cumulative_SOC_deviation: 32.0530 Fuel Consumption: 46.5079
# maximum steps, simulation is done ...
# elapsed_time: 129.641
# Episode: 99 Exploration P: 0.0753 Total reward: -338.20369231881295 SOC: 0.6281 Cumulative_SOC_deviation: 29.1169 Fuel Consumption: 47.0342
# maximum steps, simulation is done ...
# elapsed_time: 130.220
# Episode: 100 Exploration P: 0.0735 Total reward: -326.51625564211173 SOC: 0.6246 Cumulative_SOC_deviation: 28.0112 Fuel Consumption: 46.4044
# maximum steps, simulation is done ...
# elapsed_time: 28.631
# Episode: 1 Exploration P: 1.0000 Total reward: -878.2028597891875 SOC: 0.7798 Cumulative_SOC_deviation: 81.8806 Fuel Consumption: 59.3969
# maximum steps, simulation is done ...
# elapsed_time: 28.614
# Episode: 2 Exploration P: 1.0000 Total reward: -996.8895755473397 SOC: 0.8112 Cumulative_SOC_deviation: 93.4938 Fuel Consumption: 61.9518
# WARNING:tensorflow:Layer dense_27 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_30 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer dense_21 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_18 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 110.000
# Episode: 3 Exploration P: 0.9217 Total reward: -817.8467266499229 SOC: 0.7678 Cumulative_SOC_deviation: 75.9327 Fuel Consumption: 58.5199
# maximum steps, simulation is done ...
# elapsed_time: 127.102
# Episode: 4 Exploration P: 0.8970 Total reward: -772.4927750342309 SOC: 0.7217 Cumulative_SOC_deviation: 71.7682 Fuel Consumption: 54.8104
# maximum steps, simulation is done ...
# elapsed_time: 132.708
# Episode: 5 Exploration P: 0.8730 Total reward: -766.6836619599931 SOC: 0.6987 Cumulative_SOC_deviation: 71.3671 Fuel Consumption: 53.0130
# maximum steps, simulation is done ...
# elapsed_time: 126.782
# Episode: 6 Exploration P: 0.8496 Total reward: -780.5366727411954 SOC: 0.6899 Cumulative_SOC_deviation: 72.8028 Fuel Consumption: 52.5091
# maximum steps, simulation is done ...
# elapsed_time: 125.622
# Episode: 7 Exploration P: 0.8269 Total reward: -772.1620011421368 SOC: 0.7055 Cumulative_SOC_deviation: 71.8440 Fuel Consumption: 53.7223
# maximum steps, simulation is done ...
# elapsed_time: 127.316
# Episode: 8 Exploration P: 0.8048 Total reward: -913.061086702544 SOC: 0.6329 Cumulative_SOC_deviation: 86.5049 Fuel Consumption: 48.0124
# maximum steps, simulation is done ...
# elapsed_time: 127.472
# Episode: 9 Exploration P: 0.7832 Total reward: -867.3636219217102 SOC: 0.6403 Cumulative_SOC_deviation: 81.8725 Fuel Consumption: 48.6383
# maximum steps, simulation is done ...
# elapsed_time: 129.121
# Episode: 10 Exploration P: 0.7623 Total reward: -930.7916192392737 SOC: 0.6315 Cumulative_SOC_deviation: 88.2884 Fuel Consumption: 47.9076
# maximum steps, simulation is done ...
# elapsed_time: 127.450
# Episode: 11 Exploration P: 0.7419 Total reward: -912.7371548338449 SOC: 0.6166 Cumulative_SOC_deviation: 86.6029 Fuel Consumption: 46.7082
# maximum steps, simulation is done ...
# elapsed_time: 127.696
# Episode: 12 Exploration P: 0.7221 Total reward: -1282.4194955285225 SOC: 0.5825 Cumulative_SOC_deviation: 123.8143 Fuel Consumption: 44.2764
# maximum steps, simulation is done ...
# elapsed_time: 127.703
# Episode: 13 Exploration P: 0.7028 Total reward: -1298.4004576966113 SOC: 0.5663 Cumulative_SOC_deviation: 125.5469 Fuel Consumption: 42.9316
# maximum steps, simulation is done ...
# elapsed_time: 127.696
# Episode: 14 Exploration P: 0.6840 Total reward: -1214.7807146171524 SOC: 0.5720 Cumulative_SOC_deviation: 117.1494 Fuel Consumption: 43.2868
# maximum steps, simulation is done ...
# elapsed_time: 127.977
# Episode: 15 Exploration P: 0.6658 Total reward: -1405.5844251441142 SOC: 0.5512 Cumulative_SOC_deviation: 136.3714 Fuel Consumption: 41.8703
# maximum steps, simulation is done ...
# elapsed_time: 123.811
# Episode: 16 Exploration P: 0.6480 Total reward: -1582.8010626796934 SOC: 0.5284 Cumulative_SOC_deviation: 154.2631 Fuel Consumption: 40.1703
# maximum steps, simulation is done ...
# elapsed_time: 122.873
# Episode: 17 Exploration P: 0.6307 Total reward: -1453.5801224905351 SOC: 0.5345 Cumulative_SOC_deviation: 141.3025 Fuel Consumption: 40.5554
# maximum steps, simulation is done ...
# elapsed_time: 120.051
# Episode: 18 Exploration P: 0.6139 Total reward: -1504.0167810801406 SOC: 0.5404 Cumulative_SOC_deviation: 146.2892 Fuel Consumption: 41.1246
# maximum steps, simulation is done ...
# elapsed_time: 120.552
# Episode: 19 Exploration P: 0.5976 Total reward: -1807.6713180876134 SOC: 0.4820 Cumulative_SOC_deviation: 177.1077 Fuel Consumption: 36.5947
# maximum steps, simulation is done ...
# elapsed_time: 120.495
# Episode: 20 Exploration P: 0.5816 Total reward: -1898.8952954760978 SOC: 0.4851 Cumulative_SOC_deviation: 186.1944 Fuel Consumption: 36.9510
# maximum steps, simulation is done ...
# elapsed_time: 121.109
# Episode: 21 Exploration P: 0.5662 Total reward: -1958.8098818727517 SOC: 0.4556 Cumulative_SOC_deviation: 192.4093 Fuel Consumption: 34.7171
# maximum steps, simulation is done ...
# elapsed_time: 121.337
# Episode: 22 Exploration P: 0.5511 Total reward: -1879.939052684962 SOC: 0.4791 Cumulative_SOC_deviation: 184.3494 Fuel Consumption: 36.4450
# maximum steps, simulation is done ...
# elapsed_time: 121.114
# Episode: 23 Exploration P: 0.5364 Total reward: -1997.3292291759042 SOC: 0.4549 Cumulative_SOC_deviation: 196.2764 Fuel Consumption: 34.5652
# maximum steps, simulation is done ...
# elapsed_time: 122.106
# Episode: 24 Exploration P: 0.5222 Total reward: -2485.2553117359907 SOC: 0.3994 Cumulative_SOC_deviation: 245.4671 Fuel Consumption: 30.5842
# maximum steps, simulation is done ...
# elapsed_time: 93.692
# Episode: 25 Exploration P: 0.5083 Total reward: -2172.5465034728445 SOC: 0.4482 Cumulative_SOC_deviation: 213.8208 Fuel Consumption: 34.3384
# maximum steps, simulation is done ...
# elapsed_time: 79.137
# Episode: 26 Exploration P: 0.4948 Total reward: -2390.037707944028 SOC: 0.4070 Cumulative_SOC_deviation: 235.8840 Fuel Consumption: 31.1972
# maximum steps, simulation is done ...
# elapsed_time: 79.171
# Episode: 27 Exploration P: 0.4817 Total reward: -2609.2092627039265 SOC: 0.3803 Cumulative_SOC_deviation: 258.0030 Fuel Consumption: 29.1795
# maximum steps, simulation is done ...
# elapsed_time: 76.970
# Episode: 28 Exploration P: 0.4689 Total reward: -2430.018272717677 SOC: 0.4026 Cumulative_SOC_deviation: 239.9147 Fuel Consumption: 30.8709
# maximum steps, simulation is done ...
# elapsed_time: 74.410
# Episode: 29 Exploration P: 0.4565 Total reward: -2443.746402601799 SOC: 0.3841 Cumulative_SOC_deviation: 241.4220 Fuel Consumption: 29.5261
# maximum steps, simulation is done ...
# elapsed_time: 74.374
# Episode: 30 Exploration P: 0.4444 Total reward: -2781.610149111336 SOC: 0.3381 Cumulative_SOC_deviation: 275.5287 Fuel Consumption: 26.3229
# maximum steps, simulation is done ...
# elapsed_time: 74.091
# Episode: 31 Exploration P: 0.4326 Total reward: -2656.2210866160003 SOC: 0.3652 Cumulative_SOC_deviation: 262.7901 Fuel Consumption: 28.3203
# maximum steps, simulation is done ...
# elapsed_time: 74.010
# Episode: 32 Exploration P: 0.4212 Total reward: -1710.332216958027 SOC: 0.9176 Cumulative_SOC_deviation: 163.7431 Fuel Consumption: 72.9015
# Available condition is not avail... SOC: 1
# elapsed_time: 70.732
# Episode: 33 Exploration P: 0.4106 Total reward: -2741.8236338449487 SOC: 1.0000 Cumulative_SOC_deviation: 265.0818 Fuel Consumption: 91.0055
# Available condition is not avail... SOC: 1
# elapsed_time: 70.986
# Episode: 34 Exploration P: 0.4003 Total reward: -2670.148270988344 SOC: 1.0000 Cumulative_SOC_deviation: 258.0464 Fuel Consumption: 89.6842
# Available condition is not avail... SOC: 1
# elapsed_time: 70.712
# Episode: 35 Exploration P: 0.3902 Total reward: -2771.9466266571294 SOC: 1.0000 Cumulative_SOC_deviation: 267.9869 Fuel Consumption: 92.0776
# Available condition is not avail... SOC: 1
# elapsed_time: 70.928
# Episode: 36 Exploration P: 0.3804 Total reward: -2641.334934671542 SOC: 1.0000 Cumulative_SOC_deviation: 255.1160 Fuel Consumption: 90.1753
# Available condition is not avail... SOC: 1
# elapsed_time: 70.700
# Episode: 37 Exploration P: 0.3709 Total reward: -2743.6067742781 SOC: 1.0000 Cumulative_SOC_deviation: 265.1854 Fuel Consumption: 91.7523
# Available condition is not avail... SOC: 1
# elapsed_time: 70.777
# Episode: 38 Exploration P: 0.3616 Total reward: -2837.373626448052 SOC: 1.0000 Cumulative_SOC_deviation: 274.4777 Fuel Consumption: 92.5965
# Available condition is not avail... SOC: 1
# elapsed_time: 70.795
# Episode: 39 Exploration P: 0.3525 Total reward: -2806.155764509319 SOC: 1.0000 Cumulative_SOC_deviation: 271.2955 Fuel Consumption: 93.2009
# Available condition is not avail... SOC: 1
# elapsed_time: 71.580
# Episode: 40 Exploration P: 0.3437 Total reward: -2931.51928339482 SOC: 1.0000 Cumulative_SOC_deviation: 283.7472 Fuel Consumption: 94.0472
# Available condition is not avail... SOC: 1
# elapsed_time: 70.562
# Episode: 41 Exploration P: 0.3351 Total reward: -2901.098587600245 SOC: 1.0000 Cumulative_SOC_deviation: 280.7035 Fuel Consumption: 94.0632
# Available condition is not avail... SOC: 1
# elapsed_time: 70.614
# Episode: 42 Exploration P: 0.3267 Total reward: -3013.923499726566 SOC: 1.0000 Cumulative_SOC_deviation: 291.9476 Fuel Consumption: 94.4473
# Available condition is not avail... SOC: 1
# elapsed_time: 70.809
# Episode: 43 Exploration P: 0.3186 Total reward: -2924.9443570183917 SOC: 1.0000 Cumulative_SOC_deviation: 283.0705 Fuel Consumption: 94.2398
# Available condition is not avail... SOC: 1
# elapsed_time: 70.668
# Episode: 44 Exploration P: 0.3106 Total reward: -2937.679327408352 SOC: 1.0000 Cumulative_SOC_deviation: 284.3390 Fuel Consumption: 94.2890
# Available condition is not avail... SOC: 1
# elapsed_time: 71.064
# Episode: 45 Exploration P: 0.3029 Total reward: -2926.26962716038 SOC: 1.0000 Cumulative_SOC_deviation: 283.2212 Fuel Consumption: 94.0579
# Available condition is not avail... SOC: 1
# elapsed_time: 71.188
# Episode: 46 Exploration P: 0.2953 Total reward: -2961.8098612068957 SOC: 1.0000 Cumulative_SOC_deviation: 286.5588 Fuel Consumption: 96.2223
# Available condition is not avail... SOC: 1
# elapsed_time: 71.127
# Episode: 47 Exploration P: 0.2880 Total reward: -3110.0362214486427 SOC: 1.0000 Cumulative_SOC_deviation: 301.2220 Fuel Consumption: 97.8164
# Available condition is not avail... SOC: 1
# elapsed_time: 70.659
# Episode: 48 Exploration P: 0.2808 Total reward: -3003.075507190985 SOC: 1.0000 Cumulative_SOC_deviation: 290.7406 Fuel Consumption: 95.6691
# Available condition is not avail... SOC: 1
# elapsed_time: 71.260
# Episode: 49 Exploration P: 0.2738 Total reward: -3081.043757396005 SOC: 1.0000 Cumulative_SOC_deviation: 298.3405 Fuel Consumption: 97.6388
# Available condition is not avail... SOC: 1
# elapsed_time: 70.942
# Episode: 50 Exploration P: 0.2670 Total reward: -3113.4857028644014 SOC: 1.0000 Cumulative_SOC_deviation: 301.5409 Fuel Consumption: 98.0763
# Available condition is not avail... SOC: 1
# elapsed_time: 70.941
# Episode: 51 Exploration P: 0.2604 Total reward: -3097.037749807596 SOC: 1.0000 Cumulative_SOC_deviation: 299.8958 Fuel Consumption: 98.0795
# Available condition is not avail... SOC: 1
# elapsed_time: 70.891
# Episode: 52 Exploration P: 0.2540 Total reward: -3071.977129008659 SOC: 1.0000 Cumulative_SOC_deviation: 297.3566 Fuel Consumption: 98.4112
# Available condition is not avail... SOC: 1
# elapsed_time: 70.786
# Episode: 53 Exploration P: 0.2477 Total reward: -3110.4608518889477 SOC: 1.0000 Cumulative_SOC_deviation: 301.1646 Fuel Consumption: 98.8146
# Available condition is not avail... SOC: 1
# elapsed_time: 70.840
# Episode: 54 Exploration P: 0.2416 Total reward: -3070.7480680242916 SOC: 1.0000 Cumulative_SOC_deviation: 297.2924 Fuel Consumption: 97.8239
# Available condition is not avail... SOC: 1
# elapsed_time: 70.821
# Episode: 55 Exploration P: 0.2356 Total reward: -3147.428787630391 SOC: 1.0000 Cumulative_SOC_deviation: 304.7564 Fuel Consumption: 99.8652
# Available condition is not avail... SOC: 1
# elapsed_time: 70.989
# Episode: 56 Exploration P: 0.2298 Total reward: -3097.469170494378 SOC: 1.0000 Cumulative_SOC_deviation: 299.9157 Fuel Consumption: 98.3117
# Available condition is not avail... SOC: 1
# elapsed_time: 70.646
# Episode: 57 Exploration P: 0.2241 Total reward: -3072.6192040521028 SOC: 1.0000 Cumulative_SOC_deviation: 297.4567 Fuel Consumption: 98.0517
# Available condition is not avail... SOC: 1
# elapsed_time: 71.126
# Episode: 58 Exploration P: 0.2186 Total reward: -3227.9201678597547 SOC: 1.0000 Cumulative_SOC_deviation: 312.7531 Fuel Consumption: 100.3894
# Available condition is not avail... SOC: 1
# elapsed_time: 70.888
# Episode: 59 Exploration P: 0.2132 Total reward: -3189.0788998944577 SOC: 1.0000 Cumulative_SOC_deviation: 308.8106 Fuel Consumption: 100.9725
# Available condition is not avail... SOC: 1
# elapsed_time: 71.249
# Episode: 60 Exploration P: 0.2080 Total reward: -3237.754909597342 SOC: 1.0000 Cumulative_SOC_deviation: 313.5946 Fuel Consumption: 101.8091
# Available condition is not avail... SOC: 1
# elapsed_time: 71.556
# Episode: 61 Exploration P: 0.2029 Total reward: -3264.5263882402096 SOC: 1.0000 Cumulative_SOC_deviation: 316.2863 Fuel Consumption: 101.6636
# Available condition is not avail... SOC: 1
# elapsed_time: 71.781
# Episode: 62 Exploration P: 0.1979 Total reward: -3278.7875186454608 SOC: 1.0000 Cumulative_SOC_deviation: 317.6422 Fuel Consumption: 102.3655
# Available condition is not avail... SOC: 1
# elapsed_time: 71.503
# Episode: 63 Exploration P: 0.1931 Total reward: -3260.905273440152 SOC: 1.0000 Cumulative_SOC_deviation: 315.8944 Fuel Consumption: 101.9610
# Available condition is not avail... SOC: 1
# elapsed_time: 71.295
# Episode: 64 Exploration P: 0.1884 Total reward: -3285.0352075836363 SOC: 1.0000 Cumulative_SOC_deviation: 318.2728 Fuel Consumption: 102.3077
# Available condition is not avail... SOC: 1
# elapsed_time: 71.084
# Episode: 65 Exploration P: 0.1838 Total reward: -3216.5513152367416 SOC: 1.0000 Cumulative_SOC_deviation: 311.4359 Fuel Consumption: 102.1921
# Available condition is not avail... SOC: 1
# elapsed_time: 71.062
# Episode: 66 Exploration P: 0.1793 Total reward: -3231.978809145014 SOC: 1.0000 Cumulative_SOC_deviation: 313.0010 Fuel Consumption: 101.9685
# Available condition is not avail... SOC: 1
# elapsed_time: 71.013
# Episode: 67 Exploration P: 0.1749 Total reward: -3236.4357547058457 SOC: 1.0000 Cumulative_SOC_deviation: 313.3816 Fuel Consumption: 102.6201
# Available condition is not avail... SOC: 1
# elapsed_time: 70.511
# Episode: 68 Exploration P: 0.1707 Total reward: -3258.550305525297 SOC: 1.0000 Cumulative_SOC_deviation: 315.5000 Fuel Consumption: 103.5498
# Available condition is not avail... SOC: 1
# elapsed_time: 70.775
# Episode: 69 Exploration P: 0.1665 Total reward: -3324.9982976303977 SOC: 1.0000 Cumulative_SOC_deviation: 322.0373 Fuel Consumption: 104.6250
# Available condition is not avail... SOC: 1
# elapsed_time: 71.583
# Episode: 70 Exploration P: 0.1625 Total reward: -3364.5644389598024 SOC: 1.0000 Cumulative_SOC_deviation: 325.9702 Fuel Consumption: 104.8625
# Available condition is not avail... SOC: 1
# elapsed_time: 71.662
# Episode: 71 Exploration P: 0.1586 Total reward: -3160.4993568664663 SOC: 1.0000 Cumulative_SOC_deviation: 305.8605 Fuel Consumption: 101.8947
# Available condition is not avail... SOC: 1
# elapsed_time: 71.331
# Episode: 72 Exploration P: 0.1547 Total reward: -3311.441999545764 SOC: 1.0000 Cumulative_SOC_deviation: 320.7573 Fuel Consumption: 103.8686
# Available condition is not avail... SOC: 1
# elapsed_time: 71.143
# Episode: 73 Exploration P: 0.1510 Total reward: -3271.9567406317888 SOC: 1.0000 Cumulative_SOC_deviation: 316.8023 Fuel Consumption: 103.9339
# Available condition is not avail... SOC: 1
# elapsed_time: 72.209
# Episode: 74 Exploration P: 0.1474 Total reward: -3296.0222929874617 SOC: 1.0000 Cumulative_SOC_deviation: 319.1980 Fuel Consumption: 104.0420
# Available condition is not avail... SOC: 1
# elapsed_time: 71.391
# Episode: 75 Exploration P: 0.1438 Total reward: -3322.5336330387095 SOC: 1.0000 Cumulative_SOC_deviation: 321.8325 Fuel Consumption: 104.2089
# Available condition is not avail... SOC: 1
# elapsed_time: 71.311
# Episode: 76 Exploration P: 0.1404 Total reward: -3303.0385946632055 SOC: 1.0000 Cumulative_SOC_deviation: 319.8793 Fuel Consumption: 104.2452
# Available condition is not avail... SOC: 1
# elapsed_time: 71.154
# Episode: 77 Exploration P: 0.1370 Total reward: -3318.6702929883472 SOC: 1.0000 Cumulative_SOC_deviation: 321.4349 Fuel Consumption: 104.3212
# Available condition is not avail... SOC: 1
# elapsed_time: 71.179
# Episode: 78 Exploration P: 0.1338 Total reward: -3357.9575691720474 SOC: 1.0000 Cumulative_SOC_deviation: 325.2569 Fuel Consumption: 105.3889
# Available condition is not avail... SOC: 1
# elapsed_time: 71.356
# Episode: 79 Exploration P: 0.1306 Total reward: -3363.316204643639 SOC: 1.0000 Cumulative_SOC_deviation: 325.8054 Fuel Consumption: 105.2627
# Available condition is not avail... SOC: 1
# elapsed_time: 71.431
# Episode: 80 Exploration P: 0.1275 Total reward: -3357.819631489848 SOC: 1.0000 Cumulative_SOC_deviation: 325.2414 Fuel Consumption: 105.4060
# Available condition is not avail... SOC: 1
# elapsed_time: 71.530
# Episode: 81 Exploration P: 0.1244 Total reward: -3345.543430953888 SOC: 1.0000 Cumulative_SOC_deviation: 324.0600 Fuel Consumption: 104.9439
# Available condition is not avail... SOC: 1
# elapsed_time: 72.473
# Episode: 82 Exploration P: 0.1215 Total reward: -3298.3396504599127 SOC: 1.0000 Cumulative_SOC_deviation: 319.3242 Fuel Consumption: 105.0979
# Available condition is not avail... SOC: 1
# elapsed_time: 72.057
# Episode: 83 Exploration P: 0.1186 Total reward: -3331.184439502695 SOC: 1.0000 Cumulative_SOC_deviation: 322.6633 Fuel Consumption: 104.5512
# Available condition is not avail... SOC: 1
# elapsed_time: 71.787
# Episode: 84 Exploration P: 0.1158 Total reward: -3385.604716667418 SOC: 1.0000 Cumulative_SOC_deviation: 328.0051 Fuel Consumption: 105.5537
# Available condition is not avail... SOC: 1
# elapsed_time: 71.605
# Episode: 85 Exploration P: 0.1131 Total reward: -3393.800672840532 SOC: 1.0000 Cumulative_SOC_deviation: 328.7304 Fuel Consumption: 106.4962
# Available condition is not avail... SOC: 1
# elapsed_time: 70.972
# Episode: 86 Exploration P: 0.1104 Total reward: -3396.2853555987444 SOC: 1.0000 Cumulative_SOC_deviation: 329.0335 Fuel Consumption: 105.9506
# Available condition is not avail... SOC: 1
# elapsed_time: 68.067
# Episode: 87 Exploration P: 0.1079 Total reward: -3388.9838445254827 SOC: 1.0000 Cumulative_SOC_deviation: 328.3015 Fuel Consumption: 105.9688
# Available condition is not avail... SOC: 1
# elapsed_time: 71.505
# Episode: 88 Exploration P: 0.1053 Total reward: -3436.303196290426 SOC: 1.0000 Cumulative_SOC_deviation: 332.9158 Fuel Consumption: 107.1457
# Available condition is not avail... SOC: 1
# elapsed_time: 71.383
# Episode: 89 Exploration P: 0.1029 Total reward: -3376.025076349581 SOC: 1.0000 Cumulative_SOC_deviation: 326.9819 Fuel Consumption: 106.2063
# Available condition is not avail... SOC: 1
# elapsed_time: 71.412
# Episode: 90 Exploration P: 0.1005 Total reward: -3424.735862699565 SOC: 1.0000 Cumulative_SOC_deviation: 331.7896 Fuel Consumption: 106.8397
# Available condition is not avail... SOC: 1
# elapsed_time: 72.624
# Episode: 91 Exploration P: 0.0982 Total reward: -3413.042565200239 SOC: 1.0000 Cumulative_SOC_deviation: 330.6461 Fuel Consumption: 106.5818
# Available condition is not avail... SOC: 1
# elapsed_time: 69.416
# Episode: 92 Exploration P: 0.0959 Total reward: -3416.00003853363 SOC: 1.0000 Cumulative_SOC_deviation: 330.9075 Fuel Consumption: 106.9253
# Available condition is not avail... SOC: 1
# elapsed_time: 69.348
# Episode: 93 Exploration P: 0.0937 Total reward: -3450.831658158623 SOC: 1.0000 Cumulative_SOC_deviation: 334.4461 Fuel Consumption: 106.3711
# Available condition is not avail... SOC: 1
# elapsed_time: 71.220
# Episode: 94 Exploration P: 0.0915 Total reward: -3406.69298450865 SOC: 1.0000 Cumulative_SOC_deviation: 330.0117 Fuel Consumption: 106.5765
# Available condition is not avail... SOC: 1
# elapsed_time: 71.372
# Episode: 95 Exploration P: 0.0894 Total reward: -3408.669712098516 SOC: 1.0000 Cumulative_SOC_deviation: 330.1444 Fuel Consumption: 107.2259
# Available condition is not avail... SOC: 1
# elapsed_time: 71.390
# Episode: 96 Exploration P: 0.0874 Total reward: -3428.987982242234 SOC: 1.0000 Cumulative_SOC_deviation: 332.1460 Fuel Consumption: 107.5276
# Available condition is not avail... SOC: 1
# elapsed_time: 71.355
# Episode: 97 Exploration P: 0.0854 Total reward: -3439.125231260867 SOC: 1.0000 Cumulative_SOC_deviation: 333.1757 Fuel Consumption: 107.3682
# Available condition is not avail... SOC: 1
# elapsed_time: 71.573
# Episode: 98 Exploration P: 0.0834 Total reward: -3410.26330342136 SOC: 1.0000 Cumulative_SOC_deviation: 330.3002 Fuel Consumption: 107.2612
# Available condition is not avail... SOC: 1
# elapsed_time: 71.912
# Episode: 99 Exploration P: 0.0815 Total reward: -3460.5627155248208 SOC: 1.0000 Cumulative_SOC_deviation: 335.2790 Fuel Consumption: 107.7726
# Available condition is not avail... SOC: 1
# elapsed_time: 71.743
# Episode: 100 Exploration P: 0.0797 Total reward: -3451.633187333795 SOC: 1.0000 Cumulative_SOC_deviation: 334.3899 Fuel Consumption: 107.7341
# maximum steps, simulation is done ...
# elapsed_time: 21.073
# Episode: 1 Exploration P: 1.0000 Total reward: -1008.0734692597292 SOC: 0.8114 Cumulative_SOC_deviation: 94.6105 Fuel Consumption: 61.9689
# maximum steps, simulation is done ...
# elapsed_time: 21.053
# Episode: 2 Exploration P: 1.0000 Total reward: -1040.6887904241767 SOC: 0.8144 Cumulative_SOC_deviation: 97.8509 Fuel Consumption: 62.1797
# WARNING:tensorflow:Layer dense_45 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_48 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# ...
#
# WARNING:tensorflow:Layer dense_102 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer dense_93 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_90 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 52.614
# Episode: 3 Exploration P: 0.9217 Total reward: -949.3475983852189 SOC: 0.7923 Cumulative_SOC_deviation: 88.8785 Fuel Consumption: 60.5622
# maximum steps, simulation is done ...
# elapsed_time: 60.364
# Episode: 4 Exploration P: 0.8970 Total reward: -836.0830244244004 SOC: 0.7478 Cumulative_SOC_deviation: 77.9036 Fuel Consumption: 57.0468
# maximum steps, simulation is done ...
# elapsed_time: 61.542
# Episode: 5 Exploration P: 0.8730 Total reward: -738.5896419965006 SOC: 0.7077 Cumulative_SOC_deviation: 68.4768 Fuel Consumption: 53.8219
# maximum steps, simulation is done ...
# elapsed_time: 64.233
# Episode: 6 Exploration P: 0.8496 Total reward: -792.0834318331326 SOC: 0.6924 Cumulative_SOC_deviation: 73.9596 Fuel Consumption: 52.4877
# maximum steps, simulation is done ...
# elapsed_time: 65.679
# Episode: 7 Exploration P: 0.8269 Total reward: -693.5675886382569 SOC: 0.6864 Cumulative_SOC_deviation: 64.1392 Fuel Consumption: 52.1755
# maximum steps, simulation is done ...
# elapsed_time: 62.220
# Episode: 8 Exploration P: 0.8048 Total reward: -698.7477635964048 SOC: 0.6863 Cumulative_SOC_deviation: 64.6661 Fuel Consumption: 52.0866
# maximum steps, simulation is done ...
# elapsed_time: 63.506
# Episode: 9 Exploration P: 0.7832 Total reward: -787.176656485377 SOC: 0.6632 Cumulative_SOC_deviation: 73.6963 Fuel Consumption: 50.2134
# maximum steps, simulation is done ...
# elapsed_time: 61.754
# Episode: 10 Exploration P: 0.7623 Total reward: -1089.8643890601475 SOC: 0.6061 Cumulative_SOC_deviation: 104.3846 Fuel Consumption: 46.0181
# maximum steps, simulation is done ...
# elapsed_time: 65.534
# Episode: 11 Exploration P: 0.7419 Total reward: -1052.1759575833023 SOC: 0.5956 Cumulative_SOC_deviation: 100.7015 Fuel Consumption: 45.1612
# maximum steps, simulation is done ...
# elapsed_time: 62.049
# Episode: 12 Exploration P: 0.7221 Total reward: -1058.5888426876768 SOC: 0.5913 Cumulative_SOC_deviation: 101.3768 Fuel Consumption: 44.8210
# maximum steps, simulation is done ...
# elapsed_time: 62.943
# Episode: 13 Exploration P: 0.7028 Total reward: -1330.743464215039 SOC: 0.5724 Cumulative_SOC_deviation: 128.7222 Fuel Consumption: 43.5211
# maximum steps, simulation is done ...
# elapsed_time: 62.789
# Episode: 14 Exploration P: 0.6840 Total reward: -1215.8008998600596 SOC: 0.5836 Cumulative_SOC_deviation: 117.1508 Fuel Consumption: 44.2925
# maximum steps, simulation is done ...
# elapsed_time: 62.006
# Episode: 15 Exploration P: 0.6658 Total reward: -1426.1839185182534 SOC: 0.5426 Cumulative_SOC_deviation: 138.4972 Fuel Consumption: 41.2123
# maximum steps, simulation is done ...
# elapsed_time: 62.018
# Episode: 16 Exploration P: 0.6480 Total reward: -1662.4383795925698 SOC: 0.5288 Cumulative_SOC_deviation: 162.2341 Fuel Consumption: 40.0975
# maximum steps, simulation is done ...
# elapsed_time: 61.969
# Episode: 17 Exploration P: 0.6307 Total reward: -1748.4987039298387 SOC: 0.5096 Cumulative_SOC_deviation: 170.9739 Fuel Consumption: 38.7602
# maximum steps, simulation is done ...
# elapsed_time: 62.385
# Episode: 18 Exploration P: 0.6139 Total reward: -1776.7129850803722 SOC: 0.5059 Cumulative_SOC_deviation: 173.8232 Fuel Consumption: 38.4809
# maximum steps, simulation is done ...
# elapsed_time: 63.124
# Episode: 19 Exploration P: 0.5976 Total reward: -1799.6626012892305 SOC: 0.4989 Cumulative_SOC_deviation: 176.1809 Fuel Consumption: 37.8540
# maximum steps, simulation is done ...
# elapsed_time: 63.408
# Episode: 20 Exploration P: 0.5816 Total reward: -1809.873018580125 SOC: 0.4899 Cumulative_SOC_deviation: 177.2612 Fuel Consumption: 37.2613
# maximum steps, simulation is done ...
# elapsed_time: 62.537
# Episode: 21 Exploration P: 0.5662 Total reward: -1904.0588489957042 SOC: 0.4763 Cumulative_SOC_deviation: 186.7717 Fuel Consumption: 36.3422
# maximum steps, simulation is done ...
# elapsed_time: 60.742
# Episode: 22 Exploration P: 0.5511 Total reward: -2133.9681963963144 SOC: 0.4492 Cumulative_SOC_deviation: 209.9605 Fuel Consumption: 34.3630
# maximum steps, simulation is done ...
# elapsed_time: 64.101
# Episode: 23 Exploration P: 0.5364 Total reward: -2123.6940787675303 SOC: 0.4451 Cumulative_SOC_deviation: 208.9854 Fuel Consumption: 33.8398
# maximum steps, simulation is done ...
# elapsed_time: 54.928
# Episode: 24 Exploration P: 0.5222 Total reward: -2195.9100313031818 SOC: 0.4399 Cumulative_SOC_deviation: 216.2316 Fuel Consumption: 33.5937
# maximum steps, simulation is done ...
# elapsed_time: 57.578
# Episode: 25 Exploration P: 0.5083 Total reward: -2187.5431864501156 SOC: 0.4368 Cumulative_SOC_deviation: 215.4233 Fuel Consumption: 33.3102
# maximum steps, simulation is done ...
# elapsed_time: 56.519
# Episode: 26 Exploration P: 0.4948 Total reward: -2334.892299904856 SOC: 0.4122 Cumulative_SOC_deviation: 230.3324 Fuel Consumption: 31.5685
# maximum steps, simulation is done ...
# elapsed_time: 57.312
# Episode: 27 Exploration P: 0.4817 Total reward: -2554.654823918264 SOC: 0.3870 Cumulative_SOC_deviation: 252.4995 Fuel Consumption: 29.6598
# maximum steps, simulation is done ...
# elapsed_time: 60.337
# Episode: 28 Exploration P: 0.4689 Total reward: -2534.7395818774626 SOC: 0.3950 Cumulative_SOC_deviation: 250.4399 Fuel Consumption: 30.3403
# maximum steps, simulation is done ...
# elapsed_time: 63.675
# Episode: 29 Exploration P: 0.4565 Total reward: -2469.287103226552 SOC: 0.3875 Cumulative_SOC_deviation: 243.9582 Fuel Consumption: 29.7048
# maximum steps, simulation is done ...
# elapsed_time: 60.282
# Episode: 30 Exploration P: 0.4444 Total reward: -2603.232982072886 SOC: 0.3694 Cumulative_SOC_deviation: 257.4618 Fuel Consumption: 28.6146
# maximum steps, simulation is done ...
# elapsed_time: 58.455
# Episode: 31 Exploration P: 0.4326 Total reward: -2681.4096404156385 SOC: 0.3695 Cumulative_SOC_deviation: 265.2843 Fuel Consumption: 28.5664
# maximum steps, simulation is done ...
# elapsed_time: 55.700
# Episode: 32 Exploration P: 0.4212 Total reward: -2951.017407034857 SOC: 0.3402 Cumulative_SOC_deviation: 292.4458 Fuel Consumption: 26.5593
# maximum steps, simulation is done ...
# elapsed_time: 55.930
# Episode: 33 Exploration P: 0.4100 Total reward: -2780.0529124073246 SOC: 0.3571 Cumulative_SOC_deviation: 275.2340 Fuel Consumption: 27.7127
# maximum steps, simulation is done ...
# elapsed_time: 55.955
# Episode: 34 Exploration P: 0.3992 Total reward: -2947.0786306835603 SOC: 0.3183 Cumulative_SOC_deviation: 292.2269 Fuel Consumption: 24.8101
# maximum steps, simulation is done ...
# elapsed_time: 56.122
# Episode: 35 Exploration P: 0.3887 Total reward: -2915.8073484464835 SOC: 0.3258 Cumulative_SOC_deviation: 289.0470 Fuel Consumption: 25.3375
# maximum steps, simulation is done ...
# elapsed_time: 57.748
# Episode: 36 Exploration P: 0.3784 Total reward: -2826.4272232612425 SOC: 0.3374 Cumulative_SOC_deviation: 280.0206 Fuel Consumption: 26.2213
# maximum steps, simulation is done ...
# elapsed_time: 59.486
# Episode: 37 Exploration P: 0.3684 Total reward: -2989.232395122365 SOC: 0.3249 Cumulative_SOC_deviation: 296.3754 Fuel Consumption: 25.4788
# maximum steps, simulation is done ...
# elapsed_time: 62.137
# Episode: 38 Exploration P: 0.3587 Total reward: -2918.3753117596925 SOC: 0.3224 Cumulative_SOC_deviation: 289.3235 Fuel Consumption: 25.1407
# maximum steps, simulation is done ...
# elapsed_time: 58.790
# Episode: 39 Exploration P: 0.3493 Total reward: -3123.5783401105455 SOC: 0.2855 Cumulative_SOC_deviation: 310.0987 Fuel Consumption: 22.5912
# maximum steps, simulation is done ...
# elapsed_time: 57.079
# Episode: 40 Exploration P: 0.3401 Total reward: -3012.84132749004 SOC: 0.3160 Cumulative_SOC_deviation: 298.8148 Fuel Consumption: 24.6935
# maximum steps, simulation is done ...
# elapsed_time: 56.734
# Episode: 41 Exploration P: 0.3311 Total reward: -3285.685086563321 SOC: 0.2707 Cumulative_SOC_deviation: 326.4038 Fuel Consumption: 21.6475
# maximum steps, simulation is done ...
# elapsed_time: 59.575
# Episode: 42 Exploration P: 0.3224 Total reward: -3176.1703421556017 SOC: 0.2935 Cumulative_SOC_deviation: 315.2989 Fuel Consumption: 23.1817
# maximum steps, simulation is done ...
# elapsed_time: 59.509
# Episode: 43 Exploration P: 0.3140 Total reward: -3454.9486242516273 SOC: 0.2572 Cumulative_SOC_deviation: 343.4267 Fuel Consumption: 20.6815
# maximum steps, simulation is done ...
# elapsed_time: 57.796
# Episode: 44 Exploration P: 0.3057 Total reward: -3346.2603152366114 SOC: 0.2692 Cumulative_SOC_deviation: 332.4793 Fuel Consumption: 21.4678
# maximum steps, simulation is done ...
# elapsed_time: 57.853
# Episode: 45 Exploration P: 0.2977 Total reward: -3477.5536068313068 SOC: 0.2429 Cumulative_SOC_deviation: 345.7943 Fuel Consumption: 19.6105
# maximum steps, simulation is done ...
# elapsed_time: 68.316
# Episode: 46 Exploration P: 0.2899 Total reward: -3631.1943779600756 SOC: 0.2179 Cumulative_SOC_deviation: 361.3306 Fuel Consumption: 17.8880
# maximum steps, simulation is done ...
# elapsed_time: 62.272
# Episode: 47 Exploration P: 0.2824 Total reward: -3195.299601370039 SOC: 0.2751 Cumulative_SOC_deviation: 317.3513 Fuel Consumption: 21.7866
# maximum steps, simulation is done ...
# elapsed_time: 57.028
# Episode: 48 Exploration P: 0.2750 Total reward: -3606.619626571802 SOC: 0.2172 Cumulative_SOC_deviation: 358.8747 Fuel Consumption: 17.8730
# maximum steps, simulation is done ...
# elapsed_time: 63.546
# Episode: 49 Exploration P: 0.2678 Total reward: -3609.5475499319004 SOC: 0.2222 Cumulative_SOC_deviation: 359.1270 Fuel Consumption: 18.2774
# maximum steps, simulation is done ...
# elapsed_time: 55.770
# Episode: 50 Exploration P: 0.2608 Total reward: -3719.5876608880285 SOC: 0.2071 Cumulative_SOC_deviation: 370.2382 Fuel Consumption: 17.2054
# maximum steps, simulation is done ...
# elapsed_time: 60.614
# Episode: 51 Exploration P: 0.2540 Total reward: -3750.178404668073 SOC: 0.2100 Cumulative_SOC_deviation: 373.2689 Fuel Consumption: 17.4890
# maximum steps, simulation is done ...
# elapsed_time: 64.153
# Episode: 52 Exploration P: 0.2474 Total reward: -3743.368265191455 SOC: 0.2018 Cumulative_SOC_deviation: 372.6643 Fuel Consumption: 16.7251
# maximum steps, simulation is done ...
# elapsed_time: 62.555
# Episode: 53 Exploration P: 0.2410 Total reward: -3906.4495695435917 SOC: 0.1852 Cumulative_SOC_deviation: 389.0761 Fuel Consumption: 15.6884
# maximum steps, simulation is done ...
# elapsed_time: 62.598
# Episode: 54 Exploration P: 0.2347 Total reward: -3884.930674851156 SOC: 0.1879 Cumulative_SOC_deviation: 386.9075 Fuel Consumption: 15.8553
# maximum steps, simulation is done ...
# elapsed_time: 62.326
# Episode: 55 Exploration P: 0.2286 Total reward: -3745.5817365506045 SOC: 0.1966 Cumulative_SOC_deviation: 372.9218 Fuel Consumption: 16.3634
# maximum steps, simulation is done ...
# elapsed_time: 62.888
# Episode: 56 Exploration P: 0.2227 Total reward: -3957.116757735685 SOC: 0.1819 Cumulative_SOC_deviation: 394.1553 Fuel Consumption: 15.5643
# maximum steps, simulation is done ...
# elapsed_time: 62.673
# Episode: 57 Exploration P: 0.2170 Total reward: -4015.1652017350625 SOC: 0.1561 Cumulative_SOC_deviation: 400.1372 Fuel Consumption: 13.7936
# maximum steps, simulation is done ...
# elapsed_time: 62.510
# Episode: 58 Exploration P: 0.2114 Total reward: -3926.814573676887 SOC: 0.1793 Cumulative_SOC_deviation: 391.1507 Fuel Consumption: 15.3075
# maximum steps, simulation is done ...
# elapsed_time: 62.384
# Episode: 59 Exploration P: 0.2059 Total reward: -3871.4016352404365 SOC: 0.1786 Cumulative_SOC_deviation: 385.6192 Fuel Consumption: 15.2101
# maximum steps, simulation is done ...
# elapsed_time: 62.320
# Episode: 60 Exploration P: 0.2006 Total reward: -4071.84168806391 SOC: 0.1565 Cumulative_SOC_deviation: 405.7843 Fuel Consumption: 13.9990
# maximum steps, simulation is done ...
# elapsed_time: 62.291
# Episode: 61 Exploration P: 0.1954 Total reward: -4036.7247977826114 SOC: 0.1592 Cumulative_SOC_deviation: 402.2657 Fuel Consumption: 14.0675
# maximum steps, simulation is done ...
# elapsed_time: 62.448
# Episode: 62 Exploration P: 0.1904 Total reward: -4217.510821620171 SOC: 0.1487 Cumulative_SOC_deviation: 420.4017 Fuel Consumption: 13.4940
# maximum steps, simulation is done ...
# elapsed_time: 63.320
# Episode: 63 Exploration P: 0.1855 Total reward: -4113.9006063071865 SOC: 0.1518 Cumulative_SOC_deviation: 410.0341 Fuel Consumption: 13.5593
# maximum steps, simulation is done ...
# elapsed_time: 63.899
# Episode: 64 Exploration P: 0.1808 Total reward: -4196.434049115837 SOC: 0.1347 Cumulative_SOC_deviation: 418.3906 Fuel Consumption: 12.5280
# maximum steps, simulation is done ...
# elapsed_time: 64.556
# Episode: 65 Exploration P: 0.1761 Total reward: -4300.876561195945 SOC: 0.1230 Cumulative_SOC_deviation: 428.9115 Fuel Consumption: 11.7619
# maximum steps, simulation is done ...
# elapsed_time: 64.721
# Episode: 66 Exploration P: 0.1716 Total reward: -4222.4467556372865 SOC: 0.1356 Cumulative_SOC_deviation: 420.9974 Fuel Consumption: 12.4723
# maximum steps, simulation is done ...
# elapsed_time: 64.254
# Episode: 67 Exploration P: 0.1673 Total reward: -4186.37463183013 SOC: 0.1375 Cumulative_SOC_deviation: 417.3655 Fuel Consumption: 12.7195
# maximum steps, simulation is done ...
# elapsed_time: 64.226
# Episode: 68 Exploration P: 0.1630 Total reward: -4287.454710737191 SOC: 0.1264 Cumulative_SOC_deviation: 427.5552 Fuel Consumption: 11.9031
# maximum steps, simulation is done ...
# elapsed_time: 64.280
# Episode: 69 Exploration P: 0.1589 Total reward: -4233.185211419248 SOC: 0.1261 Cumulative_SOC_deviation: 422.1362 Fuel Consumption: 11.8229
# maximum steps, simulation is done ...
# elapsed_time: 64.480
# Episode: 70 Exploration P: 0.1548 Total reward: -4345.355891856997 SOC: 0.1089 Cumulative_SOC_deviation: 433.4529 Fuel Consumption: 10.8269

# %%
with open("DDPG6_1.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)
