# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 

from vehicle_model_DDPG3 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
env = Environment(cell_model, drving_cycle, battery_path, motor_path, 10)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64):      
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple):
        index = self.buffer_counter % self.buffer_capacity 

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)

        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    inputs_batchnorm = layers.BatchNormalization()(inputs)
    
    out = layers.Dense(512, activation="relu")(inputs_batchnorm)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_input_batchnorm = layers.BatchNormalization()(state_input)
    
    state_out = layers.Dense(16, activation="relu")(state_input_batchnorm)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

critic_lr = 0.0005 
actor_lr = 0.00025 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 200
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
DELAY_TRAINING = 3000

# %%
def initialization(reward_factor): 
    actor_model = get_actor() 
    critic_model = get_critic() 

    target_actor = get_actor() 
    target_critic = get_critic() 
    target_actor.set_weights(actor_model.get_weights())
    target_critic.set_weights(critic_model.get_weights())
    
    buffer = Buffer(500000, BATCH_SIZE)
    env = Environment(cell_model, drving_cycle, battery_path, motor_path, reward_factor)
    return actor_model, critic_model, target_actor, target_critic, buffer, env

# %%
def save_weights(actor_model, critic_model, target_actor, target_critic, root): 
    actor_model.save_weights("./{}/actor_model_checkpoint".format(root))
    critic_model.save_weights("./{}/critic_model_checkpoint".format(root))
    target_actor.save_weights("./{}/target_actor_checkpoint".format(root))
    target_critic.save_weights("./{}/target_critic_checkpoint".format(root))
    print("model is saved..")

# %%
print(env.version)

num_trials = 3
reward_factor = 10
results_dict = {} 
for trial in range(num_trials): 
    print()
    print("Trial {}".format(trial))
    
    actor_model, critic_model, target_actor, target_critic, buffer, env = initialization(
        reward_factor
    )
    
    eps = MAX_EPSILON 
    steps = 0
    
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    for ep in range(total_episodes): 
        start = time.time() 
        state = env.reset() 
        episodic_reward = 0 

        while True: 
            tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
            action = policy_epsilon_greedy(tf_state, eps)
    #         print(action)
            next_state, reward, done = env.step(action)
            if done: 
                next_state = [0] * num_states 

            buffer.record((state, action, reward, next_state))
            episodic_reward += reward 

            if steps > DELAY_TRAINING: 
                buffer.learn() 
                update_target(tau)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * steps)

            steps += 1

            if done: 
                break 

            state = next_state 

        elapsed_time = time.time() - start 
        print("elapsed_time: {:.3f}".format(elapsed_time))
        episode_rewards.append(episodic_reward) 
        episode_SOCs.append(env.SOC)
        episode_FCs.append(env.fuel_consumption) 

    #     print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
        SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
        print(
              'Episode: {}'.format(ep + 1),
              "Exploration P: {:.4f}".format(eps),
              'Total reward: {}'.format(episodic_reward), 
              "SOC: {:.4f}".format(env.SOC), 
              "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
              "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
        )
    
#     root = "DDPG3_trial{}".format(trial+1)
#     save_weights(actor_model, critic_model, target_actor, target_critic, root)
    
    results_dict[trial + 1] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs 
    }
# Out:
# 1
#
# Trial 0
# maximum steps, simulation is done ...
# elapsed_time: 36.834
# Episode: 1 Exploration P: 1.0000 Total reward: -5149.666902155747 SOC: 1.0000 Cumulative_SOC_deviation: 499.8453 Fuel Consumption: 151.2135
# maximum steps, simulation is done ...
# elapsed_time: 36.493
# Episode: 2 Exploration P: 1.0000 Total reward: -5060.330003553431 SOC: 1.0000 Cumulative_SOC_deviation: 491.0375 Fuel Consumption: 149.9547
# WARNING:tensorflow:Layer batch_normalization_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 95.935
# Episode: 3 Exploration P: 0.9217 Total reward: -5113.927780336382 SOC: 1.0000 Cumulative_SOC_deviation: 497.0683 Fuel Consumption: 143.2452
# maximum steps, simulation is done ...
# elapsed_time: 110.814
# Episode: 4 Exploration P: 0.8970 Total reward: -5056.555013181813 SOC: 1.0000 Cumulative_SOC_deviation: 491.5866 Fuel Consumption: 140.6890
# maximum steps, simulation is done ...
# elapsed_time: 112.756
# Episode: 5 Exploration P: 0.8730 Total reward: -4975.402025146905 SOC: 1.0000 Cumulative_SOC_deviation: 483.6704 Fuel Consumption: 138.6976
# maximum steps, simulation is done ...
# elapsed_time: 110.664
# Episode: 6 Exploration P: 0.8496 Total reward: -4908.446880364634 SOC: 1.0000 Cumulative_SOC_deviation: 477.0100 Fuel Consumption: 138.3468
# maximum steps, simulation is done ...
# elapsed_time: 110.075
# Episode: 7 Exploration P: 0.8269 Total reward: -4822.055264922799 SOC: 1.0000 Cumulative_SOC_deviation: 469.0426 Fuel Consumption: 131.6297
# maximum steps, simulation is done ...
# elapsed_time: 107.012
# Episode: 8 Exploration P: 0.8048 Total reward: -4742.307913284411 SOC: 1.0000 Cumulative_SOC_deviation: 461.6302 Fuel Consumption: 126.0063
# maximum steps, simulation is done ...
# elapsed_time: 105.559
# Episode: 9 Exploration P: 0.7832 Total reward: -4812.527683731963 SOC: 1.0000 Cumulative_SOC_deviation: 468.7718 Fuel Consumption: 124.8094
# maximum steps, simulation is done ...
# elapsed_time: 106.749
# Episode: 10 Exploration P: 0.7623 Total reward: -4616.170470403195 SOC: 1.0000 Cumulative_SOC_deviation: 449.5468 Fuel Consumption: 120.7027
# maximum steps, simulation is done ...
# elapsed_time: 111.098
# Episode: 11 Exploration P: 0.7419 Total reward: -4714.600386977387 SOC: 1.0000 Cumulative_SOC_deviation: 459.3836 Fuel Consumption: 120.7647
# maximum steps, simulation is done ...
# elapsed_time: 105.874
# Episode: 12 Exploration P: 0.7221 Total reward: -4621.644788808149 SOC: 1.0000 Cumulative_SOC_deviation: 449.7682 Fuel Consumption: 123.9633
# maximum steps, simulation is done ...
# elapsed_time: 107.875
# Episode: 13 Exploration P: 0.7028 Total reward: -4654.731765337316 SOC: 1.0000 Cumulative_SOC_deviation: 453.3998 Fuel Consumption: 120.7337
# maximum steps, simulation is done ...
# elapsed_time: 106.351
# Episode: 14 Exploration P: 0.6840 Total reward: -4492.356882083332 SOC: 1.0000 Cumulative_SOC_deviation: 437.2686 Fuel Consumption: 119.6709
# maximum steps, simulation is done ...
# elapsed_time: 105.624
# Episode: 15 Exploration P: 0.6658 Total reward: -4659.534953315566 SOC: 1.0000 Cumulative_SOC_deviation: 454.5807 Fuel Consumption: 113.7277
# maximum steps, simulation is done ...
# elapsed_time: 112.046
# Episode: 16 Exploration P: 0.6480 Total reward: -4401.352332239955 SOC: 1.0000 Cumulative_SOC_deviation: 428.9781 Fuel Consumption: 111.5712
# maximum steps, simulation is done ...
# elapsed_time: 106.140
# Episode: 17 Exploration P: 0.6307 Total reward: -4347.378936796046 SOC: 1.0000 Cumulative_SOC_deviation: 423.7975 Fuel Consumption: 109.4044
# maximum steps, simulation is done ...
# elapsed_time: 106.708
# Episode: 18 Exploration P: 0.6139 Total reward: -4296.932629757988 SOC: 1.0000 Cumulative_SOC_deviation: 419.3698 Fuel Consumption: 103.2341
# maximum steps, simulation is done ...
# elapsed_time: 106.928
# Episode: 19 Exploration P: 0.5976 Total reward: -4347.910897886365 SOC: 1.0000 Cumulative_SOC_deviation: 424.4347 Fuel Consumption: 103.5643
# maximum steps, simulation is done ...
# elapsed_time: 106.844
# Episode: 20 Exploration P: 0.5816 Total reward: -4060.9340448302164 SOC: 1.0000 Cumulative_SOC_deviation: 395.8752 Fuel Consumption: 102.1817
# maximum steps, simulation is done ...
# elapsed_time: 107.068
# Episode: 21 Exploration P: 0.5662 Total reward: -4046.5727709959165 SOC: 1.0000 Cumulative_SOC_deviation: 394.8033 Fuel Consumption: 98.5394
# maximum steps, simulation is done ...
# elapsed_time: 107.336
# Episode: 22 Exploration P: 0.5511 Total reward: -4080.2695076649966 SOC: 1.0000 Cumulative_SOC_deviation: 397.9192 Fuel Consumption: 101.0776
# maximum steps, simulation is done ...
# elapsed_time: 106.654
# Episode: 23 Exploration P: 0.5364 Total reward: -3745.958459432758 SOC: 1.0000 Cumulative_SOC_deviation: 364.8606 Fuel Consumption: 97.3528
# maximum steps, simulation is done ...
# elapsed_time: 107.728
# Episode: 24 Exploration P: 0.5222 Total reward: -3605.6697961805467 SOC: 1.0000 Cumulative_SOC_deviation: 350.8224 Fuel Consumption: 97.4457
# maximum steps, simulation is done ...
# elapsed_time: 106.251
# Episode: 25 Exploration P: 0.5083 Total reward: -3652.237615836267 SOC: 1.0000 Cumulative_SOC_deviation: 355.7774 Fuel Consumption: 94.4637
# maximum steps, simulation is done ...
# elapsed_time: 107.235
# Episode: 26 Exploration P: 0.4948 Total reward: -3501.7207448110616 SOC: 1.0000 Cumulative_SOC_deviation: 340.6194 Fuel Consumption: 95.5265
# maximum steps, simulation is done ...
# elapsed_time: 107.369
# Episode: 27 Exploration P: 0.4817 Total reward: -3381.1258073896283 SOC: 1.0000 Cumulative_SOC_deviation: 328.8674 Fuel Consumption: 92.4517
# maximum steps, simulation is done ...
# elapsed_time: 109.218
# Episode: 28 Exploration P: 0.4689 Total reward: -2680.1784427677717 SOC: 1.0000 Cumulative_SOC_deviation: 259.0203 Fuel Consumption: 89.9753
# maximum steps, simulation is done ...
# elapsed_time: 107.674
# Episode: 29 Exploration P: 0.4565 Total reward: -3578.429258270688 SOC: 1.0000 Cumulative_SOC_deviation: 348.3945 Fuel Consumption: 94.4844
# maximum steps, simulation is done ...
# elapsed_time: 107.773
# Episode: 30 Exploration P: 0.4444 Total reward: -3055.9999763698997 SOC: 1.0000 Cumulative_SOC_deviation: 296.7036 Fuel Consumption: 88.9641
# maximum steps, simulation is done ...
# elapsed_time: 107.633
# Episode: 31 Exploration P: 0.4326 Total reward: -2389.8313460741756 SOC: 1.0000 Cumulative_SOC_deviation: 230.4520 Fuel Consumption: 85.3115
# maximum steps, simulation is done ...
# elapsed_time: 107.349
# Episode: 32 Exploration P: 0.4212 Total reward: -2939.822562816214 SOC: 1.0000 Cumulative_SOC_deviation: 285.1065 Fuel Consumption: 88.7578
# maximum steps, simulation is done ...
# elapsed_time: 113.561
# Episode: 33 Exploration P: 0.4100 Total reward: -2935.199971271134 SOC: 1.0000 Cumulative_SOC_deviation: 284.9692 Fuel Consumption: 85.5076
# maximum steps, simulation is done ...
# elapsed_time: 108.347
# Episode: 34 Exploration P: 0.3992 Total reward: -2254.7273516036475 SOC: 1.0000 Cumulative_SOC_deviation: 216.9787 Fuel Consumption: 84.9401
# maximum steps, simulation is done ...
# elapsed_time: 106.939
# Episode: 35 Exploration P: 0.3887 Total reward: -2169.7652819911796 SOC: 0.9968 Cumulative_SOC_deviation: 208.6373 Fuel Consumption: 83.3924
# maximum steps, simulation is done ...
# elapsed_time: 107.285
# Episode: 36 Exploration P: 0.3784 Total reward: -2522.0591375156505 SOC: 1.0000 Cumulative_SOC_deviation: 243.7903 Fuel Consumption: 84.1559
# maximum steps, simulation is done ...
# elapsed_time: 107.672
# Episode: 37 Exploration P: 0.3684 Total reward: -2047.0426652893032 SOC: 0.9848 Cumulative_SOC_deviation: 196.4331 Fuel Consumption: 82.7114
# maximum steps, simulation is done ...
# elapsed_time: 108.027
# Episode: 38 Exploration P: 0.3587 Total reward: -2184.299618788595 SOC: 0.9838 Cumulative_SOC_deviation: 210.1444 Fuel Consumption: 82.8558
# maximum steps, simulation is done ...
# elapsed_time: 108.510
# Episode: 39 Exploration P: 0.3493 Total reward: -1728.3949246290333 SOC: 0.9164 Cumulative_SOC_deviation: 165.0451 Fuel Consumption: 77.9444
# maximum steps, simulation is done ...
# elapsed_time: 141.299
# Episode: 40 Exploration P: 0.3401 Total reward: -1257.7210442398396 SOC: 0.8686 Cumulative_SOC_deviation: 118.3945 Fuel Consumption: 73.7758
# maximum steps, simulation is done ...
# elapsed_time: 236.730
# Episode: 41 Exploration P: 0.3311 Total reward: -1640.3645349855258 SOC: 0.9200 Cumulative_SOC_deviation: 156.2451 Fuel Consumption: 77.9134
# maximum steps, simulation is done ...
# elapsed_time: 233.193
# Episode: 42 Exploration P: 0.3224 Total reward: -976.9652162664108 SOC: 0.8147 Cumulative_SOC_deviation: 90.7059 Fuel Consumption: 69.9065
# maximum steps, simulation is done ...
# elapsed_time: 232.792
# Episode: 43 Exploration P: 0.3140 Total reward: -1011.4157644754023 SOC: 0.8144 Cumulative_SOC_deviation: 94.1489 Fuel Consumption: 69.9272
# maximum steps, simulation is done ...
# elapsed_time: 234.063
# Episode: 44 Exploration P: 0.3057 Total reward: -793.5022470788529 SOC: 0.7550 Cumulative_SOC_deviation: 72.7661 Fuel Consumption: 65.8412
# maximum steps, simulation is done ...
# elapsed_time: 233.159
# Episode: 45 Exploration P: 0.2977 Total reward: -1157.8402289881062 SOC: 0.8431 Cumulative_SOC_deviation: 108.5571 Fuel Consumption: 72.2694
# maximum steps, simulation is done ...
# elapsed_time: 232.794
# Episode: 46 Exploration P: 0.2899 Total reward: -993.2226407614585 SOC: 0.7424 Cumulative_SOC_deviation: 92.8031 Fuel Consumption: 65.1912
# maximum steps, simulation is done ...
# elapsed_time: 232.569
# Episode: 47 Exploration P: 0.2824 Total reward: -838.1289264456732 SOC: 0.6433 Cumulative_SOC_deviation: 78.0553 Fuel Consumption: 57.5764
# maximum steps, simulation is done ...
# elapsed_time: 233.977
# Episode: 48 Exploration P: 0.2750 Total reward: -577.4028817178854 SOC: 0.7173 Cumulative_SOC_deviation: 51.4740 Fuel Consumption: 62.6632
# maximum steps, simulation is done ...
# elapsed_time: 233.091
# Episode: 49 Exploration P: 0.2678 Total reward: -1157.1141064421129 SOC: 0.6872 Cumulative_SOC_deviation: 109.5534 Fuel Consumption: 61.5798
# maximum steps, simulation is done ...
# elapsed_time: 231.888
# Episode: 50 Exploration P: 0.2608 Total reward: -923.1701108112305 SOC: 0.6868 Cumulative_SOC_deviation: 86.1879 Fuel Consumption: 61.2909
# maximum steps, simulation is done ...
# elapsed_time: 234.250
# Episode: 51 Exploration P: 0.2540 Total reward: -1966.1212250523035 SOC: 0.4967 Cumulative_SOC_deviation: 191.9162 Fuel Consumption: 46.9590
# maximum steps, simulation is done ...
# elapsed_time: 232.479
# Episode: 52 Exploration P: 0.2474 Total reward: -1599.0341037836945 SOC: 0.5539 Cumulative_SOC_deviation: 154.7979 Fuel Consumption: 51.0553
# maximum steps, simulation is done ...
# elapsed_time: 230.206
# Episode: 53 Exploration P: 0.2410 Total reward: -1333.1885250047305 SOC: 0.5867 Cumulative_SOC_deviation: 127.9667 Fuel Consumption: 53.5213
# maximum steps, simulation is done ...
# elapsed_time: 234.240
# Episode: 54 Exploration P: 0.2347 Total reward: -1820.5521289581213 SOC: 0.5486 Cumulative_SOC_deviation: 176.9435 Fuel Consumption: 51.1172
# maximum steps, simulation is done ...
# elapsed_time: 234.081
# Episode: 55 Exploration P: 0.2286 Total reward: -2012.1049220180967 SOC: 0.5002 Cumulative_SOC_deviation: 196.4424 Fuel Consumption: 47.6813
# maximum steps, simulation is done ...
# elapsed_time: 234.567
# Episode: 56 Exploration P: 0.2227 Total reward: -1472.038995053095 SOC: 0.5700 Cumulative_SOC_deviation: 141.9869 Fuel Consumption: 52.1697
# maximum steps, simulation is done ...
# elapsed_time: 234.695
# Episode: 57 Exploration P: 0.2170 Total reward: -1381.1046280900594 SOC: 0.5643 Cumulative_SOC_deviation: 132.9162 Fuel Consumption: 51.9427
# maximum steps, simulation is done ...
# elapsed_time: 235.203
# Episode: 58 Exploration P: 0.2114 Total reward: -2113.311351036917 SOC: 0.4637 Cumulative_SOC_deviation: 206.8664 Fuel Consumption: 44.6477
# maximum steps, simulation is done ...
# elapsed_time: 235.034
# Episode: 59 Exploration P: 0.2059 Total reward: -2413.7178365730406 SOC: 0.4682 Cumulative_SOC_deviation: 236.8699 Fuel Consumption: 45.0192
# maximum steps, simulation is done ...
# elapsed_time: 234.763
# Episode: 60 Exploration P: 0.2006 Total reward: -2125.110822755625 SOC: 0.4662 Cumulative_SOC_deviation: 208.0473 Fuel Consumption: 44.6374
# maximum steps, simulation is done ...
# elapsed_time: 233.466
# Episode: 61 Exploration P: 0.1954 Total reward: -2587.868487532896 SOC: 0.4415 Cumulative_SOC_deviation: 254.4799 Fuel Consumption: 43.0691
# maximum steps, simulation is done ...
# elapsed_time: 233.344
# Episode: 62 Exploration P: 0.1904 Total reward: -3125.579985412869 SOC: 0.3482 Cumulative_SOC_deviation: 308.8898 Fuel Consumption: 36.6821
# maximum steps, simulation is done ...
# elapsed_time: 234.783
# Episode: 63 Exploration P: 0.1855 Total reward: -912.7944729949905 SOC: 0.6545 Cumulative_SOC_deviation: 85.4832 Fuel Consumption: 57.9624
# maximum steps, simulation is done ...
# elapsed_time: 229.997
# Episode: 64 Exploration P: 0.1808 Total reward: -353.5519911371072 SOC: 0.6785 Cumulative_SOC_deviation: 29.6137 Fuel Consumption: 57.4151
# maximum steps, simulation is done ...
# elapsed_time: 215.682
# Episode: 65 Exploration P: 0.1761 Total reward: -368.26751618343786 SOC: 0.6717 Cumulative_SOC_deviation: 31.0837 Fuel Consumption: 57.4303
# maximum steps, simulation is done ...
# elapsed_time: 220.672
# Episode: 66 Exploration P: 0.1716 Total reward: -260.50307387296345 SOC: 0.6482 Cumulative_SOC_deviation: 20.5217 Fuel Consumption: 55.2862
# maximum steps, simulation is done ...
# elapsed_time: 218.423
# Episode: 67 Exploration P: 0.1673 Total reward: -150.81281039671424 SOC: 0.6302 Cumulative_SOC_deviation: 9.8924 Fuel Consumption: 51.8889
# maximum steps, simulation is done ...
# elapsed_time: 218.894
# Episode: 68 Exploration P: 0.1630 Total reward: -144.56088977760535 SOC: 0.6062 Cumulative_SOC_deviation: 9.4154 Fuel Consumption: 50.4070
# maximum steps, simulation is done ...
# elapsed_time: 5289.585
# Episode: 69 Exploration P: 0.1589 Total reward: -207.08113919405187 SOC: 0.6412 Cumulative_SOC_deviation: 15.3465 Fuel Consumption: 53.6161
# maximum steps, simulation is done ...
# elapsed_time: 137.139
# Episode: 70 Exploration P: 0.1548 Total reward: -135.81107436156145 SOC: 0.6051 Cumulative_SOC_deviation: 8.5452 Fuel Consumption: 50.3594
# maximum steps, simulation is done ...
# elapsed_time: 129.551
# Episode: 71 Exploration P: 0.1509 Total reward: -162.02472896263754 SOC: 0.6202 Cumulative_SOC_deviation: 10.9708 Fuel Consumption: 52.3167
# maximum steps, simulation is done ...
# elapsed_time: 130.690
# Episode: 72 Exploration P: 0.1471 Total reward: -182.50969623480228 SOC: 0.6188 Cumulative_SOC_deviation: 13.1320 Fuel Consumption: 51.1893
# maximum steps, simulation is done ...
# elapsed_time: 127.030
# Episode: 73 Exploration P: 0.1434 Total reward: -187.5552298843556 SOC: 0.6227 Cumulative_SOC_deviation: 13.6424 Fuel Consumption: 51.1314
# maximum steps, simulation is done ...
# elapsed_time: 121.149
# Episode: 74 Exploration P: 0.1398 Total reward: -160.84732963262374 SOC: 0.6094 Cumulative_SOC_deviation: 11.0403 Fuel Consumption: 50.4442
# maximum steps, simulation is done ...
# elapsed_time: 97.379
# Episode: 75 Exploration P: 0.1362 Total reward: -145.1341313513274 SOC: 0.6200 Cumulative_SOC_deviation: 9.4146 Fuel Consumption: 50.9877
# maximum steps, simulation is done ...
# elapsed_time: 98.104
# Episode: 76 Exploration P: 0.1328 Total reward: -146.05493975943753 SOC: 0.6199 Cumulative_SOC_deviation: 9.5141 Fuel Consumption: 50.9135
# maximum steps, simulation is done ...
# elapsed_time: 98.159
# Episode: 77 Exploration P: 0.1295 Total reward: -149.0798060375024 SOC: 0.6074 Cumulative_SOC_deviation: 9.9392 Fuel Consumption: 49.6877
# maximum steps, simulation is done ...
# elapsed_time: 98.775
# Episode: 78 Exploration P: 0.1263 Total reward: -145.05690343122538 SOC: 0.6065 Cumulative_SOC_deviation: 9.5098 Fuel Consumption: 49.9586
# maximum steps, simulation is done ...
# elapsed_time: 98.592
# Episode: 79 Exploration P: 0.1231 Total reward: -145.95776874544657 SOC: 0.6197 Cumulative_SOC_deviation: 9.5423 Fuel Consumption: 50.5347
# maximum steps, simulation is done ...
# elapsed_time: 100.111
# Episode: 80 Exploration P: 0.1200 Total reward: -147.18692375434279 SOC: 0.6194 Cumulative_SOC_deviation: 9.6247 Fuel Consumption: 50.9403
# maximum steps, simulation is done ...
# elapsed_time: 106.651
# Episode: 81 Exploration P: 0.1171 Total reward: -125.24979450700629 SOC: 0.6118 Cumulative_SOC_deviation: 7.6076 Fuel Consumption: 49.1743
# maximum steps, simulation is done ...
# elapsed_time: 106.548
# Episode: 82 Exploration P: 0.1142 Total reward: -147.61313841351645 SOC: 0.6196 Cumulative_SOC_deviation: 9.6822 Fuel Consumption: 50.7908
# maximum steps, simulation is done ...
# elapsed_time: 109.199
# Episode: 83 Exploration P: 0.1113 Total reward: -140.3817025840113 SOC: 0.6135 Cumulative_SOC_deviation: 9.0230 Fuel Consumption: 50.1517
# maximum steps, simulation is done ...
# elapsed_time: 113.973
# Episode: 84 Exploration P: 0.1086 Total reward: -150.18046070839463 SOC: 0.6208 Cumulative_SOC_deviation: 10.0127 Fuel Consumption: 50.0533
# maximum steps, simulation is done ...
# elapsed_time: 107.794
# Episode: 85 Exploration P: 0.1059 Total reward: -135.2963914724352 SOC: 0.6007 Cumulative_SOC_deviation: 8.6826 Fuel Consumption: 48.4705
# maximum steps, simulation is done ...
# elapsed_time: 102.586
# Episode: 86 Exploration P: 0.1033 Total reward: -144.981850133959 SOC: 0.6152 Cumulative_SOC_deviation: 9.4853 Fuel Consumption: 50.1288
# maximum steps, simulation is done ...
# elapsed_time: 99.048
# Episode: 87 Exploration P: 0.1008 Total reward: -130.71989858291244 SOC: 0.6028 Cumulative_SOC_deviation: 8.2572 Fuel Consumption: 48.1476
# maximum steps, simulation is done ...
# elapsed_time: 100.366
# Episode: 88 Exploration P: 0.0983 Total reward: -133.6948065291761 SOC: 0.6152 Cumulative_SOC_deviation: 8.4103 Fuel Consumption: 49.5914
# maximum steps, simulation is done ...
# elapsed_time: 98.793
# Episode: 89 Exploration P: 0.0960 Total reward: -129.59263516339374 SOC: 0.6125 Cumulative_SOC_deviation: 8.0867 Fuel Consumption: 48.7260
# maximum steps, simulation is done ...
# elapsed_time: 99.026
# Episode: 90 Exploration P: 0.0936 Total reward: -137.59223455470334 SOC: 0.6036 Cumulative_SOC_deviation: 8.8985 Fuel Consumption: 48.6072
# maximum steps, simulation is done ...
# elapsed_time: 98.894
# Episode: 91 Exploration P: 0.0914 Total reward: -137.9800746480919 SOC: 0.6132 Cumulative_SOC_deviation: 8.8619 Fuel Consumption: 49.3612
# maximum steps, simulation is done ...
# elapsed_time: 98.673
# Episode: 92 Exploration P: 0.0892 Total reward: -135.55005630452953 SOC: 0.6093 Cumulative_SOC_deviation: 8.7312 Fuel Consumption: 48.2378
# maximum steps, simulation is done ...
# elapsed_time: 99.119
# Episode: 93 Exploration P: 0.0870 Total reward: -138.18354740004824 SOC: 0.6112 Cumulative_SOC_deviation: 8.9849 Fuel Consumption: 48.3345
# maximum steps, simulation is done ...
# elapsed_time: 99.414
# Episode: 94 Exploration P: 0.0849 Total reward: -138.51162357214935 SOC: 0.6091 Cumulative_SOC_deviation: 9.0869 Fuel Consumption: 47.6426
# maximum steps, simulation is done ...
# elapsed_time: 98.726
# Episode: 95 Exploration P: 0.0829 Total reward: -134.18980620858463 SOC: 0.5996 Cumulative_SOC_deviation: 8.6963 Fuel Consumption: 47.2270
# maximum steps, simulation is done ...
# elapsed_time: 98.978
# Episode: 96 Exploration P: 0.0809 Total reward: -143.66035042243908 SOC: 0.6018 Cumulative_SOC_deviation: 9.5779 Fuel Consumption: 47.8815
# maximum steps, simulation is done ...
# elapsed_time: 99.098
# Episode: 97 Exploration P: 0.0790 Total reward: -133.6346188404918 SOC: 0.5994 Cumulative_SOC_deviation: 8.6278 Fuel Consumption: 47.3563
# maximum steps, simulation is done ...
# elapsed_time: 98.808
# Episode: 98 Exploration P: 0.0771 Total reward: -137.29511244032017 SOC: 0.5976 Cumulative_SOC_deviation: 9.0244 Fuel Consumption: 47.0509
# maximum steps, simulation is done ...
# elapsed_time: 98.526
# Episode: 99 Exploration P: 0.0753 Total reward: -139.95229868559161 SOC: 0.6033 Cumulative_SOC_deviation: 9.2678 Fuel Consumption: 47.2743
# maximum steps, simulation is done ...
# elapsed_time: 99.119
# Episode: 100 Exploration P: 0.0735 Total reward: -137.7120355997503 SOC: 0.6052 Cumulative_SOC_deviation: 8.9762 Fuel Consumption: 47.9501
# maximum steps, simulation is done ...
# elapsed_time: 97.770
# Episode: 101 Exploration P: 0.0718 Total reward: -135.3244216245176 SOC: 0.5972 Cumulative_SOC_deviation: 8.8506 Fuel Consumption: 46.8187
# maximum steps, simulation is done ...
# elapsed_time: 99.243
# Episode: 102 Exploration P: 0.0701 Total reward: -132.94450861090567 SOC: 0.5943 Cumulative_SOC_deviation: 8.5904 Fuel Consumption: 47.0401
# maximum steps, simulation is done ...
# elapsed_time: 98.812
# Episode: 103 Exploration P: 0.0685 Total reward: -151.06233695442072 SOC: 0.6029 Cumulative_SOC_deviation: 10.3484 Fuel Consumption: 47.5780
# maximum steps, simulation is done ...
# elapsed_time: 98.663
# Episode: 104 Exploration P: 0.0669 Total reward: -147.61606071502513 SOC: 0.5979 Cumulative_SOC_deviation: 10.0384 Fuel Consumption: 47.2316
# maximum steps, simulation is done ...
# elapsed_time: 98.455
# Episode: 105 Exploration P: 0.0654 Total reward: -140.31600735230492 SOC: 0.5989 Cumulative_SOC_deviation: 9.3352 Fuel Consumption: 46.9642
# maximum steps, simulation is done ...
# elapsed_time: 98.879
# Episode: 106 Exploration P: 0.0639 Total reward: -147.42020054809063 SOC: 0.5942 Cumulative_SOC_deviation: 10.0295 Fuel Consumption: 47.1250
# maximum steps, simulation is done ...
# elapsed_time: 98.678
# Episode: 107 Exploration P: 0.0624 Total reward: -148.64765796180805 SOC: 0.5965 Cumulative_SOC_deviation: 10.1737 Fuel Consumption: 46.9109
# maximum steps, simulation is done ...
# elapsed_time: 98.914
# Episode: 108 Exploration P: 0.0610 Total reward: -151.28599252526467 SOC: 0.6004 Cumulative_SOC_deviation: 10.4483 Fuel Consumption: 46.8033
# maximum steps, simulation is done ...
# elapsed_time: 98.871
# Episode: 109 Exploration P: 0.0596 Total reward: -154.86366635792194 SOC: 0.6002 Cumulative_SOC_deviation: 10.8158 Fuel Consumption: 46.7057
# maximum steps, simulation is done ...
# elapsed_time: 99.183
# Episode: 110 Exploration P: 0.0583 Total reward: -166.54014593949574 SOC: 0.6026 Cumulative_SOC_deviation: 11.9905 Fuel Consumption: 46.6353
# maximum steps, simulation is done ...
# elapsed_time: 98.932
# Episode: 111 Exploration P: 0.0570 Total reward: -161.41870498154591 SOC: 0.5946 Cumulative_SOC_deviation: 11.4937 Fuel Consumption: 46.4819
# maximum steps, simulation is done ...
# elapsed_time: 98.765
# Episode: 112 Exploration P: 0.0557 Total reward: -171.75037334622914 SOC: 0.5922 Cumulative_SOC_deviation: 12.5436 Fuel Consumption: 46.3139
# maximum steps, simulation is done ...
# elapsed_time: 98.625
# Episode: 113 Exploration P: 0.0545 Total reward: -172.78138343845805 SOC: 0.5926 Cumulative_SOC_deviation: 12.6788 Fuel Consumption: 45.9935
# maximum steps, simulation is done ...
# elapsed_time: 98.733
# Episode: 114 Exploration P: 0.0533 Total reward: -177.81310365069015 SOC: 0.5935 Cumulative_SOC_deviation: 13.1126 Fuel Consumption: 46.6875
# maximum steps, simulation is done ...
# elapsed_time: 98.609
# Episode: 115 Exploration P: 0.0521 Total reward: -192.3545363102111 SOC: 0.5901 Cumulative_SOC_deviation: 14.5932 Fuel Consumption: 46.4228
# maximum steps, simulation is done ...
# elapsed_time: 98.815
# Episode: 116 Exploration P: 0.0510 Total reward: -208.3080243693351 SOC: 0.5984 Cumulative_SOC_deviation: 16.1658 Fuel Consumption: 46.6500
# maximum steps, simulation is done ...
# elapsed_time: 98.677
# Episode: 117 Exploration P: 0.0498 Total reward: -192.5509940804461 SOC: 0.5963 Cumulative_SOC_deviation: 14.6007 Fuel Consumption: 46.5445
# maximum steps, simulation is done ...
# elapsed_time: 98.651
# Episode: 118 Exploration P: 0.0488 Total reward: -194.01228501158778 SOC: 0.5954 Cumulative_SOC_deviation: 14.7555 Fuel Consumption: 46.4577
# maximum steps, simulation is done ...
# elapsed_time: 98.760
# Episode: 119 Exploration P: 0.0477 Total reward: -196.47988053546632 SOC: 0.5914 Cumulative_SOC_deviation: 15.0482 Fuel Consumption: 45.9975
# maximum steps, simulation is done ...
# elapsed_time: 99.083
# Episode: 120 Exploration P: 0.0467 Total reward: -215.94576200567948 SOC: 0.5905 Cumulative_SOC_deviation: 17.0055 Fuel Consumption: 45.8907
# maximum steps, simulation is done ...
# elapsed_time: 98.771
# Episode: 121 Exploration P: 0.0457 Total reward: -142.63082651241186 SOC: 0.6056 Cumulative_SOC_deviation: 9.5506 Fuel Consumption: 47.1244
# maximum steps, simulation is done ...
# elapsed_time: 98.731
# Episode: 122 Exploration P: 0.0447 Total reward: -172.47918782454863 SOC: 0.5918 Cumulative_SOC_deviation: 12.6122 Fuel Consumption: 46.3577
# maximum steps, simulation is done ...
# elapsed_time: 98.663
# Episode: 123 Exploration P: 0.0438 Total reward: -156.85781779127404 SOC: 0.6025 Cumulative_SOC_deviation: 11.0132 Fuel Consumption: 46.7255
# maximum steps, simulation is done ...
# elapsed_time: 98.924
# Episode: 124 Exploration P: 0.0429 Total reward: -187.52490487952494 SOC: 0.5885 Cumulative_SOC_deviation: 14.1833 Fuel Consumption: 45.6924
# maximum steps, simulation is done ...
# elapsed_time: 98.916
# Episode: 125 Exploration P: 0.0420 Total reward: -181.47484689731058 SOC: 0.6001 Cumulative_SOC_deviation: 13.5087 Fuel Consumption: 46.3877
# maximum steps, simulation is done ...
# elapsed_time: 98.958
# Episode: 126 Exploration P: 0.0411 Total reward: -170.83009736615162 SOC: 0.6035 Cumulative_SOC_deviation: 12.4402 Fuel Consumption: 46.4276
# maximum steps, simulation is done ...
# elapsed_time: 98.090
# Episode: 127 Exploration P: 0.0403 Total reward: -126.89694738318173 SOC: 0.5937 Cumulative_SOC_deviation: 8.0575 Fuel Consumption: 46.3217
# maximum steps, simulation is done ...
# elapsed_time: 98.935
# Episode: 128 Exploration P: 0.0395 Total reward: -138.96175027615104 SOC: 0.6001 Cumulative_SOC_deviation: 9.2305 Fuel Consumption: 46.6566
# maximum steps, simulation is done ...
# elapsed_time: 98.857
# Episode: 129 Exploration P: 0.0387 Total reward: -163.46315015631097 SOC: 0.6072 Cumulative_SOC_deviation: 11.6321 Fuel Consumption: 47.1417
# maximum steps, simulation is done ...
# elapsed_time: 98.977
# Episode: 130 Exploration P: 0.0379 Total reward: -198.82877266854527 SOC: 0.5894 Cumulative_SOC_deviation: 15.2971 Fuel Consumption: 45.8581
# maximum steps, simulation is done ...
# elapsed_time: 99.024
# Episode: 131 Exploration P: 0.0371 Total reward: -136.65562720913022 SOC: 0.5903 Cumulative_SOC_deviation: 9.0952 Fuel Consumption: 45.7041
# maximum steps, simulation is done ...
# elapsed_time: 99.035
# Episode: 132 Exploration P: 0.0364 Total reward: -235.12699231982936 SOC: 0.5919 Cumulative_SOC_deviation: 18.9471 Fuel Consumption: 45.6560
# maximum steps, simulation is done ...
# elapsed_time: 98.684
# Episode: 133 Exploration P: 0.0357 Total reward: -147.34069558556376 SOC: 0.6030 Cumulative_SOC_deviation: 10.0614 Fuel Consumption: 46.7264
# maximum steps, simulation is done ...
# elapsed_time: 95.877
# Episode: 134 Exploration P: 0.0350 Total reward: -125.50077551269736 SOC: 0.6023 Cumulative_SOC_deviation: 7.8086 Fuel Consumption: 47.4147
# maximum steps, simulation is done ...
# elapsed_time: 96.409
# Episode: 135 Exploration P: 0.0343 Total reward: -197.77360945282763 SOC: 0.5871 Cumulative_SOC_deviation: 15.1938 Fuel Consumption: 45.8353
# maximum steps, simulation is done ...
# elapsed_time: 98.915
# Episode: 136 Exploration P: 0.0336 Total reward: -147.73615210195695 SOC: 0.5974 Cumulative_SOC_deviation: 10.1091 Fuel Consumption: 46.6450
# maximum steps, simulation is done ...
# elapsed_time: 98.754
# Episode: 137 Exploration P: 0.0330 Total reward: -131.3298054373629 SOC: 0.6022 Cumulative_SOC_deviation: 8.3901 Fuel Consumption: 47.4284
# maximum steps, simulation is done ...
# elapsed_time: 99.229
# Episode: 138 Exploration P: 0.0324 Total reward: -120.97133387386012 SOC: 0.6025 Cumulative_SOC_deviation: 7.4398 Fuel Consumption: 46.5733
# maximum steps, simulation is done ...
# elapsed_time: 98.789
# Episode: 139 Exploration P: 0.0318 Total reward: -125.22604110279003 SOC: 0.5990 Cumulative_SOC_deviation: 7.8887 Fuel Consumption: 46.3389
# maximum steps, simulation is done ...
# elapsed_time: 98.824
# Episode: 140 Exploration P: 0.0312 Total reward: -124.8158701363306 SOC: 0.6076 Cumulative_SOC_deviation: 7.7918 Fuel Consumption: 46.8979
# maximum steps, simulation is done ...
# elapsed_time: 99.020
# Episode: 141 Exploration P: 0.0306 Total reward: -123.86096844239248 SOC: 0.6003 Cumulative_SOC_deviation: 7.6999 Fuel Consumption: 46.8621
# maximum steps, simulation is done ...
# elapsed_time: 96.343
# Episode: 142 Exploration P: 0.0301 Total reward: -126.05940050414421 SOC: 0.6039 Cumulative_SOC_deviation: 7.9542 Fuel Consumption: 46.5176
# maximum steps, simulation is done ...
# elapsed_time: 96.665
# Episode: 143 Exploration P: 0.0295 Total reward: -119.61443428845443 SOC: 0.6034 Cumulative_SOC_deviation: 7.3394 Fuel Consumption: 46.2200
# maximum steps, simulation is done ...
# elapsed_time: 98.912
# Episode: 144 Exploration P: 0.0290 Total reward: -127.41426922427927 SOC: 0.6041 Cumulative_SOC_deviation: 8.0979 Fuel Consumption: 46.4353
# maximum steps, simulation is done ...
# elapsed_time: 99.144
# Episode: 145 Exploration P: 0.0285 Total reward: -118.96943973515287 SOC: 0.6066 Cumulative_SOC_deviation: 7.2448 Fuel Consumption: 46.5216
# maximum steps, simulation is done ...
# elapsed_time: 99.012
# Episode: 146 Exploration P: 0.0280 Total reward: -119.32832192059396 SOC: 0.6012 Cumulative_SOC_deviation: 7.3610 Fuel Consumption: 45.7186
# maximum steps, simulation is done ...
# elapsed_time: 97.863
# Episode: 147 Exploration P: 0.0275 Total reward: -134.42938784766807 SOC: 0.6000 Cumulative_SOC_deviation: 8.8544 Fuel Consumption: 45.8858
# maximum steps, simulation is done ...
# elapsed_time: 95.787
# Episode: 148 Exploration P: 0.0270 Total reward: -141.13108887633442 SOC: 0.6021 Cumulative_SOC_deviation: 9.4732 Fuel Consumption: 46.3986
# maximum steps, simulation is done ...
# elapsed_time: 99.277
# Episode: 149 Exploration P: 0.0265 Total reward: -122.36465685646301 SOC: 0.6011 Cumulative_SOC_deviation: 7.5874 Fuel Consumption: 46.4904
# maximum steps, simulation is done ...
# elapsed_time: 99.101
# Episode: 150 Exploration P: 0.0261 Total reward: -118.79494960041814 SOC: 0.6027 Cumulative_SOC_deviation: 7.2957 Fuel Consumption: 45.8378
# maximum steps, simulation is done ...
# elapsed_time: 99.109
# Episode: 151 Exploration P: 0.0257 Total reward: -120.56877022727136 SOC: 0.5997 Cumulative_SOC_deviation: 7.4923 Fuel Consumption: 45.6457
# maximum steps, simulation is done ...
# elapsed_time: 97.192
# Episode: 152 Exploration P: 0.0252 Total reward: -122.64141898529242 SOC: 0.6021 Cumulative_SOC_deviation: 7.6665 Fuel Consumption: 45.9761
# maximum steps, simulation is done ...
# elapsed_time: 95.843
# Episode: 153 Exploration P: 0.0248 Total reward: -131.6504506166169 SOC: 0.5976 Cumulative_SOC_deviation: 8.5602 Fuel Consumption: 46.0487
# maximum steps, simulation is done ...
# elapsed_time: 98.651
# Episode: 154 Exploration P: 0.0244 Total reward: -132.2598406185945 SOC: 0.5970 Cumulative_SOC_deviation: 8.6093 Fuel Consumption: 46.1671
# maximum steps, simulation is done ...
# elapsed_time: 98.886
# Episode: 155 Exploration P: 0.0240 Total reward: -117.93398604086295 SOC: 0.6001 Cumulative_SOC_deviation: 7.1989 Fuel Consumption: 45.9450
# maximum steps, simulation is done ...
# elapsed_time: 98.996
# Episode: 156 Exploration P: 0.0237 Total reward: -126.21921770017111 SOC: 0.6003 Cumulative_SOC_deviation: 8.0306 Fuel Consumption: 45.9128
# maximum steps, simulation is done ...
# elapsed_time: 98.899
# Episode: 157 Exploration P: 0.0233 Total reward: -150.5657197036673 SOC: 0.5991 Cumulative_SOC_deviation: 10.4082 Fuel Consumption: 46.4838
# maximum steps, simulation is done ...
# elapsed_time: 98.977
# Episode: 158 Exploration P: 0.0229 Total reward: -118.02387374765385 SOC: 0.6027 Cumulative_SOC_deviation: 7.1989 Fuel Consumption: 46.0352
# maximum steps, simulation is done ...
# elapsed_time: 99.141
# Episode: 159 Exploration P: 0.0226 Total reward: -116.97333149155924 SOC: 0.6027 Cumulative_SOC_deviation: 7.0953 Fuel Consumption: 46.0202
# maximum steps, simulation is done ...
# elapsed_time: 98.954
# Episode: 160 Exploration P: 0.0222 Total reward: -125.22201963447574 SOC: 0.6001 Cumulative_SOC_deviation: 7.9476 Fuel Consumption: 45.7462
# maximum steps, simulation is done ...
# elapsed_time: 98.831
# Episode: 161 Exploration P: 0.0219 Total reward: -125.50194400890753 SOC: 0.6024 Cumulative_SOC_deviation: 7.9431 Fuel Consumption: 46.0709
# maximum steps, simulation is done ...
# elapsed_time: 98.992
# Episode: 162 Exploration P: 0.0216 Total reward: -125.21833983940962 SOC: 0.6016 Cumulative_SOC_deviation: 7.9007 Fuel Consumption: 46.2117
# maximum steps, simulation is done ...
# elapsed_time: 98.947
# Episode: 163 Exploration P: 0.0213 Total reward: -113.62787275383042 SOC: 0.6011 Cumulative_SOC_deviation: 6.7684 Fuel Consumption: 45.9435
# maximum steps, simulation is done ...
# elapsed_time: 98.745
# Episode: 164 Exploration P: 0.0210 Total reward: -130.32278287746414 SOC: 0.5970 Cumulative_SOC_deviation: 8.4488 Fuel Consumption: 45.8351
# maximum steps, simulation is done ...
# elapsed_time: 98.799
# Episode: 165 Exploration P: 0.0207 Total reward: -132.5235145773296 SOC: 0.5959 Cumulative_SOC_deviation: 8.7165 Fuel Consumption: 45.3588
# maximum steps, simulation is done ...
# elapsed_time: 98.607
# Episode: 166 Exploration P: 0.0204 Total reward: -131.15991071592555 SOC: 0.6016 Cumulative_SOC_deviation: 8.5362 Fuel Consumption: 45.7980
# maximum steps, simulation is done ...
# elapsed_time: 98.728
# Episode: 167 Exploration P: 0.0201 Total reward: -123.7011477025143 SOC: 0.6017 Cumulative_SOC_deviation: 7.7945 Fuel Consumption: 45.7557
# maximum steps, simulation is done ...
# elapsed_time: 98.935
# Episode: 168 Exploration P: 0.0198 Total reward: -119.95565814189156 SOC: 0.5987 Cumulative_SOC_deviation: 7.3990 Fuel Consumption: 45.9660
# maximum steps, simulation is done ...
# elapsed_time: 98.292
# Episode: 169 Exploration P: 0.0196 Total reward: -135.50946940053942 SOC: 0.5959 Cumulative_SOC_deviation: 8.9660 Fuel Consumption: 45.8496
# maximum steps, simulation is done ...
# elapsed_time: 98.627
# Episode: 170 Exploration P: 0.0193 Total reward: -138.5817846557895 SOC: 0.5987 Cumulative_SOC_deviation: 9.3260 Fuel Consumption: 45.3219
# maximum steps, simulation is done ...
# elapsed_time: 98.183
# Episode: 171 Exploration P: 0.0190 Total reward: -134.43606142326666 SOC: 0.6006 Cumulative_SOC_deviation: 8.8773 Fuel Consumption: 45.6632
# maximum steps, simulation is done ...
# elapsed_time: 98.416
# Episode: 172 Exploration P: 0.0188 Total reward: -129.11655756135434 SOC: 0.5983 Cumulative_SOC_deviation: 8.3291 Fuel Consumption: 45.8260
# maximum steps, simulation is done ...
# elapsed_time: 98.439
# Episode: 173 Exploration P: 0.0186 Total reward: -140.39876073187867 SOC: 0.5937 Cumulative_SOC_deviation: 9.5141 Fuel Consumption: 45.2573
# maximum steps, simulation is done ...
# elapsed_time: 98.465
# Episode: 174 Exploration P: 0.0183 Total reward: -154.08576646942325 SOC: 0.5969 Cumulative_SOC_deviation: 10.8341 Fuel Consumption: 45.7450
# maximum steps, simulation is done ...
# elapsed_time: 102.399
# Episode: 175 Exploration P: 0.0181 Total reward: -125.4114961623301 SOC: 0.6028 Cumulative_SOC_deviation: 7.9387 Fuel Consumption: 46.0250
# maximum steps, simulation is done ...
# elapsed_time: 103.624
# Episode: 176 Exploration P: 0.0179 Total reward: -131.2614061180709 SOC: 0.5971 Cumulative_SOC_deviation: 8.5780 Fuel Consumption: 45.4815
# maximum steps, simulation is done ...
# elapsed_time: 97.921
# Episode: 177 Exploration P: 0.0177 Total reward: -133.08190406020356 SOC: 0.6029 Cumulative_SOC_deviation: 8.6734 Fuel Consumption: 46.3475
# maximum steps, simulation is done ...
# elapsed_time: 98.641
# Episode: 178 Exploration P: 0.0175 Total reward: -116.7706301196337 SOC: 0.6049 Cumulative_SOC_deviation: 7.0650 Fuel Consumption: 46.1204
# maximum steps, simulation is done ...
# elapsed_time: 98.707
# Episode: 179 Exploration P: 0.0173 Total reward: -115.17564276054941 SOC: 0.6021 Cumulative_SOC_deviation: 6.9118 Fuel Consumption: 46.0574
# maximum steps, simulation is done ...
# elapsed_time: 98.930
# Episode: 180 Exploration P: 0.0171 Total reward: -128.10316829747717 SOC: 0.5993 Cumulative_SOC_deviation: 8.2370 Fuel Consumption: 45.7331
# maximum steps, simulation is done ...
# elapsed_time: 98.561
# Episode: 181 Exploration P: 0.0169 Total reward: -118.98261072358297 SOC: 0.6011 Cumulative_SOC_deviation: 7.3083 Fuel Consumption: 45.8999
# maximum steps, simulation is done ...
# elapsed_time: 98.680
# Episode: 182 Exploration P: 0.0167 Total reward: -128.5233251589289 SOC: 0.5988 Cumulative_SOC_deviation: 8.2693 Fuel Consumption: 45.8307
# maximum steps, simulation is done ...
# elapsed_time: 99.315
# Episode: 183 Exploration P: 0.0165 Total reward: -133.1802959302018 SOC: 0.5971 Cumulative_SOC_deviation: 8.7694 Fuel Consumption: 45.4858
# maximum steps, simulation is done ...
# elapsed_time: 98.720
# Episode: 184 Exploration P: 0.0163 Total reward: -132.219458951024 SOC: 0.5990 Cumulative_SOC_deviation: 8.6837 Fuel Consumption: 45.3822
# maximum steps, simulation is done ...
# elapsed_time: 98.240
# Episode: 185 Exploration P: 0.0162 Total reward: -125.7243035468017 SOC: 0.5984 Cumulative_SOC_deviation: 7.9965 Fuel Consumption: 45.7589
# maximum steps, simulation is done ...
# elapsed_time: 98.850
# Episode: 186 Exploration P: 0.0160 Total reward: -128.36101643937556 SOC: 0.6011 Cumulative_SOC_deviation: 8.2838 Fuel Consumption: 45.5234
# maximum steps, simulation is done ...
# elapsed_time: 98.173
# Episode: 187 Exploration P: 0.0158 Total reward: -138.69816565252128 SOC: 0.5962 Cumulative_SOC_deviation: 9.3545 Fuel Consumption: 45.1532
# maximum steps, simulation is done ...
# elapsed_time: 98.695
# Episode: 188 Exploration P: 0.0157 Total reward: -140.65438494388172 SOC: 0.5982 Cumulative_SOC_deviation: 9.4984 Fuel Consumption: 45.6707
# maximum steps, simulation is done ...
# elapsed_time: 98.615
# Episode: 189 Exploration P: 0.0155 Total reward: -130.6759970182682 SOC: 0.5971 Cumulative_SOC_deviation: 8.5001 Fuel Consumption: 45.6753
# maximum steps, simulation is done ...
# elapsed_time: 98.520
# Episode: 190 Exploration P: 0.0154 Total reward: -153.05162816136956 SOC: 0.5956 Cumulative_SOC_deviation: 10.8008 Fuel Consumption: 45.0439
# maximum steps, simulation is done ...
# elapsed_time: 98.361
# Episode: 191 Exploration P: 0.0152 Total reward: -140.77567601568364 SOC: 0.5969 Cumulative_SOC_deviation: 9.5094 Fuel Consumption: 45.6818
# maximum steps, simulation is done ...
# elapsed_time: 98.508
# Episode: 192 Exploration P: 0.0151 Total reward: -146.6740589259156 SOC: 0.5977 Cumulative_SOC_deviation: 10.1331 Fuel Consumption: 45.3426
# maximum steps, simulation is done ...
# elapsed_time: 98.621
# Episode: 193 Exploration P: 0.0149 Total reward: -157.81696537427138 SOC: 0.5968 Cumulative_SOC_deviation: 11.2839 Fuel Consumption: 44.9784
# maximum steps, simulation is done ...
# elapsed_time: 98.254
# Episode: 194 Exploration P: 0.0148 Total reward: -150.70770101865662 SOC: 0.5983 Cumulative_SOC_deviation: 10.5650 Fuel Consumption: 45.0581
# maximum steps, simulation is done ...
# elapsed_time: 98.375
# Episode: 195 Exploration P: 0.0147 Total reward: -169.71480422127954 SOC: 0.5961 Cumulative_SOC_deviation: 12.4164 Fuel Consumption: 45.5510
# maximum steps, simulation is done ...
# elapsed_time: 98.700
# Episode: 196 Exploration P: 0.0146 Total reward: -143.93375455815786 SOC: 0.6010 Cumulative_SOC_deviation: 9.8422 Fuel Consumption: 45.5115
# maximum steps, simulation is done ...
# elapsed_time: 98.462
# Episode: 197 Exploration P: 0.0144 Total reward: -143.82837371543374 SOC: 0.5960 Cumulative_SOC_deviation: 9.8728 Fuel Consumption: 45.1003
# maximum steps, simulation is done ...
# elapsed_time: 98.366
# Episode: 198 Exploration P: 0.0143 Total reward: -163.492473491643 SOC: 0.5946 Cumulative_SOC_deviation: 11.8701 Fuel Consumption: 44.7918
# maximum steps, simulation is done ...
# elapsed_time: 98.492
# Episode: 199 Exploration P: 0.0142 Total reward: -169.71117138373364 SOC: 0.5935 Cumulative_SOC_deviation: 12.5206 Fuel Consumption: 44.5057
# maximum steps, simulation is done ...
# elapsed_time: 98.445
# Episode: 200 Exploration P: 0.0141 Total reward: -153.6849983278425 SOC: 0.5956 Cumulative_SOC_deviation: 10.8857 Fuel Consumption: 44.8279
#
# Trial 1
# maximum steps, simulation is done ...
# elapsed_time: 28.769
# Episode: 1 Exploration P: 1.0000 Total reward: -5082.201166663016 SOC: 1.0000 Cumulative_SOC_deviation: 493.3887 Fuel Consumption: 148.3141
# maximum steps, simulation is done ...
# elapsed_time: 30.238
# Episode: 2 Exploration P: 1.0000 Total reward: -5004.881997819692 SOC: 1.0000 Cumulative_SOC_deviation: 485.6083 Fuel Consumption: 148.7990
# WARNING:tensorflow:Layer batch_normalization_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_7 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_4 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 83.456
# Episode: 3 Exploration P: 0.9217 Total reward: -5015.094425571555 SOC: 1.0000 Cumulative_SOC_deviation: 487.5281 Fuel Consumption: 139.8132
# maximum steps, simulation is done ...
# elapsed_time: 95.930
# Episode: 4 Exploration P: 0.8970 Total reward: -4972.722573751058 SOC: 1.0000 Cumulative_SOC_deviation: 483.3024 Fuel Consumption: 139.6984
# maximum steps, simulation is done ...
# elapsed_time: 95.940
# Episode: 5 Exploration P: 0.8730 Total reward: -5012.188364583319 SOC: 1.0000 Cumulative_SOC_deviation: 487.7051 Fuel Consumption: 135.1378
# maximum steps, simulation is done ...
# elapsed_time: 95.948
# Episode: 6 Exploration P: 0.8496 Total reward: -4873.43744350033 SOC: 1.0000 Cumulative_SOC_deviation: 474.0869 Fuel Consumption: 132.5686
# maximum steps, simulation is done ...
# elapsed_time: 96.152
# Episode: 7 Exploration P: 0.8269 Total reward: -4875.005019257589 SOC: 1.0000 Cumulative_SOC_deviation: 474.6584 Fuel Consumption: 128.4207
# maximum steps, simulation is done ...
# elapsed_time: 95.965
# Episode: 8 Exploration P: 0.8048 Total reward: -4776.648534155889 SOC: 1.0000 Cumulative_SOC_deviation: 464.7753 Fuel Consumption: 128.8953
# maximum steps, simulation is done ...
# elapsed_time: 96.091
# Episode: 9 Exploration P: 0.7832 Total reward: -4753.73733452447 SOC: 1.0000 Cumulative_SOC_deviation: 462.8505 Fuel Consumption: 125.2324
# maximum steps, simulation is done ...
# elapsed_time: 96.110
# Episode: 10 Exploration P: 0.7623 Total reward: -4704.887502676014 SOC: 1.0000 Cumulative_SOC_deviation: 458.3916 Fuel Consumption: 120.9710
# maximum steps, simulation is done ...
# elapsed_time: 96.118
# ...
# elapsed_time: 69.092
# Episode: 121 Exploration P: 0.0457 Total reward: -146.5656778674734 SOC: 0.6009 Cumulative_SOC_deviation: 10.0264 Fuel Consumption: 46.3015
# maximum steps, simulation is done ...
# elapsed_time: 70.106
# Episode: 122 Exploration P: 0.0447 Total reward: -167.97609708784069 SOC: 0.5965 Cumulative_SOC_deviation: 12.2260 Fuel Consumption: 45.7166
# maximum steps, simulation is done ...
# elapsed_time: 70.353
# Episode: 123 Exploration P: 0.0438 Total reward: -168.4264430054289 SOC: 0.5946 Cumulative_SOC_deviation: 12.2497 Fuel Consumption: 45.9296
# maximum steps, simulation is done ...
# elapsed_time: 70.264
# Episode: 124 Exploration P: 0.0429 Total reward: -152.13148328018056 SOC: 0.5986 Cumulative_SOC_deviation: 10.6205 Fuel Consumption: 45.9269
# maximum steps, simulation is done ...
# elapsed_time: 70.482
# Episode: 125 Exploration P: 0.0420 Total reward: -144.96572241260097 SOC: 0.5970 Cumulative_SOC_deviation: 9.9054 Fuel Consumption: 45.9116
# maximum steps, simulation is done ...
# elapsed_time: 70.222
# Episode: 126 Exploration P: 0.0411 Total reward: -141.7943064640328 SOC: 0.5952 Cumulative_SOC_deviation: 9.5933 Fuel Consumption: 45.8609
# maximum steps, simulation is done ...
# elapsed_time: 70.027
# Episode: 127 Exploration P: 0.0403 Total reward: -155.69676517814108 SOC: 0.5918 Cumulative_SOC_deviation: 11.0069 Fuel Consumption: 45.6279
# maximum steps, simulation is done ...
# elapsed_time: 69.926
# Episode: 128 Exploration P: 0.0395 Total reward: -148.94945331662396 SOC: 0.6011 Cumulative_SOC_deviation: 10.2746 Fuel Consumption: 46.2030
# maximum steps, simulation is done ...
# elapsed_time: 70.034
# Episode: 129 Exploration P: 0.0387 Total reward: -148.349903464145 SOC: 0.5958 Cumulative_SOC_deviation: 10.2749 Fuel Consumption: 45.6008
# maximum steps, simulation is done ...
# elapsed_time: 69.884
# Episode: 130 Exploration P: 0.0379 Total reward: -150.69143089725344 SOC: 0.5984 Cumulative_SOC_deviation: 10.4864 Fuel Consumption: 45.8271
# maximum steps, simulation is done ...
# elapsed_time: 69.939
# Episode: 131 Exploration P: 0.0371 Total reward: -142.01150174764348 SOC: 0.6000 Cumulative_SOC_deviation: 9.6012 Fuel Consumption: 45.9993
# maximum steps, simulation is done ...
# elapsed_time: 69.971
# Episode: 132 Exploration P: 0.0364 Total reward: -156.39152933468523 SOC: 0.5905 Cumulative_SOC_deviation: 11.1000 Fuel Consumption: 45.3914
# maximum steps, simulation is done ...
# elapsed_time: 69.833
# Episode: 133 Exploration P: 0.0357 Total reward: -146.22539305298707 SOC: 0.5952 Cumulative_SOC_deviation: 10.0750 Fuel Consumption: 45.4758
# maximum steps, simulation is done ...
# elapsed_time: 69.872
# Episode: 134 Exploration P: 0.0350 Total reward: -147.5021973102371 SOC: 0.5994 Cumulative_SOC_deviation: 10.1588 Fuel Consumption: 45.9145
# maximum steps, simulation is done ...
# elapsed_time: 69.971
# Episode: 135 Exploration P: 0.0343 Total reward: -151.9004011392426 SOC: 0.5943 Cumulative_SOC_deviation: 10.6471 Fuel Consumption: 45.4292
# maximum steps, simulation is done ...
# elapsed_time: 70.225
# Episode: 136 Exploration P: 0.0336 Total reward: -158.65022291616035 SOC: 0.5974 Cumulative_SOC_deviation: 11.3247 Fuel Consumption: 45.4035
# maximum steps, simulation is done ...
# elapsed_time: 70.249
# Episode: 137 Exploration P: 0.0330 Total reward: -171.78796276272072 SOC: 0.5951 Cumulative_SOC_deviation: 12.6248 Fuel Consumption: 45.5398
# maximum steps, simulation is done ...
# elapsed_time: 70.224
# Episode: 138 Exploration P: 0.0324 Total reward: -164.8123067173494 SOC: 0.5926 Cumulative_SOC_deviation: 11.9677 Fuel Consumption: 45.1349
# maximum steps, simulation is done ...
# elapsed_time: 70.003
# Episode: 139 Exploration P: 0.0318 Total reward: -151.47391284566848 SOC: 0.5966 Cumulative_SOC_deviation: 10.6322 Fuel Consumption: 45.1518
# maximum steps, simulation is done ...
# elapsed_time: 69.899
# Episode: 140 Exploration P: 0.0312 Total reward: -138.63092280591363 SOC: 0.6003 Cumulative_SOC_deviation: 9.2723 Fuel Consumption: 45.9081
# maximum steps, simulation is done ...
# elapsed_time: 69.861
# Episode: 141 Exploration P: 0.0306 Total reward: -146.73752204373451 SOC: 0.5973 Cumulative_SOC_deviation: 10.0771 Fuel Consumption: 45.9661
# maximum steps, simulation is done ...
# elapsed_time: 69.974
# Episode: 142 Exploration P: 0.0301 Total reward: -184.94252837524016 SOC: 0.5983 Cumulative_SOC_deviation: 13.9642 Fuel Consumption: 45.3008
# maximum steps, simulation is done ...
# elapsed_time: 69.932
# Episode: 143 Exploration P: 0.0295 Total reward: -179.5415670937058 SOC: 0.5900 Cumulative_SOC_deviation: 13.4896 Fuel Consumption: 44.6461
# maximum steps, simulation is done ...
# elapsed_time: 69.941
# Episode: 144 Exploration P: 0.0290 Total reward: -175.04684221002938 SOC: 0.5952 Cumulative_SOC_deviation: 12.9256 Fuel Consumption: 45.7909
# maximum steps, simulation is done ...
# elapsed_time: 69.844
# Episode: 145 Exploration P: 0.0285 Total reward: -199.0111161703102 SOC: 0.5890 Cumulative_SOC_deviation: 15.4538 Fuel Consumption: 44.4730
# maximum steps, simulation is done ...
# elapsed_time: 70.250
# Episode: 146 Exploration P: 0.0280 Total reward: -231.77946664727435 SOC: 0.5934 Cumulative_SOC_deviation: 18.6026 Fuel Consumption: 45.7533
# maximum steps, simulation is done ...
# elapsed_time: 69.250
# Episode: 147 Exploration P: 0.0275 Total reward: -195.9681698471457 SOC: 0.5960 Cumulative_SOC_deviation: 15.1103 Fuel Consumption: 44.8654
# maximum steps, simulation is done ...
# elapsed_time: 69.861
# Episode: 148 Exploration P: 0.0270 Total reward: -157.49860636388536 SOC: 0.5892 Cumulative_SOC_deviation: 11.2835 Fuel Consumption: 44.6638
# maximum steps, simulation is done ...
# elapsed_time: 70.008
# Episode: 149 Exploration P: 0.0265 Total reward: -187.91281257281645 SOC: 0.5919 Cumulative_SOC_deviation: 14.2795 Fuel Consumption: 45.1176
# maximum steps, simulation is done ...
# elapsed_time: 70.718
# Episode: 150 Exploration P: 0.0261 Total reward: -217.28408918671036 SOC: 0.5868 Cumulative_SOC_deviation: 17.2674 Fuel Consumption: 44.6104
# maximum steps, simulation is done ...
# elapsed_time: 70.103
# Episode: 151 Exploration P: 0.0257 Total reward: -178.0785896950434 SOC: 0.6011 Cumulative_SOC_deviation: 13.2559 Fuel Consumption: 45.5196
# maximum steps, simulation is done ...
# elapsed_time: 70.307
# Episode: 152 Exploration P: 0.0252 Total reward: -170.63249165599973 SOC: 0.5954 Cumulative_SOC_deviation: 12.4936 Fuel Consumption: 45.6963
# maximum steps, simulation is done ...
# elapsed_time: 70.307
# Episode: 153 Exploration P: 0.0248 Total reward: -190.1716594687203 SOC: 0.5907 Cumulative_SOC_deviation: 14.5496 Fuel Consumption: 44.6753
# maximum steps, simulation is done ...
# elapsed_time: 70.080
# Episode: 154 Exploration P: 0.0244 Total reward: -181.37214522812442 SOC: 0.5871 Cumulative_SOC_deviation: 13.7086 Fuel Consumption: 44.2860
# maximum steps, simulation is done ...
# elapsed_time: 70.019
# Episode: 155 Exploration P: 0.0240 Total reward: -200.51111258325722 SOC: 0.5974 Cumulative_SOC_deviation: 15.5111 Fuel Consumption: 45.4002
# maximum steps, simulation is done ...
# elapsed_time: 70.230
# Episode: 156 Exploration P: 0.0237 Total reward: -170.902326255264 SOC: 0.5932 Cumulative_SOC_deviation: 12.6089 Fuel Consumption: 44.8133
# maximum steps, simulation is done ...
# elapsed_time: 70.168
# Episode: 157 Exploration P: 0.0233 Total reward: -141.83335566956953 SOC: 0.5964 Cumulative_SOC_deviation: 9.6912 Fuel Consumption: 44.9216
# maximum steps, simulation is done ...
# elapsed_time: 70.178
# Episode: 158 Exploration P: 0.0229 Total reward: -130.58005043789564 SOC: 0.5997 Cumulative_SOC_deviation: 8.4890 Fuel Consumption: 45.6896
# maximum steps, simulation is done ...
# elapsed_time: 70.203
# Episode: 159 Exploration P: 0.0226 Total reward: -143.93199256214226 SOC: 0.5979 Cumulative_SOC_deviation: 9.8592 Fuel Consumption: 45.3400
# maximum steps, simulation is done ...
# elapsed_time: 69.823
# Episode: 160 Exploration P: 0.0222 Total reward: -152.0699623787331 SOC: 0.5972 Cumulative_SOC_deviation: 10.6919 Fuel Consumption: 45.1511
# maximum steps, simulation is done ...
# elapsed_time: 69.962
# Episode: 161 Exploration P: 0.0219 Total reward: -147.7260982967212 SOC: 0.5923 Cumulative_SOC_deviation: 10.2825 Fuel Consumption: 44.9015
# maximum steps, simulation is done ...
# elapsed_time: 69.831
# Episode: 162 Exploration P: 0.0216 Total reward: -144.49912372141924 SOC: 0.6037 Cumulative_SOC_deviation: 9.9036 Fuel Consumption: 45.4634
# maximum steps, simulation is done ...
# elapsed_time: 69.777
# Episode: 163 Exploration P: 0.0213 Total reward: -145.5649970928212 SOC: 0.5936 Cumulative_SOC_deviation: 10.0122 Fuel Consumption: 45.4429
# maximum steps, simulation is done ...
# elapsed_time: 69.815
# Episode: 164 Exploration P: 0.0210 Total reward: -134.38855384339251 SOC: 0.5980 Cumulative_SOC_deviation: 8.9058 Fuel Consumption: 45.3306
# maximum steps, simulation is done ...
# elapsed_time: 69.952
# Episode: 165 Exploration P: 0.0207 Total reward: -164.5200082615293 SOC: 0.5970 Cumulative_SOC_deviation: 11.9658 Fuel Consumption: 44.8620
# maximum steps, simulation is done ...
# elapsed_time: 70.095
# Episode: 166 Exploration P: 0.0204 Total reward: -137.00867511795198 SOC: 0.6012 Cumulative_SOC_deviation: 9.1528 Fuel Consumption: 45.4812
# maximum steps, simulation is done ...
# elapsed_time: 69.908
# Episode: 167 Exploration P: 0.0201 Total reward: -132.7649565438862 SOC: 0.5983 Cumulative_SOC_deviation: 8.7323 Fuel Consumption: 45.4420
# maximum steps, simulation is done ...
# elapsed_time: 70.142
# Episode: 168 Exploration P: 0.0198 Total reward: -130.0315064318672 SOC: 0.6010 Cumulative_SOC_deviation: 8.4349 Fuel Consumption: 45.6823
# maximum steps, simulation is done ...
# elapsed_time: 69.845
# Episode: 169 Exploration P: 0.0196 Total reward: -143.87746590768987 SOC: 0.5982 Cumulative_SOC_deviation: 9.8457 Fuel Consumption: 45.4207
# maximum steps, simulation is done ...
# elapsed_time: 69.706
# Episode: 170 Exploration P: 0.0193 Total reward: -135.0595074706723 SOC: 0.5968 Cumulative_SOC_deviation: 8.9907 Fuel Consumption: 45.1529
# maximum steps, simulation is done ...
# elapsed_time: 69.827
# Episode: 171 Exploration P: 0.0190 Total reward: -125.74000476071365 SOC: 0.5968 Cumulative_SOC_deviation: 8.0223 Fuel Consumption: 45.5168
# maximum steps, simulation is done ...
# elapsed_time: 69.834
# Episode: 172 Exploration P: 0.0188 Total reward: -147.6483051120232 SOC: 0.5934 Cumulative_SOC_deviation: 10.2699 Fuel Consumption: 44.9489
# maximum steps, simulation is done ...
# elapsed_time: 69.898
# Episode: 173 Exploration P: 0.0186 Total reward: -163.67184979261012 SOC: 0.5934 Cumulative_SOC_deviation: 11.8643 Fuel Consumption: 45.0287
# maximum steps, simulation is done ...
# elapsed_time: 68.987
# Episode: 174 Exploration P: 0.0183 Total reward: -158.9600729410566 SOC: 0.5936 Cumulative_SOC_deviation: 11.4370 Fuel Consumption: 44.5904
# maximum steps, simulation is done ...
# elapsed_time: 69.961
# Episode: 175 Exploration P: 0.0181 Total reward: -138.25098473870634 SOC: 0.6017 Cumulative_SOC_deviation: 9.2513 Fuel Consumption: 45.7378
# maximum steps, simulation is done ...
# elapsed_time: 69.837
# Episode: 176 Exploration P: 0.0179 Total reward: -140.77481594255832 SOC: 0.5927 Cumulative_SOC_deviation: 9.5664 Fuel Consumption: 45.1112
# maximum steps, simulation is done ...
# elapsed_time: 69.901
# Episode: 177 Exploration P: 0.0177 Total reward: -139.06545812550976 SOC: 0.5965 Cumulative_SOC_deviation: 9.3737 Fuel Consumption: 45.3288
# maximum steps, simulation is done ...
# elapsed_time: 69.789
# Episode: 178 Exploration P: 0.0175 Total reward: -148.2009252363664 SOC: 0.5973 Cumulative_SOC_deviation: 10.3216 Fuel Consumption: 44.9845
# maximum steps, simulation is done ...
# elapsed_time: 69.856
# Episode: 179 Exploration P: 0.0173 Total reward: -150.22119759548917 SOC: 0.5943 Cumulative_SOC_deviation: 10.5605 Fuel Consumption: 44.6162
# maximum steps, simulation is done ...
# elapsed_time: 69.858
# Episode: 180 Exploration P: 0.0171 Total reward: -152.61177706336312 SOC: 0.5954 Cumulative_SOC_deviation: 10.7421 Fuel Consumption: 45.1906
# maximum steps, simulation is done ...
# elapsed_time: 69.825
# Episode: 181 Exploration P: 0.0169 Total reward: -157.32745830874939 SOC: 0.5960 Cumulative_SOC_deviation: 11.2159 Fuel Consumption: 45.1685
# maximum steps, simulation is done ...
# elapsed_time: 69.660
# Episode: 182 Exploration P: 0.0167 Total reward: -153.71554064492636 SOC: 0.5961 Cumulative_SOC_deviation: 10.8574 Fuel Consumption: 45.1417
# maximum steps, simulation is done ...
# elapsed_time: 69.801
# Episode: 183 Exploration P: 0.0165 Total reward: -166.42611168840702 SOC: 0.5935 Cumulative_SOC_deviation: 12.1692 Fuel Consumption: 44.7338
# maximum steps, simulation is done ...
# elapsed_time: 70.191
# Episode: 184 Exploration P: 0.0163 Total reward: -146.45399118796357 SOC: 0.5964 Cumulative_SOC_deviation: 10.1132 Fuel Consumption: 45.3217
# maximum steps, simulation is done ...
# elapsed_time: 69.859
# Episode: 185 Exploration P: 0.0162 Total reward: -146.55184335882052 SOC: 0.5940 Cumulative_SOC_deviation: 10.1572 Fuel Consumption: 44.9800
# maximum steps, simulation is done ...
# elapsed_time: 69.799
# Episode: 186 Exploration P: 0.0160 Total reward: -155.23014181906026 SOC: 0.5978 Cumulative_SOC_deviation: 10.9930 Fuel Consumption: 45.3004
# maximum steps, simulation is done ...
# elapsed_time: 70.066
# Episode: 187 Exploration P: 0.0158 Total reward: -168.2165762666645 SOC: 0.5935 Cumulative_SOC_deviation: 12.3049 Fuel Consumption: 45.1671
# maximum steps, simulation is done ...
# elapsed_time: 69.870
# Episode: 188 Exploration P: 0.0157 Total reward: -145.79478893015843 SOC: 0.5952 Cumulative_SOC_deviation: 10.0662 Fuel Consumption: 45.1328
# maximum steps, simulation is done ...
# elapsed_time: 69.954
# Episode: 189 Exploration P: 0.0155 Total reward: -142.4235053334257 SOC: 0.5944 Cumulative_SOC_deviation: 9.7349 Fuel Consumption: 45.0742
# maximum steps, simulation is done ...
# elapsed_time: 69.794
# Episode: 190 Exploration P: 0.0154 Total reward: -155.27556593130998 SOC: 0.5955 Cumulative_SOC_deviation: 11.0180 Fuel Consumption: 45.0953
# maximum steps, simulation is done ...
# elapsed_time: 69.614
# Episode: 191 Exploration P: 0.0152 Total reward: -175.53357871204454 SOC: 0.5890 Cumulative_SOC_deviation: 13.1107 Fuel Consumption: 44.4266
# maximum steps, simulation is done ...
# elapsed_time: 69.717
# Episode: 192 Exploration P: 0.0151 Total reward: -225.1408782487349 SOC: 0.5930 Cumulative_SOC_deviation: 18.0199 Fuel Consumption: 44.9423
# maximum steps, simulation is done ...
# elapsed_time: 69.833
# Episode: 193 Exploration P: 0.0149 Total reward: -150.78506406809112 SOC: 0.5950 Cumulative_SOC_deviation: 10.5545 Fuel Consumption: 45.2399
# maximum steps, simulation is done ...
# elapsed_time: 69.856
# Episode: 194 Exploration P: 0.0148 Total reward: -167.17226847139187 SOC: 0.5921 Cumulative_SOC_deviation: 12.2357 Fuel Consumption: 44.8154
# maximum steps, simulation is done ...
# elapsed_time: 69.928
# Episode: 195 Exploration P: 0.0147 Total reward: -158.68216981943507 SOC: 0.5952 Cumulative_SOC_deviation: 11.3617 Fuel Consumption: 45.0649
# maximum steps, simulation is done ...
# elapsed_time: 69.636
# Episode: 196 Exploration P: 0.0146 Total reward: -183.85310586002123 SOC: 0.5927 Cumulative_SOC_deviation: 13.8758 Fuel Consumption: 45.0948
# maximum steps, simulation is done ...
# elapsed_time: 70.029
# Episode: 197 Exploration P: 0.0144 Total reward: -155.05825246943974 SOC: 0.5967 Cumulative_SOC_deviation: 10.9762 Fuel Consumption: 45.2960
# maximum steps, simulation is done ...
# elapsed_time: 69.922
# Episode: 198 Exploration P: 0.0143 Total reward: -151.84484044407193 SOC: 0.5966 Cumulative_SOC_deviation: 10.6415 Fuel Consumption: 45.4302
# maximum steps, simulation is done ...
# elapsed_time: 69.864
# Episode: 199 Exploration P: 0.0142 Total reward: -163.82125938040113 SOC: 0.5925 Cumulative_SOC_deviation: 11.8322 Fuel Consumption: 45.4995
# maximum steps, simulation is done ...
# elapsed_time: 69.244
# Episode: 200 Exploration P: 0.0141 Total reward: -164.20358468836048 SOC: 0.5909 Cumulative_SOC_deviation: 11.9091 Fuel Consumption: 45.1125

# %%
with open("DDPG3_mass1200.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)
